# %% [markdown]
# # 기본

# %%
import pandas as pd
import numpy as np

# Visualization
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
plt.rcParams['font.family'] = 'NanumGothic'
import platform
if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
    rc('font', family='AppleGothic')

matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import os
path = os.path.dirname(os.getcwd())
path = os.path.join(path, "ProcessedData")
train = pd.read_csv(os.path.join(path,"merged_train.csv"))
test = pd.read_csv(os.path.join(path,"merged_test.csv"))

# %%
train=train.drop_duplicates(keep='first')
test=test.drop_duplicates(keep='first')

# %% [markdown]
# ## 1. EDA 및 전처리(baseline: MSE 98)

# %% [markdown]
# ### 1) 상가비율

# %%
tmp = train.groupby(['단지코드','임대건물구분']).count().iloc[:,:1].reset_index()
store = tmp[tmp['임대건물구분']=='상가'].reset_index(drop=True)[['단지코드','총세대수']].rename(columns={'총세대수':'상가수'})
apt = tmp[tmp['임대건물구분']=='아파트'].reset_index(drop=True)[['단지코드','총세대수']].rename(columns={'총세대수':'아파트수'})
total = pd.merge(apt,store,on='단지코드',how='left').fillna(0)
total['상가비율'] = total.apply(lambda x : x['상가수']/(x['아파트수']+x['상가수']),axis=1)
train = pd.merge(train,total[['단지코드','상가비율']],on='단지코드',how='left')

# %%
tmp = test.groupby(['단지코드','임대건물구분']).count().iloc[:,:1].reset_index()
store = tmp[tmp['임대건물구분']=='상가'].reset_index(drop=True)[['단지코드','총세대수']].rename(columns={'총세대수':'상가수'})
apt = tmp[tmp['임대건물구분']=='아파트'].reset_index(drop=True)[['단지코드','총세대수']].rename(columns={'총세대수':'아파트수'})
total = pd.merge(apt,store,on='단지코드',how='left').fillna(0)
total['상가비율'] = total.apply(lambda x : x['상가수']/(x['아파트수']+x['상가수']),axis=1)
test = pd.merge(test,total[['단지코드','상가비율']],on='단지코드',how='left')

# %% [markdown]
# ### 2) 세대당가능주차면수

# %%
train['세대당_가능주차면수'] = train.apply(lambda x : x['단지내주차면수']/x['총세대수'],axis=1)
test['세대당_가능주차면수'] = test.apply(lambda x : x['단지내주차면수']/x['총세대수'],axis=1)

# %% [markdown]
# ### 3) 공가비율

# %%
train['공가비율'] = train.apply(lambda x : x['공가수']/x['총세대수'],axis=1)
test['공가비율'] = test.apply(lambda x : x['공가수']/x['총세대수'],axis=1)

# %% [markdown]
# ### 4) 대형전용면적

# %%
level = 85

# %%
train['대형전용면적'] = train['전용면적'].apply(lambda x : 1 if x>level else 0)
test['대형전용면적'] = test['전용면적'].apply(lambda x : 1 if x>level else 0)

# %% [markdown]
# ### 5) 공급유형
# - 공공임대 5년/10년 $\rightarrow$ 공공임대(단기)

# %%
train.loc[train.공급유형.isin(['공공임대(5년)', '공공임대(10년)']), '공급유형'] = '공공임대(단기)'
test.loc[test.공급유형.isin(['공공임대(5년)', '공공임대(10년)']), '공급유형'] = '공공임대(단기)'

# %% [markdown]
# - 1차원으로 합치기

# %%
not_unique = ['공급유형','전용면적','임대건물구분','전용면적별세대수','대형전용면적','임대보증금','임대료','자격유형']

# %%
train_one = train.drop(not_unique,axis=1).drop_duplicates().reset_index(drop=True)
test_one = test.drop(not_unique,axis=1).drop_duplicates().reset_index(drop=True)

# %% [markdown]
# - 전용면적별세대수 채우기

# %%
for i in train['공급유형'].unique():
    train_one[i] = 0
    test_one[i] = 0

# %%
sample = pd.DataFrame(train.groupby(['단지코드','공급유형']).sum()['전용면적별세대수']).reset_index()
for i in sample.index:
    code = sample.loc[i,'단지코드']
    col = sample.loc[i,'공급유형']
    val = sample.loc[i,'전용면적별세대수']  # 전용면적별세대수
    ind = train_one[train_one['단지코드']==code].index
    train_one.loc[ind,col] = val

# %%
sample = pd.DataFrame(test.groupby(['단지코드','공급유형']).sum()['전용면적별세대수']).reset_index()
for i in sample.index:
    code = sample.loc[i,'단지코드']
    col = sample.loc[i,'공급유형']
    val = sample.loc[i,'전용면적별세대수']  # 전용면적별세대수
    ind = test_one[test_one['단지코드']==code].index
    test_one.loc[ind,col] = val

# %% [markdown]
# ### 6) 임대료 임대보증금 : 평균

# %%
sample = train.groupby('단지코드').mean()[['임대료','임대보증금']].reset_index()
train_one=pd.merge(train_one, sample, on="단지코드", how="left")

# %%
sample = test.groupby('단지코드').mean()[['임대료','임대보증금']].reset_index()
test_one=pd.merge(test_one, sample, on="단지코드", how="left")

# %% [markdown]
# ### 7) 대형전용면적 총개수

# %%
sample = pd.DataFrame(train.groupby('단지코드')['대형전용면적'].sum()).reset_index()
train_one = pd.merge(train_one, sample, on="단지코드", how="left")

# %%
sample = pd.DataFrame(test.groupby('단지코드')['대형전용면적'].sum()).reset_index()
test_one = pd.merge(test_one, sample, on="단지코드", how="left")

# %% [markdown]
# ### 8) 변수제거

# %%
col = ['단지명','도로명주소','subway_name','임대상가']

# %%
train_one = train_one.drop(col,axis=1)
test_one = test_one.drop(col,axis=1)

# %% [markdown]
# ## 2. 데이터 나누기: 단지내주차면수 987 기준

# %%
train_up = train_one[train_one['단지내주차면수']>=987].reset_index(drop=True)
train_down = train_one[train_one['단지내주차면수']<987].reset_index(drop=True)

# %%
test_up = test_one[test_one['단지내주차면수']>=987].reset_index(drop=True)
test_down = test_one[test_one['단지내주차면수']<987].reset_index(drop=True)

# %% [markdown]
# ### 1) train/test up : area 변수 추가(Baseline추가 MSE:96)

# %%
tmp = train[train['단지내주차면수']>=987].reset_index(drop=True)
tmp['등록차량수-총세대수'] = tmp.apply(lambda x : x['등록차량수']-x['총세대수'],axis=1)
tmp['cluster'] = tmp.apply(lambda x : 1 if x['등록차량수-총세대수']>0 else 0 ,axis=1)

# %%
fig, ax = plt.subplots(figsize=(30,5))
sns.kdeplot(data=tmp,x='등록차량수-총세대수')
# Out:
# <AxesSubplot:xlabel='등록차량수-총세대수', ylabel='Density'>

# %%
tmp = tmp[(tmp['등록차량수-총세대수']>200)|(tmp['등록차량수-총세대수']<-200)]
fig, ax = plt.subplots(figsize=(30,5))
sns.countplot(data=tmp,x='공급유형',hue='cluster')

fig, ax = plt.subplots(figsize=(30,5))
sns.countplot(data=tmp,x='지역',hue='cluster')
# Out:
# <AxesSubplot:xlabel='지역', ylabel='count'>

# %%
def areafunc(x):
    if x in ['제주특별자치도','경상남도','부산광역시']:
        return 0
    elif x in ['광주광역시','세종특별자치시','경상북도','전라북도','서울특별시']:
        return 1
    elif x in ['대구광역시']:
        return 2
    else: 
        return 3

# %%
train_up['지역'] = train_up['지역'].apply(lambda x : areafunc(x))
test_up['지역'] = test_up['지역'].apply(lambda x : areafunc(x))

# %%
train_up = train_up.join(pd.get_dummies(train_up['지역'],prefix='area')).iloc[:,:-1]
test_up = test_up.join(pd.get_dummies(test_up['지역'],prefix='area')).iloc[:,:-1]

# %% [markdown]
# ## 3. 모델링

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, KFold, RepeatedKFold
from sklearn.metrics import mean_absolute_error
from catboost import CatBoostRegressor

# %%
def fit(X_train, X_test, y_train, y_test, model):
    try:
        model.fit(X_train, y_train, verbose=False)
    except:
        model.fit(X_train, y_train)
    tst_pred = model.predict(X_test)
    error = mean_absolute_error(y_test,tst_pred)
    return model, tst_pred, error


def fit_models(X, y, models, cv=False):
    X = np.array(X.reset_index(drop=True))
    y = np.array(y.reset_index(drop=True))
    best_error = 10000
    best_tst_pred = 0
    best_model = ""
    if cv==False:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True,random_state=2021)
        for m in models:
            model, tst_pred, error = fit(X_train, X_test, y_train, y_test, m)
            if best_error > error:
                best_error = error
                best_tst_pred = tst_pred
                best_model = model
    else:
        best_tst_idx = []
        kf = KFold(n_splits = 5, shuffle=True,random_state = 2021)
        for m in models:
            mae = []
            pred= []
            tst_idx = []
            for train_index, test_index in kf.split(X, y):
                X_train, X_test = X[train_index], X[test_index]
                y_train, y_test = y[train_index], y[test_index]
                model, tst_pred, error = fit(X_train, X_test, y_train, y_test, m)
                mae.append(error)
                pred.append(tst_pred.tolist())
                tst_idx.append(test_index.tolist())
            cv_error = np.mean(mae)
            if best_error > cv_error:
                best_error = cv_error
                best_tst_pred = pred
                best_tst_idx = sum(tst_idx, [])
                best_model = model
    best_tst_pred = sum(best_tst_pred,[])
    best_tst_pred = dict(zip(best_tst_idx,best_tst_pred))
    try:
        best_model = best_model.fit(np.concatenate((X_train, X_test),axis=0), 
                                                np.concatenate((y_train, y_test),axis=0), 
                                                verbose=False)
    except:
        best_model = best_model.fit(np.concatenate((X_train, X_test),axis=0), 
                                        np.concatenate((y_train, y_test),axis=0))
    return best_model, best_tst_pred, best_error

# %% [markdown]
# ### 1) train/test down

# %%
X = train_down.drop(columns=['단지코드','등록차량수'],axis=1)
X = pd.get_dummies(X, drop_first=True) 
y = train_down['등록차량수']

# %%
models = [CatBoostRegressor(random_state=2021, loss_function = 'MAE')]

model_down,pred_down,error_down = fit_models(X, y, models, cv=True)
print('MAE : ',error_down)
# Out:
# MAE :  105.37534703159452

# %%
plt.figure(figsize=(8,10))
sns.barplot(y = X.columns[np.argsort(model_down.feature_importances_)], x = list(model_down.feature_importances_[np.argsort(model_down.feature_importances_)]))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2) train/test up

# %%
X = train_up.drop(columns=['단지코드','등록차량수','지역','상가비율'],axis=1)
X = X[['총세대수', '공가수', '지하철역', '버스정류장', '단지내주차면수', '연면적', '위도', '경도',
       'subway_dist', '환승역 수', '총인구수', '세대당_인구', '남/여비율', '남/여_0~19세',
       '남/여_20~39세', '남/여_40~69세', '남/여_70세이상', '0~19세_비율', '20~39세_비율',
       '40~69세_비율', '70세이상_비율', '세대당_가능주차면수', '공가비율', '국민임대', '영구임대',
       '공공임대(단기)', '장기전세', '행복주택', '공공임대(분납)', '공공분양', '공공임대(50년)', '임대료',
       '임대보증금', '대형전용면적', 'area_0', 'area_1', 'area_2']]
y = train_up['등록차량수']

models = [CatBoostRegressor(random_state=2021, loss_function = 'MAE')]

model_up,pred_up,error_up = fit_models(X, y, models, cv=True)
print('MAE : ',error_up)
# Out:
# MAE :  295.9342977834218

# %%
plt.figure(figsize=(8,10))
sns.barplot(y = X.columns[np.argsort(model_up.feature_importances_)], x = list(model_up.feature_importances_[np.argsort(model_up.feature_importances_)]))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4. Final prediction

# %%
col = ['총세대수', '공가수', '지하철역', '버스정류장', '단지내주차면수', '연면적', '위도', '경도',
       'subway_dist', '환승역 수', '총인구수', '세대당_인구', '남/여비율', '남/여_0~19세',
       '남/여_20~39세', '남/여_40~69세', '남/여_70세이상', '0~19세_비율', '20~39세_비율',
       '40~69세_비율', '70세이상_비율', '상가비율', '세대당_가능주차면수', '공가비율', '국민임대', '영구임대',
       '공공임대(단기)', '장기전세', '행복주택', '공공임대(분납)', '공공분양', '공공임대(50년)', '임대료',
       '임대보증금', '대형전용면적', '지역_경기도', '지역_경상남도', '지역_경상북도', '지역_광주광역시',
       '지역_대구광역시', '지역_대전광역시', '지역_부산광역시', '지역_서울특별시', '지역_세종특별자치시',
       '지역_울산광역시', '지역_전라남도', '지역_전라북도', '지역_제주특별자치도', '지역_충청남도', '지역_충청북도']

# %%
X_train = train_down.drop(columns=['단지코드','등록차량수'],axis=1)
X_train = pd.get_dummies(X_train, drop_first=True) 
X_train['지역_세종특별자치시'] = 0
X_train = X_train[col]
y_train = train_down['등록차량수']
X_test = test_down.drop(columns=['단지코드'],axis=1)
X_test = pd.get_dummies(X_test, drop_first=True) 
X_test['지역_서울특별시'] = 0
X_test = X_test[col]

# %%
cb_down = CatBoostRegressor(random_state=2021,verbose=False).fit(X_train,y_train)
pred_down = cb_down.predict(X_test)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold

# %%
col = ['총세대수', '공가수', '지하철역', '버스정류장', '단지내주차면수', '연면적', '위도', '경도',
       'subway_dist', '환승역 수', '총인구수', '세대당_인구', '남/여비율', '남/여_0~19세',
       '남/여_20~39세', '남/여_40~69세', '남/여_70세이상', '0~19세_비율', '20~39세_비율',
       '40~69세_비율', '70세이상_비율', '세대당_가능주차면수', '공가비율', '국민임대', '영구임대',
       '공공임대(단기)', '장기전세', '행복주택', '공공임대(분납)', '공공분양', '공공임대(50년)', '임대료',
       '임대보증금', '대형전용면적', 'area_0', 'area_1', 'area_2']

# %%
X_train = train_up.drop(columns=['단지코드','등록차량수','지역'],axis=1)
X_train = X_train[col]
y_train = train_up['등록차량수']
X_test = test_up.drop(columns=['단지코드','지역'],axis=1)
X_test = X_test[col]

cb_up = CatBoostRegressor(random_state=2021,loss_function='MAE').fit(X_train,y_train)
pred_up = cb_up.predict(X_test)
# Out:
# 0:	learn: 334.2965376	total: 2.27ms	remaining: 2.27s
# 1:	learn: 327.6678647	total: 3.27ms	remaining: 1.63s
# 2:	learn: 322.5947783	total: 4.12ms	remaining: 1.37s
# 3:	learn: 318.2730492	total: 4.98ms	remaining: 1.24s
# 4:	learn: 312.9761222	total: 5.95ms	remaining: 1.18s
# 5:	learn: 308.8466067	total: 6.99ms	remaining: 1.16s
# 6:	learn: 303.6475645	total: 7.9ms	remaining: 1.12s
# 7:	learn: 299.3353397	total: 8.87ms	remaining: 1.1s
# 8:	learn: 293.9398340	total: 9.81ms	remaining: 1.08s
# 9:	learn: 289.6665547	total: 11ms	remaining: 1.09s
# 10:	learn: 284.3007535	total: 11.9ms	remaining: 1.07s
# 11:	learn: 280.6670222	total: 12.6ms	remaining: 1.04s
# 12:	learn: 276.2215802	total: 13.4ms	remaining: 1.02s
# 13:	learn: 272.2577485	total: 14.4ms	remaining: 1.01s
# 14:	learn: 267.4491254	total: 15.2ms	remaining: 999ms
# 15:	learn: 262.5309103	total: 16.1ms	remaining: 989ms
# 16:	learn: 257.5089743	total: 16.9ms	remaining: 976ms
# 17:	learn: 252.0111759	total: 17.7ms	remaining: 968ms
# 18:	learn: 248.3001168	total: 18.7ms	remaining: 964ms
# 19:	learn: 244.9112445	total: 19.4ms	remaining: 950ms
# 20:	learn: 239.8359172	total: 20.3ms	remaining: 946ms
# 21:	learn: 235.7144898	total: 21ms	remaining: 936ms
# 22:	learn: 232.7124587	total: 21.8ms	remaining: 925ms
# 23:	learn: 229.6464869	total: 22.5ms	remaining: 917ms
# 24:	learn: 226.6648847	total: 23.3ms	remaining: 910ms
# 25:	learn: 223.7708358	total: 24.2ms	remaining: 906ms
# 26:	learn: 221.1485880	total: 25ms	remaining: 902ms
# 27:	learn: 218.7695081	total: 25.8ms	remaining: 896ms
# 28:	learn: 215.5625901	total: 26.5ms	remaining: 888ms
# 29:	learn: 211.8092527	total: 27.1ms	remaining: 878ms
# 30:	learn: 209.3750576	total: 27.8ms	remaining: 869ms
# 31:	learn: 205.4505020	total: 28.5ms	remaining: 863ms
# 32:	learn: 201.4197321	total: 29.2ms	remaining: 856ms
# 33:	learn: 199.1980065	total: 29.9ms	remaining: 849ms
# 34:	learn: 195.9825061	total: 30.5ms	remaining: 841ms
# 35:	learn: 192.8432558	total: 31.2ms	remaining: 835ms
# 36:	learn: 190.8388952	total: 31.9ms	remaining: 830ms
# 37:	learn: 188.3905324	total: 32.6ms	remaining: 826ms
# 38:	learn: 186.5384004	total: 33.3ms	remaining: 821ms
# 39:	learn: 184.3073412	total: 34ms	remaining: 817ms
# 40:	learn: 182.3768233	total: 34.7ms	remaining: 811ms
# 41:	learn: 179.1631799	total: 35.3ms	remaining: 805ms
# 42:	learn: 176.3542045	total: 35.9ms	remaining: 799ms
# 43:	learn: 173.3957727	total: 36.6ms	remaining: 794ms
# 44:	learn: 171.3226734	total: 37.1ms	remaining: 788ms
# 45:	learn: 168.5793249	total: 37.7ms	remaining: 783ms
# 46:	learn: 165.9452082	total: 38.4ms	remaining: 778ms
# 47:	learn: 164.2863054	total: 39ms	remaining: 773ms
# 48:	learn: 161.7296211	total: 40.2ms	remaining: 779ms
# 49:	learn: 159.6330226	total: 40.9ms	remaining: 776ms
# 50:	learn: 157.4179949	total: 41.5ms	remaining: 772ms
# 51:	learn: 156.0700027	total: 42.2ms	remaining: 769ms
# 52:	learn: 154.6934472	total: 42.8ms	remaining: 765ms
# 53:	learn: 152.8802027	total: 44.2ms	remaining: 774ms
# 54:	learn: 151.2334999	total: 44.8ms	remaining: 770ms
# 55:	learn: 148.7624398	total: 45.5ms	remaining: 766ms
# 56:	learn: 146.1917434	total: 46.1ms	remaining: 763ms
# 57:	learn: 145.0681075	total: 46.7ms	remaining: 759ms
# 58:	learn: 143.2783587	total: 47.5ms	remaining: 757ms
# 59:	learn: 142.1257970	total: 48.1ms	remaining: 753ms
# 60:	learn: 139.1294736	total: 48.7ms	remaining: 750ms
# 61:	learn: 137.5423444	total: 49.3ms	remaining: 745ms
# 62:	learn: 135.9829753	total: 49.9ms	remaining: 742ms
# 63:	learn: 133.7645944	total: 50.5ms	remaining: 738ms
# 64:	learn: 132.2640106	total: 51.1ms	remaining: 734ms
# 65:	learn: 129.5477298	total: 51.7ms	remaining: 731ms
# 66:	learn: 127.6638411	total: 52.3ms	remaining: 728ms
# 67:	learn: 125.5457478	total: 52.8ms	remaining: 724ms
# 68:	learn: 123.5214798	total: 53.4ms	remaining: 721ms
# 69:	learn: 122.0550717	total: 54.1ms	remaining: 718ms
# 70:	learn: 120.2223553	total: 54.6ms	remaining: 715ms
# 71:	learn: 119.8668684	total: 55ms	remaining: 709ms
# 72:	learn: 118.7082813	total: 55.6ms	remaining: 705ms
# 73:	learn: 117.5050849	total: 56.1ms	remaining: 702ms
# 74:	learn: 115.7887979	total: 56.7ms	remaining: 699ms
# 75:	learn: 114.4878799	total: 57.9ms	remaining: 704ms
# 76:	learn: 111.9835375	total: 58.5ms	remaining: 701ms
# 77:	learn: 110.7289582	total: 59.1ms	remaining: 698ms
# 78:	learn: 110.2906915	total: 59.5ms	remaining: 694ms
# 79:	learn: 108.6092030	total: 60.1ms	remaining: 691ms
# 80:	learn: 107.2192621	total: 60.7ms	remaining: 688ms
# 81:	learn: 105.3440482	total: 61.2ms	remaining: 685ms
# 82:	learn: 104.4333860	total: 62.3ms	remaining: 689ms
# 83:	learn: 102.9673605	total: 62.8ms	remaining: 685ms
# 84:	learn: 101.9879446	total: 63.4ms	remaining: 682ms
# 85:	learn: 99.7755654	total: 64ms	remaining: 680ms
# 86:	learn: 98.3639623	total: 64.6ms	remaining: 678ms
# 87:	learn: 97.2863580	total: 65.1ms	remaining: 675ms
# 88:	learn: 96.8488346	total: 65.6ms	remaining: 672ms
# 89:	learn: 95.8794397	total: 66.5ms	remaining: 672ms
# 90:	learn: 94.5806698	total: 67.2ms	remaining: 671ms
# 91:	learn: 93.4285123	total: 67.8ms	remaining: 670ms
# 92:	learn: 92.2422591	total: 68.5ms	remaining: 668ms
# 93:	learn: 91.4134368	total: 69.2ms	remaining: 667ms
# 94:	learn: 90.5739219	total: 70ms	remaining: 667ms
# 95:	learn: 89.5404554	total: 70.7ms	remaining: 666ms
# 96:	learn: 88.8654175	total: 71.3ms	remaining: 664ms
# 97:	learn: 87.9754734	total: 72ms	remaining: 662ms
# 98:	learn: 86.8200043	total: 72.7ms	remaining: 662ms
# 99:	learn: 85.9894029	total: 73.4ms	remaining: 661ms
# 100:	learn: 84.8776019	total: 74.2ms	remaining: 661ms
# 101:	learn: 84.4772339	total: 75ms	remaining: 660ms
# 102:	learn: 83.2809011	total: 75.7ms	remaining: 659ms
# 103:	learn: 82.7487564	total: 77ms	remaining: 664ms
# 104:	learn: 82.0394387	total: 77.7ms	remaining: 662ms
# 105:	learn: 80.7216583	total: 78.5ms	remaining: 662ms
# 106:	learn: 80.0510764	total: 79.6ms	remaining: 664ms
# 107:	learn: 78.8987131	total: 80.3ms	remaining: 663ms
# 108:	learn: 78.2152908	total: 81.3ms	remaining: 665ms
# 109:	learn: 77.7671545	total: 82.1ms	remaining: 664ms
# 110:	learn: 76.6398771	total: 82.9ms	remaining: 664ms
# 111:	learn: 75.4774959	total: 83.6ms	remaining: 662ms
# 112:	learn: 75.3397738	total: 84.2ms	remaining: 661ms
# 113:	learn: 74.4154289	total: 84.9ms	remaining: 660ms
# 114:	learn: 73.9724372	total: 85.7ms	remaining: 659ms
# 115:	learn: 73.2900431	total: 86.4ms	remaining: 658ms
# 116:	learn: 72.2903965	total: 87ms	remaining: 657ms
# 117:	learn: 71.2815901	total: 87.8ms	remaining: 656ms
# 118:	learn: 70.7421045	total: 88.6ms	remaining: 656ms
# 119:	learn: 70.2273862	total: 89.4ms	remaining: 656ms
# 120:	learn: 69.2341682	total: 90ms	remaining: 654ms
# 121:	learn: 68.9602499	total: 90.7ms	remaining: 653ms
# 122:	learn: 68.2601408	total: 91.4ms	remaining: 652ms
# 123:	learn: 67.6429632	total: 92.1ms	remaining: 650ms
# 124:	learn: 66.8024617	total: 93ms	remaining: 651ms
# 125:	learn: 66.3089561	total: 93.7ms	remaining: 650ms
# 126:	learn: 65.6755568	total: 94.5ms	remaining: 650ms
# 127:	learn: 65.3765085	total: 95.2ms	remaining: 648ms
# 128:	learn: 64.6613729	total: 96.4ms	remaining: 651ms
# 129:	learn: 63.3562699	total: 97.1ms	remaining: 650ms
# 130:	learn: 62.4812739	total: 97.8ms	remaining: 649ms
# 131:	learn: 61.4173726	total: 98.7ms	remaining: 649ms
# 132:	learn: 60.9050491	total: 99.3ms	remaining: 647ms
# 133:	learn: 60.7022598	total: 99.6ms	remaining: 644ms
# 134:	learn: 59.9888379	total: 100ms	remaining: 642ms
# 135:	learn: 59.2975468	total: 101ms	remaining: 640ms
# 136:	learn: 58.8321152	total: 101ms	remaining: 638ms
# 137:	learn: 58.2545182	total: 102ms	remaining: 637ms
# 138:	learn: 57.5585795	total: 103ms	remaining: 635ms
# 139:	learn: 57.1365940	total: 103ms	remaining: 633ms
# 140:	learn: 56.0879692	total: 104ms	remaining: 633ms
# 141:	learn: 55.5691759	total: 104ms	remaining: 631ms
# 142:	learn: 54.6390081	total: 105ms	remaining: 629ms
# 143:	learn: 54.0779159	total: 106ms	remaining: 628ms
# 144:	learn: 53.6930037	total: 106ms	remaining: 627ms
# 145:	learn: 52.8205148	total: 107ms	remaining: 625ms
# 146:	learn: 52.3693592	total: 108ms	remaining: 626ms
# 147:	learn: 51.6562864	total: 108ms	remaining: 624ms
# 148:	learn: 51.0164097	total: 109ms	remaining: 623ms
# 149:	learn: 50.3787620	total: 110ms	remaining: 622ms
# 150:	learn: 50.0976523	total: 110ms	remaining: 620ms
# 151:	learn: 49.7738779	total: 111ms	remaining: 618ms
# 152:	learn: 49.3104449	total: 111ms	remaining: 617ms
# 153:	learn: 48.9884798	total: 112ms	remaining: 616ms
# 154:	learn: 48.7076536	total: 113ms	remaining: 616ms
# 155:	learn: 47.7995158	total: 113ms	remaining: 614ms
# 156:	learn: 47.4485688	total: 114ms	remaining: 613ms
# 157:	learn: 47.1111110	total: 115ms	remaining: 613ms
# 158:	learn: 46.6327882	total: 115ms	remaining: 611ms
# 159:	learn: 45.9904023	total: 116ms	remaining: 609ms
# 160:	learn: 45.7065497	total: 117ms	remaining: 608ms
# 161:	learn: 44.9027964	total: 117ms	remaining: 606ms
# 162:	learn: 44.6924296	total: 118ms	remaining: 606ms
# 163:	learn: 44.3630599	total: 119ms	remaining: 605ms
# 164:	learn: 44.1256334	total: 119ms	remaining: 604ms
# 165:	learn: 43.8126703	total: 120ms	remaining: 603ms
# 166:	learn: 43.1210866	total: 121ms	remaining: 602ms
# 167:	learn: 42.7239783	total: 121ms	remaining: 602ms
# 168:	learn: 42.0438397	total: 122ms	remaining: 600ms
# 169:	learn: 41.2871018	total: 123ms	remaining: 600ms
# 170:	learn: 40.8427449	total: 124ms	remaining: 600ms
# 171:	learn: 40.5640015	total: 124ms	remaining: 598ms
# 172:	learn: 40.3331428	total: 125ms	remaining: 598ms
# 173:	learn: 39.8949855	total: 126ms	remaining: 597ms
# 174:	learn: 39.6816940	total: 127ms	remaining: 597ms
# 175:	learn: 39.4373405	total: 127ms	remaining: 596ms
# 176:	learn: 39.1887792	total: 128ms	remaining: 595ms
# 177:	learn: 38.6888732	total: 129ms	remaining: 594ms
# 178:	learn: 38.5837724	total: 130ms	remaining: 595ms
# 179:	learn: 38.3293977	total: 130ms	remaining: 594ms
# 180:	learn: 37.9021547	total: 131ms	remaining: 593ms
# 181:	learn: 37.4718791	total: 132ms	remaining: 592ms
# 182:	learn: 37.1708576	total: 133ms	remaining: 593ms
# 183:	learn: 36.9712023	total: 134ms	remaining: 593ms
# 184:	learn: 36.8266384	total: 134ms	remaining: 592ms
# 185:	learn: 36.5676306	total: 135ms	remaining: 592ms
# 186:	learn: 36.3193725	total: 136ms	remaining: 592ms
# 187:	learn: 36.0866428	total: 137ms	remaining: 591ms
# 188:	learn: 35.7871651	total: 137ms	remaining: 590ms
# 189:	learn: 35.5671345	total: 138ms	remaining: 589ms
# 190:	learn: 34.8658132	total: 139ms	remaining: 589ms
# 191:	learn: 34.5357902	total: 140ms	remaining: 588ms
# 192:	learn: 34.0855490	total: 141ms	remaining: 589ms
# 193:	learn: 33.7762156	total: 142ms	remaining: 590ms
# 194:	learn: 33.4676206	total: 143ms	remaining: 590ms
# 195:	learn: 33.1415118	total: 144ms	remaining: 589ms
# 196:	learn: 32.8848356	total: 145ms	remaining: 590ms
# 197:	learn: 32.5653264	total: 145ms	remaining: 589ms
# 198:	learn: 32.2925697	total: 146ms	remaining: 588ms
# 199:	learn: 32.0383535	total: 147ms	remaining: 588ms
# 200:	learn: 31.7762458	total: 148ms	remaining: 587ms
# 201:	learn: 31.4180538	total: 148ms	remaining: 586ms
# 202:	learn: 31.0360393	total: 149ms	remaining: 585ms
# 203:	learn: 30.7034738	total: 150ms	remaining: 584ms
# 204:	learn: 30.1659830	total: 151ms	remaining: 584ms
# 205:	learn: 29.8688319	total: 151ms	remaining: 583ms
# 206:	learn: 29.0475902	total: 152ms	remaining: 582ms
# 207:	learn: 28.8231904	total: 153ms	remaining: 582ms
# 208:	learn: 28.5994759	total: 153ms	remaining: 581ms
# 209:	learn: 28.1960800	total: 154ms	remaining: 580ms
# 210:	learn: 27.7184243	total: 155ms	remaining: 579ms
# 211:	learn: 27.6120549	total: 155ms	remaining: 578ms
# 212:	learn: 27.3362532	total: 156ms	remaining: 577ms
# 213:	learn: 27.2099076	total: 157ms	remaining: 577ms
# 214:	learn: 26.8026427	total: 158ms	remaining: 576ms
# 215:	learn: 26.5397382	total: 159ms	remaining: 576ms
# 216:	learn: 26.2202264	total: 159ms	remaining: 574ms
# 217:	learn: 26.0499041	total: 160ms	remaining: 574ms
# 218:	learn: 25.8872984	total: 161ms	remaining: 574ms
# 219:	learn: 25.6254920	total: 162ms	remaining: 574ms
# 220:	learn: 25.2670126	total: 162ms	remaining: 573ms
# 221:	learn: 24.9941431	total: 163ms	remaining: 572ms
# 222:	learn: 24.8691184	total: 164ms	remaining: 571ms
# 223:	learn: 24.7205763	total: 165ms	remaining: 570ms
# 224:	learn: 24.5549611	total: 165ms	remaining: 569ms
# 225:	learn: 24.3941292	total: 166ms	remaining: 568ms
# 226:	learn: 24.1689914	total: 167ms	remaining: 567ms
# 227:	learn: 23.9979924	total: 167ms	remaining: 566ms
# 228:	learn: 23.7958165	total: 168ms	remaining: 566ms
# 229:	learn: 23.6508765	total: 169ms	remaining: 565ms
# 230:	learn: 23.3744453	total: 170ms	remaining: 565ms
# 231:	learn: 22.9805537	total: 171ms	remaining: 564ms
# 232:	learn: 22.8090860	total: 171ms	remaining: 564ms
# 233:	learn: 22.5684927	total: 172ms	remaining: 562ms
# 234:	learn: 22.3406594	total: 172ms	remaining: 561ms
# 235:	learn: 22.1995167	total: 173ms	remaining: 560ms
# 236:	learn: 21.9925696	total: 174ms	remaining: 559ms
# 237:	learn: 21.8865853	total: 174ms	remaining: 558ms
# 238:	learn: 21.6552355	total: 175ms	remaining: 558ms
# 239:	learn: 21.0599291	total: 176ms	remaining: 557ms
# 240:	learn: 20.9151726	total: 176ms	remaining: 556ms
# 241:	learn: 20.7473215	total: 177ms	remaining: 555ms
# 242:	learn: 20.6312304	total: 178ms	remaining: 555ms
# 243:	learn: 20.5473280	total: 179ms	remaining: 554ms
# 244:	learn: 20.4226521	total: 180ms	remaining: 554ms
# 245:	learn: 20.2457053	total: 180ms	remaining: 553ms
# 246:	learn: 20.1262853	total: 181ms	remaining: 552ms
# 247:	learn: 19.9925436	total: 182ms	remaining: 552ms
# 248:	learn: 19.6949632	total: 183ms	remaining: 552ms
# 249:	learn: 19.5980612	total: 184ms	remaining: 551ms
# 250:	learn: 19.5485053	total: 184ms	remaining: 550ms
# 251:	learn: 19.4530272	total: 185ms	remaining: 550ms
# 252:	learn: 19.3532934	total: 186ms	remaining: 549ms
# 253:	learn: 19.2592788	total: 187ms	remaining: 549ms
# 254:	learn: 19.0721942	total: 187ms	remaining: 548ms
# 255:	learn: 18.8838333	total: 189ms	remaining: 548ms
# 256:	learn: 18.7788343	total: 189ms	remaining: 548ms
# 257:	learn: 18.6577280	total: 190ms	remaining: 547ms
# 258:	learn: 18.5459869	total: 191ms	remaining: 546ms
# 259:	learn: 18.1306992	total: 191ms	remaining: 545ms
# 260:	learn: 17.7001177	total: 192ms	remaining: 544ms
# 261:	learn: 17.3030776	total: 193ms	remaining: 543ms
# 262:	learn: 16.9078354	total: 193ms	remaining: 542ms
# 263:	learn: 16.6184884	total: 194ms	remaining: 540ms
# 264:	learn: 16.4136398	total: 194ms	remaining: 539ms
# 265:	learn: 16.3403046	total: 195ms	remaining: 538ms
# 266:	learn: 16.0873464	total: 196ms	remaining: 537ms
# 267:	learn: 15.8419770	total: 196ms	remaining: 536ms
# 268:	learn: 15.7640702	total: 197ms	remaining: 535ms
# 269:	learn: 15.7216350	total: 198ms	remaining: 535ms
# 270:	learn: 15.6588570	total: 198ms	remaining: 534ms
# 271:	learn: 15.5505322	total: 199ms	remaining: 533ms
# 272:	learn: 15.4880161	total: 200ms	remaining: 532ms
# 273:	learn: 15.4381982	total: 200ms	remaining: 531ms
# 274:	learn: 15.3339154	total: 201ms	remaining: 530ms
# 275:	learn: 15.2316247	total: 202ms	remaining: 529ms
# 276:	learn: 15.1429053	total: 202ms	remaining: 528ms
# 277:	learn: 15.0876839	total: 203ms	remaining: 527ms
# 278:	learn: 14.9295366	total: 204ms	remaining: 526ms
# 279:	learn: 14.6794321	total: 204ms	remaining: 525ms
# 280:	learn: 14.5929926	total: 205ms	remaining: 525ms
# 281:	learn: 14.5196238	total: 206ms	remaining: 524ms
# 282:	learn: 14.3569312	total: 206ms	remaining: 523ms
# 283:	learn: 14.2836350	total: 207ms	remaining: 522ms
# 284:	learn: 14.2250338	total: 208ms	remaining: 521ms
# 285:	learn: 14.1533056	total: 209ms	remaining: 522ms
# 286:	learn: 14.0864539	total: 210ms	remaining: 522ms
# 287:	learn: 13.9824113	total: 212ms	remaining: 524ms
# 288:	learn: 13.8827190	total: 213ms	remaining: 523ms
# 289:	learn: 13.7814490	total: 214ms	remaining: 523ms
# 290:	learn: 13.6832213	total: 215ms	remaining: 523ms
# 291:	learn: 13.5881505	total: 215ms	remaining: 522ms
# 292:	learn: 13.5643419	total: 216ms	remaining: 521ms
# 293:	learn: 13.4645128	total: 217ms	remaining: 520ms
# 294:	learn: 13.3663552	total: 217ms	remaining: 520ms
# 295:	learn: 13.2865674	total: 218ms	remaining: 519ms
# 296:	learn: 13.1529085	total: 219ms	remaining: 518ms
# 297:	learn: 13.0242788	total: 219ms	remaining: 517ms
# 298:	learn: 12.9662681	total: 220ms	remaining: 517ms
# 299:	learn: 12.9258825	total: 221ms	remaining: 516ms
# 300:	learn: 12.8004457	total: 222ms	remaining: 515ms
# 301:	learn: 12.7823176	total: 222ms	remaining: 514ms
# 302:	learn: 12.5285702	total: 223ms	remaining: 513ms
# 303:	learn: 12.4264421	total: 224ms	remaining: 512ms
# 304:	learn: 12.2702935	total: 225ms	remaining: 512ms
# 305:	learn: 12.1301677	total: 227ms	remaining: 514ms
# 306:	learn: 12.0671521	total: 227ms	remaining: 513ms
# 307:	learn: 11.9982629	total: 228ms	remaining: 513ms
# 308:	learn: 11.9163059	total: 230ms	remaining: 514ms
# 309:	learn: 11.6113279	total: 231ms	remaining: 513ms
# 310:	learn: 11.4873050	total: 231ms	remaining: 513ms
# 311:	learn: 11.4083875	total: 232ms	remaining: 512ms
# 312:	learn: 11.3717733	total: 233ms	remaining: 511ms
# 313:	learn: 11.3553992	total: 233ms	remaining: 510ms
# 314:	learn: 11.2067128	total: 234ms	remaining: 509ms
# 315:	learn: 11.1559022	total: 235ms	remaining: 508ms
# 316:	learn: 10.9240189	total: 235ms	remaining: 507ms
# 317:	learn: 10.9149569	total: 236ms	remaining: 506ms
# 318:	learn: 10.6487929	total: 236ms	remaining: 505ms
# 319:	learn: 10.6299280	total: 237ms	remaining: 504ms
# 320:	learn: 10.4919984	total: 238ms	remaining: 503ms
# 321:	learn: 10.3803910	total: 238ms	remaining: 502ms
# 322:	learn: 10.3571187	total: 239ms	remaining: 502ms
# 323:	learn: 10.3082843	total: 240ms	remaining: 501ms
# 324:	learn: 10.2693185	total: 241ms	remaining: 500ms
# 325:	learn: 10.0228905	total: 242ms	remaining: 500ms
# 326:	learn: 9.7838553	total: 243ms	remaining: 499ms
# 327:	learn: 9.5519912	total: 243ms	remaining: 498ms
# 328:	learn: 9.3270829	total: 244ms	remaining: 498ms
# 329:	learn: 9.1089220	total: 245ms	remaining: 497ms
# 330:	learn: 8.8973058	total: 245ms	remaining: 496ms
# 331:	learn: 8.6920382	total: 246ms	remaining: 495ms
# 332:	learn: 8.4929285	total: 247ms	remaining: 495ms
# 333:	learn: 8.2998144	total: 248ms	remaining: 494ms
# 334:	learn: 8.2773618	total: 249ms	remaining: 493ms
# 335:	learn: 8.0906084	total: 249ms	remaining: 493ms
# 336:	learn: 7.8833625	total: 250ms	remaining: 492ms
# 337:	learn: 7.8749318	total: 251ms	remaining: 492ms
# 338:	learn: 7.7956574	total: 252ms	remaining: 491ms
# 339:	learn: 7.7635481	total: 253ms	remaining: 491ms
# 340:	learn: 7.7419384	total: 253ms	remaining: 490ms
# 341:	learn: 7.7175459	total: 254ms	remaining: 489ms
# 342:	learn: 7.6902752	total: 255ms	remaining: 488ms
# 343:	learn: 7.6721099	total: 255ms	remaining: 487ms
# 344:	learn: 7.6543459	total: 256ms	remaining: 487ms
# 345:	learn: 7.6316987	total: 257ms	remaining: 486ms
# 346:	learn: 7.6237667	total: 258ms	remaining: 485ms
# 347:	learn: 7.6011161	total: 259ms	remaining: 485ms
# 348:	learn: 7.5925790	total: 260ms	remaining: 485ms
# 349:	learn: 7.5628497	total: 261ms	remaining: 484ms
# 350:	learn: 7.5571961	total: 261ms	remaining: 483ms
# 351:	learn: 7.5432061	total: 262ms	remaining: 483ms
# 352:	learn: 7.5240414	total: 263ms	remaining: 482ms
# 353:	learn: 7.4917166	total: 264ms	remaining: 481ms
# 354:	learn: 7.4568777	total: 265ms	remaining: 481ms
# 355:	learn: 7.4266068	total: 266ms	remaining: 482ms
# 356:	learn: 7.3654616	total: 267ms	remaining: 481ms
# 357:	learn: 7.3470072	total: 268ms	remaining: 480ms
# 358:	learn: 7.3196743	total: 269ms	remaining: 480ms
# 359:	learn: 7.3042171	total: 270ms	remaining: 480ms
# 360:	learn: 7.2375462	total: 270ms	remaining: 479ms
# 361:	learn: 7.1728003	total: 271ms	remaining: 478ms
# 362:	learn: 7.1122081	total: 272ms	remaining: 477ms
# 363:	learn: 6.9744760	total: 273ms	remaining: 477ms
# 364:	learn: 6.9429273	total: 274ms	remaining: 477ms
# 365:	learn: 6.9058236	total: 275ms	remaining: 476ms
# 366:	learn: 6.8757112	total: 276ms	remaining: 475ms
# 367:	learn: 6.8424202	total: 276ms	remaining: 474ms
# 368:	learn: 6.8356765	total: 277ms	remaining: 474ms
# 369:	learn: 6.8307484	total: 278ms	remaining: 473ms
# 370:	learn: 6.8259658	total: 279ms	remaining: 473ms
# 371:	learn: 6.8215901	total: 280ms	remaining: 472ms
# 372:	learn: 6.7514616	total: 280ms	remaining: 471ms
# 373:	learn: 6.7391561	total: 281ms	remaining: 471ms
# 374:	learn: 6.7269649	total: 282ms	remaining: 470ms
# 375:	learn: 6.7152075	total: 283ms	remaining: 470ms
# 376:	learn: 6.6958919	total: 284ms	remaining: 469ms
# 377:	learn: 6.6557171	total: 284ms	remaining: 468ms
# 378:	learn: 6.6247296	total: 285ms	remaining: 467ms
# 379:	learn: 6.4845447	total: 286ms	remaining: 466ms
# 380:	learn: 6.4542689	total: 287ms	remaining: 466ms
# 381:	learn: 6.4381245	total: 287ms	remaining: 465ms
# 382:	learn: 6.4312108	total: 288ms	remaining: 464ms
# 383:	learn: 6.4247764	total: 289ms	remaining: 463ms
# 384:	learn: 6.4100980	total: 290ms	remaining: 464ms
# 385:	learn: 6.3831986	total: 291ms	remaining: 463ms
# 386:	learn: 6.3728360	total: 292ms	remaining: 462ms
# 387:	learn: 6.3578466	total: 292ms	remaining: 461ms
# 388:	learn: 6.3272556	total: 293ms	remaining: 461ms
# 389:	learn: 6.2175803	total: 294ms	remaining: 460ms
# 390:	learn: 6.1193892	total: 295ms	remaining: 460ms
# 391:	learn: 6.1083300	total: 296ms	remaining: 459ms
# 392:	learn: 6.0560107	total: 296ms	remaining: 458ms
# 393:	learn: 5.9562680	total: 298ms	remaining: 458ms
# 394:	learn: 5.9315837	total: 298ms	remaining: 457ms
# 395:	learn: 5.8918768	total: 299ms	remaining: 456ms
# 396:	learn: 5.7982813	total: 300ms	remaining: 455ms
# 397:	learn: 5.7823742	total: 301ms	remaining: 455ms
# 398:	learn: 5.7712746	total: 301ms	remaining: 454ms
# 399:	learn: 5.7578616	total: 302ms	remaining: 453ms
# 400:	learn: 5.7477710	total: 303ms	remaining: 452ms
# 401:	learn: 5.7411863	total: 304ms	remaining: 452ms
# 402:	learn: 5.7302233	total: 305ms	remaining: 451ms
# 403:	learn: 5.6595042	total: 305ms	remaining: 450ms
# 404:	learn: 5.6512445	total: 306ms	remaining: 449ms
# 405:	learn: 5.6466302	total: 307ms	remaining: 448ms
# 406:	learn: 5.6422167	total: 307ms	remaining: 448ms
# 407:	learn: 5.6208688	total: 308ms	remaining: 447ms
# 408:	learn: 5.5702875	total: 309ms	remaining: 446ms
# 409:	learn: 5.4649346	total: 309ms	remaining: 445ms
# 410:	learn: 5.3681009	total: 310ms	remaining: 444ms
# 411:	learn: 5.2347861	total: 311ms	remaining: 444ms
# 412:	learn: 5.2222883	total: 312ms	remaining: 443ms
# 413:	learn: 5.0865866	total: 312ms	remaining: 442ms
# 414:	learn: 5.0638387	total: 313ms	remaining: 441ms
# 415:	learn: 4.9722882	total: 314ms	remaining: 440ms
# 416:	learn: 4.8794918	total: 314ms	remaining: 440ms
# 417:	learn: 4.8534705	total: 315ms	remaining: 439ms
# 418:	learn: 4.8282299	total: 316ms	remaining: 438ms
# 419:	learn: 4.8042766	total: 317ms	remaining: 437ms
# 420:	learn: 4.7950781	total: 317ms	remaining: 436ms
# 421:	learn: 4.6697899	total: 318ms	remaining: 436ms
# 422:	learn: 4.6481836	total: 319ms	remaining: 435ms
# 423:	learn: 4.6330103	total: 320ms	remaining: 434ms
# 424:	learn: 4.6140668	total: 321ms	remaining: 434ms
# 425:	learn: 4.6057520	total: 321ms	remaining: 433ms
# 426:	learn: 4.5521909	total: 322ms	remaining: 432ms
# 427:	learn: 4.5409191	total: 323ms	remaining: 431ms
# 428:	learn: 4.4269682	total: 324ms	remaining: 431ms
# 429:	learn: 4.4141416	total: 325ms	remaining: 431ms
# 430:	learn: 4.4025798	total: 326ms	remaining: 430ms
# 431:	learn: 4.3711910	total: 326ms	remaining: 429ms
# 432:	learn: 4.2964078	total: 327ms	remaining: 428ms
# 433:	learn: 4.2274004	total: 328ms	remaining: 428ms
# 434:	learn: 4.2149692	total: 329ms	remaining: 427ms
# 435:	learn: 4.2029111	total: 329ms	remaining: 426ms
# 436:	learn: 4.1912146	total: 331ms	remaining: 426ms
# 437:	learn: 4.1798691	total: 331ms	remaining: 425ms
# 438:	learn: 4.1688639	total: 332ms	remaining: 424ms
# 439:	learn: 4.1581889	total: 333ms	remaining: 424ms
# 440:	learn: 4.1478341	total: 334ms	remaining: 423ms
# 441:	learn: 4.1377925	total: 334ms	remaining: 422ms
# 442:	learn: 4.1320087	total: 335ms	remaining: 421ms
# 443:	learn: 4.1292388	total: 336ms	remaining: 421ms
# 444:	learn: 4.0517273	total: 337ms	remaining: 420ms
# 445:	learn: 4.0361454	total: 338ms	remaining: 419ms
# 446:	learn: 4.0131184	total: 339ms	remaining: 419ms
# 447:	learn: 3.9359218	total: 340ms	remaining: 418ms
# 448:	learn: 3.8954367	total: 340ms	remaining: 418ms
# 449:	learn: 3.8574717	total: 341ms	remaining: 417ms
# 450:	learn: 3.8470153	total: 342ms	remaining: 416ms
# 451:	learn: 3.8399783	total: 343ms	remaining: 415ms
# 452:	learn: 3.7736307	total: 343ms	remaining: 414ms
# 453:	learn: 3.7323224	total: 344ms	remaining: 414ms
# 454:	learn: 3.7245654	total: 345ms	remaining: 413ms
# 455:	learn: 3.6838456	total: 346ms	remaining: 412ms
# 456:	learn: 3.6795653	total: 346ms	remaining: 411ms
# 457:	learn: 3.6172753	total: 347ms	remaining: 410ms
# 458:	learn: 3.5797585	total: 347ms	remaining: 410ms
# 459:	learn: 3.5433673	total: 349ms	remaining: 409ms
# 460:	learn: 3.5080677	total: 349ms	remaining: 408ms
# 461:	learn: 3.4738272	total: 350ms	remaining: 408ms
# 462:	learn: 3.4406138	total: 351ms	remaining: 407ms
# 463:	learn: 3.4083969	total: 352ms	remaining: 406ms
# 464:	learn: 3.3771465	total: 352ms	remaining: 405ms
# 465:	learn: 3.3468336	total: 353ms	remaining: 405ms
# 466:	learn: 3.3380318	total: 354ms	remaining: 404ms
# 467:	learn: 3.3086840	total: 355ms	remaining: 403ms
# 468:	learn: 3.2802166	total: 356ms	remaining: 403ms
# 469:	learn: 3.2526032	total: 356ms	remaining: 402ms
# 470:	learn: 3.2258183	total: 357ms	remaining: 401ms
# 471:	learn: 3.1998368	total: 358ms	remaining: 400ms
# 472:	learn: 3.1746349	total: 358ms	remaining: 399ms
# 473:	learn: 3.1501909	total: 359ms	remaining: 398ms
# 474:	learn: 3.0909782	total: 360ms	remaining: 398ms
# 475:	learn: 3.0702662	total: 360ms	remaining: 397ms
# 476:	learn: 3.0152958	total: 361ms	remaining: 396ms
# 477:	learn: 3.0057498	total: 362ms	remaining: 395ms
# 478:	learn: 2.9843306	total: 363ms	remaining: 395ms
# 479:	learn: 2.9760976	total: 364ms	remaining: 394ms
# 480:	learn: 2.9639811	total: 364ms	remaining: 393ms
# 481:	learn: 2.9605157	total: 365ms	remaining: 392ms
# 482:	learn: 2.9536587	total: 366ms	remaining: 392ms
# 483:	learn: 2.8990631	total: 367ms	remaining: 391ms
# 484:	learn: 2.8762370	total: 368ms	remaining: 391ms
# 485:	learn: 2.8249582	total: 369ms	remaining: 390ms
# 486:	learn: 2.8215661	total: 369ms	remaining: 389ms
# 487:	learn: 2.8138615	total: 370ms	remaining: 388ms
# 488:	learn: 2.8112485	total: 371ms	remaining: 388ms
# 489:	learn: 2.7912148	total: 372ms	remaining: 387ms
# 490:	learn: 2.7720383	total: 372ms	remaining: 386ms
# 491:	learn: 2.7539133	total: 373ms	remaining: 385ms
# 492:	learn: 2.7491598	total: 374ms	remaining: 385ms
# 493:	learn: 2.6793779	total: 375ms	remaining: 384ms
# 494:	learn: 2.6537577	total: 376ms	remaining: 384ms
# 495:	learn: 2.6474139	total: 377ms	remaining: 383ms
# 496:	learn: 2.5923373	total: 378ms	remaining: 383ms
# 497:	learn: 2.5451956	total: 379ms	remaining: 382ms
# 498:	learn: 2.5407649	total: 379ms	remaining: 381ms
# 499:	learn: 2.5347889	total: 380ms	remaining: 380ms
# 500:	learn: 2.4648251	total: 380ms	remaining: 379ms
# 501:	learn: 2.4158580	total: 381ms	remaining: 378ms
# 502:	learn: 2.4128328	total: 381ms	remaining: 377ms
# 503:	learn: 2.4101011	total: 382ms	remaining: 376ms
# 504:	learn: 2.4067221	total: 383ms	remaining: 375ms
# 505:	learn: 2.3874692	total: 383ms	remaining: 374ms
# 506:	learn: 2.3856229	total: 384ms	remaining: 373ms
# 507:	learn: 2.3838290	total: 384ms	remaining: 372ms
# 508:	learn: 2.3809891	total: 385ms	remaining: 371ms
# 509:	learn: 2.3729549	total: 385ms	remaining: 370ms
# 510:	learn: 2.3651652	total: 386ms	remaining: 369ms
# 511:	learn: 2.3617340	total: 387ms	remaining: 368ms
# 512:	learn: 2.3561644	total: 387ms	remaining: 368ms
# 513:	learn: 2.3483159	total: 388ms	remaining: 367ms
# 514:	learn: 2.3333662	total: 389ms	remaining: 366ms
# 515:	learn: 2.3185560	total: 390ms	remaining: 365ms
# 516:	learn: 2.3000056	total: 390ms	remaining: 365ms
# 517:	learn: 2.2859339	total: 391ms	remaining: 364ms
# 518:	learn: 2.2840805	total: 392ms	remaining: 363ms
# 519:	learn: 2.2277394	total: 392ms	remaining: 362ms
# 520:	learn: 2.2258708	total: 393ms	remaining: 361ms
# 521:	learn: 2.2120861	total: 394ms	remaining: 361ms
# 522:	learn: 2.1888396	total: 395ms	remaining: 360ms
# 523:	learn: 2.1662603	total: 395ms	remaining: 359ms
# 524:	learn: 2.1632474	total: 396ms	remaining: 358ms
# 525:	learn: 2.1593462	total: 397ms	remaining: 357ms
# 526:	learn: 2.1171285	total: 397ms	remaining: 356ms
# 527:	learn: 2.0761821	total: 398ms	remaining: 356ms
# 528:	learn: 2.0454553	total: 398ms	remaining: 355ms
# 529:	learn: 2.0056713	total: 399ms	remaining: 354ms
# 530:	learn: 1.9670920	total: 400ms	remaining: 353ms
# 531:	learn: 1.9498107	total: 400ms	remaining: 352ms
# 532:	learn: 1.9491788	total: 401ms	remaining: 351ms
# 533:	learn: 1.9486217	total: 401ms	remaining: 350ms
# 534:	learn: 1.9101153	total: 402ms	remaining: 349ms
# 535:	learn: 1.8626941	total: 403ms	remaining: 348ms
# 536:	learn: 1.8514088	total: 403ms	remaining: 348ms
# 537:	learn: 1.8097128	total: 404ms	remaining: 347ms
# 538:	learn: 1.7979600	total: 404ms	remaining: 346ms
# 539:	learn: 1.7942090	total: 405ms	remaining: 345ms
# 540:	learn: 1.7923476	total: 406ms	remaining: 344ms
# 541:	learn: 1.7908920	total: 407ms	remaining: 344ms
# 542:	learn: 1.7884010	total: 408ms	remaining: 343ms
# 543:	learn: 1.7445636	total: 409ms	remaining: 343ms
# 544:	learn: 1.7400834	total: 410ms	remaining: 342ms
# 545:	learn: 1.7264702	total: 411ms	remaining: 342ms
# 546:	learn: 1.7239131	total: 412ms	remaining: 341ms
# 547:	learn: 1.7214328	total: 412ms	remaining: 340ms
# 548:	learn: 1.7197344	total: 413ms	remaining: 339ms
# 549:	learn: 1.7051121	total: 414ms	remaining: 339ms
# 550:	learn: 1.6909284	total: 415ms	remaining: 338ms
# 551:	learn: 1.6775079	total: 416ms	remaining: 337ms
# 552:	learn: 1.6417417	total: 417ms	remaining: 337ms
# 553:	learn: 1.6300820	total: 418ms	remaining: 336ms
# 554:	learn: 1.6220667	total: 418ms	remaining: 335ms
# 555:	learn: 1.5894812	total: 419ms	remaining: 335ms
# 556:	learn: 1.5587192	total: 420ms	remaining: 334ms
# 557:	learn: 1.5580197	total: 421ms	remaining: 334ms
# 558:	learn: 1.5528450	total: 422ms	remaining: 333ms
# 559:	learn: 1.5513570	total: 422ms	remaining: 332ms
# 560:	learn: 1.5495879	total: 423ms	remaining: 331ms
# 561:	learn: 1.5483473	total: 424ms	remaining: 331ms
# 562:	learn: 1.5182639	total: 425ms	remaining: 330ms
# 563:	learn: 1.4821840	total: 426ms	remaining: 329ms
# 564:	learn: 1.4539913	total: 427ms	remaining: 329ms
# 565:	learn: 1.4198355	total: 428ms	remaining: 328ms
# 566:	learn: 1.4181422	total: 428ms	remaining: 327ms
# 567:	learn: 1.4028938	total: 429ms	remaining: 326ms
# 568:	learn: 1.3882691	total: 430ms	remaining: 325ms
# 569:	learn: 1.3739277	total: 431ms	remaining: 325ms
# 570:	learn: 1.3689950	total: 432ms	remaining: 324ms
# 571:	learn: 1.3641919	total: 432ms	remaining: 323ms
# 572:	learn: 1.3600482	total: 433ms	remaining: 323ms
# 573:	learn: 1.3504733	total: 434ms	remaining: 322ms
# 574:	learn: 1.3399052	total: 434ms	remaining: 321ms
# 575:	learn: 1.3067084	total: 435ms	remaining: 320ms
# 576:	learn: 1.2964349	total: 436ms	remaining: 320ms
# 577:	learn: 1.2871957	total: 437ms	remaining: 319ms
# 578:	learn: 1.2839236	total: 437ms	remaining: 318ms
# 579:	learn: 1.2766019	total: 438ms	remaining: 317ms
# 580:	learn: 1.2760870	total: 439ms	remaining: 316ms
# 581:	learn: 1.2754566	total: 440ms	remaining: 316ms
# 582:	learn: 1.2745419	total: 440ms	remaining: 315ms
# 583:	learn: 1.2738791	total: 441ms	remaining: 314ms
# 584:	learn: 1.2734098	total: 442ms	remaining: 314ms
# 585:	learn: 1.2699553	total: 443ms	remaining: 313ms
# 586:	learn: 1.2694366	total: 443ms	remaining: 312ms
# 587:	learn: 1.2685003	total: 444ms	remaining: 311ms
# 588:	learn: 1.2682212	total: 445ms	remaining: 310ms
# 589:	learn: 1.2678482	total: 445ms	remaining: 310ms
# 590:	learn: 1.2676605	total: 446ms	remaining: 309ms
# 591:	learn: 1.2674962	total: 447ms	remaining: 308ms
# 592:	learn: 1.2618527	total: 447ms	remaining: 307ms
# 593:	learn: 1.2564097	total: 448ms	remaining: 306ms
# 594:	learn: 1.2562214	total: 449ms	remaining: 305ms
# 595:	learn: 1.2309863	total: 450ms	remaining: 305ms
# 596:	learn: 1.2070649	total: 450ms	remaining: 304ms
# 597:	learn: 1.2067858	total: 451ms	remaining: 303ms
# 598:	learn: 1.1833655	total: 452ms	remaining: 302ms
# 599:	learn: 1.1830081	total: 452ms	remaining: 302ms
# 600:	learn: 1.1775673	total: 453ms	remaining: 301ms
# 601:	learn: 1.1749991	total: 454ms	remaining: 300ms
# 602:	learn: 1.1656942	total: 454ms	remaining: 299ms
# 603:	learn: 1.1624547	total: 455ms	remaining: 298ms
# 604:	learn: 1.1563458	total: 456ms	remaining: 298ms
# 605:	learn: 1.1557233	total: 457ms	remaining: 297ms
# 606:	learn: 1.1325914	total: 457ms	remaining: 296ms
# 607:	learn: 1.1092492	total: 458ms	remaining: 295ms
# 608:	learn: 1.1007272	total: 459ms	remaining: 295ms
# 609:	learn: 1.0968440	total: 460ms	remaining: 294ms
# 610:	learn: 1.0943066	total: 461ms	remaining: 293ms
# 611:	learn: 1.0924013	total: 463ms	remaining: 293ms
# 612:	learn: 1.0912490	total: 463ms	remaining: 292ms
# 613:	learn: 1.0906109	total: 464ms	remaining: 292ms
# 614:	learn: 1.0898921	total: 465ms	remaining: 291ms
# 615:	learn: 1.0894519	total: 466ms	remaining: 290ms
# 616:	learn: 1.0886435	total: 466ms	remaining: 289ms
# 617:	learn: 1.0600427	total: 467ms	remaining: 289ms
# 618:	learn: 1.0583917	total: 468ms	remaining: 288ms
# 619:	learn: 1.0581612	total: 468ms	remaining: 287ms
# 620:	learn: 1.0578926	total: 469ms	remaining: 286ms
# 621:	learn: 1.0521949	total: 470ms	remaining: 286ms
# 622:	learn: 1.0518857	total: 471ms	remaining: 285ms
# 623:	learn: 1.0464723	total: 471ms	remaining: 284ms
# 624:	learn: 1.0453907	total: 472ms	remaining: 283ms
# 625:	learn: 1.0444587	total: 473ms	remaining: 282ms
# 626:	learn: 1.0396281	total: 474ms	remaining: 282ms
# 627:	learn: 1.0392817	total: 474ms	remaining: 281ms
# 628:	learn: 1.0390047	total: 475ms	remaining: 280ms
# 629:	learn: 1.0384455	total: 476ms	remaining: 279ms
# 630:	learn: 1.0179343	total: 477ms	remaining: 279ms
# 631:	learn: 1.0153720	total: 477ms	remaining: 278ms
# 632:	learn: 0.9933048	total: 478ms	remaining: 277ms
# 633:	learn: 0.9718996	total: 479ms	remaining: 276ms
# 634:	learn: 0.9511366	total: 479ms	remaining: 276ms
# 635:	learn: 0.9310000	total: 480ms	remaining: 275ms
# 636:	learn: 0.9217267	total: 481ms	remaining: 274ms
# 637:	learn: 0.9149202	total: 482ms	remaining: 273ms
# 638:	learn: 0.9125570	total: 483ms	remaining: 273ms
# 639:	learn: 0.9122486	total: 483ms	remaining: 272ms
# 640:	learn: 0.8904899	total: 484ms	remaining: 271ms
# 641:	learn: 0.8866339	total: 485ms	remaining: 270ms
# 642:	learn: 0.8692472	total: 486ms	remaining: 270ms
# 643:	learn: 0.8609315	total: 486ms	remaining: 269ms
# 644:	learn: 0.8585749	total: 487ms	remaining: 268ms
# 645:	learn: 0.8505780	total: 488ms	remaining: 267ms
# 646:	learn: 0.8428210	total: 489ms	remaining: 267ms
# 647:	learn: 0.8352972	total: 489ms	remaining: 266ms
# 648:	learn: 0.8332473	total: 490ms	remaining: 265ms
# 649:	learn: 0.8275324	total: 491ms	remaining: 264ms
# 650:	learn: 0.8269535	total: 492ms	remaining: 264ms
# 651:	learn: 0.8266859	total: 492ms	remaining: 263ms
# 652:	learn: 0.8100828	total: 493ms	remaining: 262ms
# 653:	learn: 0.8076294	total: 494ms	remaining: 261ms
# 654:	learn: 0.7902736	total: 495ms	remaining: 260ms
# 655:	learn: 0.7898117	total: 495ms	remaining: 260ms
# 656:	learn: 0.7856211	total: 496ms	remaining: 259ms
# 657:	learn: 0.7813246	total: 497ms	remaining: 258ms
# 658:	learn: 0.7806242	total: 498ms	remaining: 258ms
# 659:	learn: 0.7802009	total: 499ms	remaining: 257ms
# 660:	learn: 0.7745998	total: 499ms	remaining: 256ms
# 661:	learn: 0.7733877	total: 500ms	remaining: 255ms
# 662:	learn: 0.7730928	total: 501ms	remaining: 255ms
# 663:	learn: 0.7693976	total: 501ms	remaining: 254ms
# 664:	learn: 0.7652932	total: 502ms	remaining: 253ms
# 665:	learn: 0.7602596	total: 503ms	remaining: 252ms
# 666:	learn: 0.7558130	total: 504ms	remaining: 252ms
# 667:	learn: 0.7402319	total: 505ms	remaining: 251ms
# 668:	learn: 0.7218143	total: 506ms	remaining: 250ms
# 669:	learn: 0.7215007	total: 506ms	remaining: 249ms
# 670:	learn: 0.7211969	total: 507ms	remaining: 249ms
# 671:	learn: 0.7176699	total: 508ms	remaining: 248ms
# 672:	learn: 0.7175500	total: 508ms	remaining: 247ms
# 673:	learn: 0.7172087	total: 509ms	remaining: 246ms
# 674:	learn: 0.7160698	total: 510ms	remaining: 246ms
# 675:	learn: 0.7159481	total: 511ms	remaining: 245ms
# 676:	learn: 0.6976039	total: 512ms	remaining: 244ms
# 677:	learn: 0.6955290	total: 512ms	remaining: 243ms
# 678:	learn: 0.6949054	total: 513ms	remaining: 243ms
# 679:	learn: 0.6946050	total: 514ms	remaining: 242ms
# 680:	learn: 0.6914530	total: 515ms	remaining: 241ms
# 681:	learn: 0.6912490	total: 515ms	remaining: 240ms
# 682:	learn: 0.6754779	total: 516ms	remaining: 240ms
# 683:	learn: 0.6615114	total: 517ms	remaining: 239ms
# 684:	learn: 0.6478555	total: 518ms	remaining: 238ms
# 685:	learn: 0.6439198	total: 518ms	remaining: 237ms
# 686:	learn: 0.6437178	total: 519ms	remaining: 236ms
# 687:	learn: 0.6253823	total: 520ms	remaining: 236ms
# 688:	learn: 0.6087972	total: 521ms	remaining: 235ms
# 689:	learn: 0.6077290	total: 521ms	remaining: 234ms
# 690:	learn: 0.6075526	total: 522ms	remaining: 233ms
# 691:	learn: 0.5936394	total: 523ms	remaining: 233ms
# 692:	learn: 0.5932007	total: 523ms	remaining: 232ms
# 693:	learn: 0.5928954	total: 524ms	remaining: 231ms
# 694:	learn: 0.5924189	total: 525ms	remaining: 230ms
# 695:	learn: 0.5919568	total: 525ms	remaining: 229ms
# 696:	learn: 0.5892646	total: 526ms	remaining: 229ms
# 697:	learn: 0.5866533	total: 527ms	remaining: 228ms
# 698:	learn: 0.5853257	total: 527ms	remaining: 227ms
# 699:	learn: 0.5841398	total: 528ms	remaining: 226ms
# 700:	learn: 0.5840471	total: 529ms	remaining: 226ms
# 701:	learn: 0.5825886	total: 529ms	remaining: 225ms
# 702:	learn: 0.5797722	total: 530ms	remaining: 224ms
# 703:	learn: 0.5784919	total: 531ms	remaining: 223ms
# 704:	learn: 0.5750612	total: 532ms	remaining: 223ms
# 705:	learn: 0.5732012	total: 533ms	remaining: 222ms
# 706:	learn: 0.5592818	total: 534ms	remaining: 221ms
# 707:	learn: 0.5452499	total: 534ms	remaining: 220ms
# 708:	learn: 0.5441061	total: 535ms	remaining: 220ms
# 709:	learn: 0.5414760	total: 536ms	remaining: 219ms
# 710:	learn: 0.5390165	total: 536ms	remaining: 218ms
# 711:	learn: 0.5387144	total: 537ms	remaining: 217ms
# 712:	learn: 0.5385419	total: 538ms	remaining: 217ms
# 713:	learn: 0.5383320	total: 539ms	remaining: 216ms
# 714:	learn: 0.5369812	total: 540ms	remaining: 215ms
# 715:	learn: 0.5367881	total: 540ms	remaining: 214ms
# 716:	learn: 0.5254196	total: 541ms	remaining: 214ms
# 717:	learn: 0.5146039	total: 542ms	remaining: 213ms
# 718:	learn: 0.5121894	total: 543ms	remaining: 212ms
# 719:	learn: 0.5109138	total: 543ms	remaining: 211ms
# 720:	learn: 0.5004909	total: 544ms	remaining: 211ms
# 721:	learn: 0.4983520	total: 545ms	remaining: 210ms
# 722:	learn: 0.4962389	total: 546ms	remaining: 209ms
# 723:	learn: 0.4942009	total: 546ms	remaining: 208ms
# 724:	learn: 0.4940069	total: 547ms	remaining: 208ms
# 725:	learn: 0.4920527	total: 548ms	remaining: 207ms
# 726:	learn: 0.4800638	total: 548ms	remaining: 206ms
# 727:	learn: 0.4781218	total: 549ms	remaining: 205ms
# 728:	learn: 0.4736200	total: 550ms	remaining: 204ms
# 729:	learn: 0.4628764	total: 551ms	remaining: 204ms
# 730:	learn: 0.4612185	total: 551ms	remaining: 203ms
# 731:	learn: 0.4603931	total: 552ms	remaining: 202ms
# 732:	learn: 0.4581963	total: 553ms	remaining: 201ms
# 733:	learn: 0.4572947	total: 553ms	remaining: 200ms
# 734:	learn: 0.4565660	total: 554ms	remaining: 200ms
# 735:	learn: 0.4556337	total: 555ms	remaining: 199ms
# 736:	learn: 0.4541974	total: 556ms	remaining: 198ms
# 737:	learn: 0.4506149	total: 556ms	remaining: 198ms
# 738:	learn: 0.4490953	total: 557ms	remaining: 197ms
# 739:	learn: 0.4477896	total: 558ms	remaining: 196ms
# 740:	learn: 0.4476106	total: 559ms	remaining: 195ms
# 741:	learn: 0.4462464	total: 560ms	remaining: 195ms
# 742:	learn: 0.4455354	total: 561ms	remaining: 194ms
# 743:	learn: 0.4430713	total: 562ms	remaining: 193ms
# 744:	learn: 0.4315720	total: 563ms	remaining: 193ms
# 745:	learn: 0.4307302	total: 563ms	remaining: 192ms
# 746:	learn: 0.4306141	total: 564ms	remaining: 191ms
# 747:	learn: 0.4279972	total: 565ms	remaining: 190ms
# 748:	learn: 0.4272050	total: 566ms	remaining: 190ms
# 749:	learn: 0.4251830	total: 567ms	remaining: 189ms
# 750:	learn: 0.4250934	total: 567ms	remaining: 188ms
# 751:	learn: 0.4231630	total: 568ms	remaining: 187ms
# 752:	learn: 0.4230093	total: 568ms	remaining: 186ms
# 753:	learn: 0.4205203	total: 569ms	remaining: 186ms
# 754:	learn: 0.4197863	total: 570ms	remaining: 185ms
# 755:	learn: 0.4196502	total: 570ms	remaining: 184ms
# 756:	learn: 0.4194341	total: 571ms	remaining: 183ms
# 757:	learn: 0.4079376	total: 572ms	remaining: 183ms
# 758:	learn: 0.4076233	total: 572ms	remaining: 182ms
# 759:	learn: 0.3960421	total: 573ms	remaining: 181ms
# 760:	learn: 0.3848098	total: 574ms	remaining: 180ms
# 761:	learn: 0.3748306	total: 574ms	remaining: 179ms
# 762:	learn: 0.3732330	total: 575ms	remaining: 179ms
# 763:	learn: 0.3726728	total: 575ms	remaining: 178ms
# 764:	learn: 0.3724283	total: 576ms	remaining: 177ms
# 765:	learn: 0.3721961	total: 576ms	remaining: 176ms
# 766:	learn: 0.3720099	total: 577ms	remaining: 175ms
# 767:	learn: 0.3699909	total: 578ms	remaining: 175ms
# 768:	learn: 0.3691856	total: 579ms	remaining: 174ms
# 769:	learn: 0.3610197	total: 579ms	remaining: 173ms
# 770:	learn: 0.3585238	total: 580ms	remaining: 172ms
# 771:	learn: 0.3583673	total: 581ms	remaining: 171ms
# 772:	learn: 0.3582290	total: 582ms	remaining: 171ms
# 773:	learn: 0.3485289	total: 582ms	remaining: 170ms
# 774:	learn: 0.3391197	total: 583ms	remaining: 169ms
# 775:	learn: 0.3299928	total: 584ms	remaining: 168ms
# 776:	learn: 0.3211397	total: 584ms	remaining: 168ms
# 777:	learn: 0.3209522	total: 585ms	remaining: 167ms
# 778:	learn: 0.3208102	total: 586ms	remaining: 166ms
# 779:	learn: 0.3116232	total: 586ms	remaining: 165ms
# 780:	learn: 0.3036121	total: 587ms	remaining: 165ms
# 781:	learn: 0.2958921	total: 588ms	remaining: 164ms
# 782:	learn: 0.2957789	total: 588ms	remaining: 163ms
# 783:	learn: 0.2945062	total: 589ms	remaining: 162ms
# 784:	learn: 0.2940451	total: 590ms	remaining: 162ms
# 785:	learn: 0.2936643	total: 591ms	remaining: 161ms
# 786:	learn: 0.2935352	total: 592ms	remaining: 160ms
# 787:	learn: 0.2856465	total: 592ms	remaining: 159ms
# 788:	learn: 0.2855119	total: 593ms	remaining: 159ms
# 789:	learn: 0.2843587	total: 594ms	remaining: 158ms
# 790:	learn: 0.2832164	total: 595ms	remaining: 157ms
# 791:	learn: 0.2821101	total: 596ms	remaining: 156ms
# 792:	learn: 0.2820276	total: 597ms	remaining: 156ms
# 793:	learn: 0.2819816	total: 598ms	remaining: 155ms
# 794:	learn: 0.2738880	total: 598ms	remaining: 154ms
# 795:	learn: 0.2669237	total: 599ms	remaining: 154ms
# 796:	learn: 0.2667744	total: 600ms	remaining: 153ms
# 797:	learn: 0.2657211	total: 601ms	remaining: 152ms
# 798:	learn: 0.2586183	total: 602ms	remaining: 151ms
# 799:	learn: 0.2577193	total: 602ms	remaining: 151ms
# 800:	learn: 0.2575607	total: 603ms	remaining: 150ms
# 801:	learn: 0.2574725	total: 604ms	remaining: 149ms
# 802:	learn: 0.2560592	total: 605ms	remaining: 148ms
# 803:	learn: 0.2559250	total: 605ms	remaining: 148ms
# 804:	learn: 0.2558159	total: 606ms	remaining: 147ms
# 805:	learn: 0.2557573	total: 607ms	remaining: 146ms
# 806:	learn: 0.2556666	total: 608ms	remaining: 145ms
# 807:	learn: 0.2555786	total: 608ms	remaining: 145ms
# 808:	learn: 0.2554933	total: 609ms	remaining: 144ms
# 809:	learn: 0.2554106	total: 610ms	remaining: 143ms
# 810:	learn: 0.2553364	total: 611ms	remaining: 142ms
# 811:	learn: 0.2552424	total: 611ms	remaining: 142ms
# 812:	learn: 0.2551615	total: 612ms	remaining: 141ms
# 813:	learn: 0.2550864	total: 613ms	remaining: 140ms
# 814:	learn: 0.2550381	total: 614ms	remaining: 139ms
# 815:	learn: 0.2549977	total: 614ms	remaining: 139ms
# 816:	learn: 0.2549279	total: 615ms	remaining: 138ms
# 817:	learn: 0.2548033	total: 616ms	remaining: 137ms
# 818:	learn: 0.2538840	total: 617ms	remaining: 136ms
# 819:	learn: 0.2525041	total: 617ms	remaining: 135ms
# 820:	learn: 0.2511722	total: 618ms	remaining: 135ms
# 821:	learn: 0.2510784	total: 619ms	remaining: 134ms
# 822:	learn: 0.2510037	total: 619ms	remaining: 133ms
# 823:	learn: 0.2509216	total: 620ms	remaining: 132ms
# 824:	learn: 0.2508762	total: 621ms	remaining: 132ms
# 825:	learn: 0.2508041	total: 622ms	remaining: 131ms
# 826:	learn: 0.2500133	total: 622ms	remaining: 130ms
# 827:	learn: 0.2499360	total: 623ms	remaining: 129ms
# 828:	learn: 0.2491574	total: 624ms	remaining: 129ms
# 829:	learn: 0.2490971	total: 625ms	remaining: 128ms
# 830:	learn: 0.2487290	total: 626ms	remaining: 127ms
# 831:	learn: 0.2483735	total: 626ms	remaining: 126ms
# 832:	learn: 0.2476933	total: 627ms	remaining: 126ms
# 833:	learn: 0.2476489	total: 628ms	remaining: 125ms
# 834:	learn: 0.2472390	total: 629ms	remaining: 124ms
# 835:	learn: 0.2471755	total: 629ms	remaining: 123ms
# 836:	learn: 0.2471498	total: 630ms	remaining: 123ms
# 837:	learn: 0.2465033	total: 631ms	remaining: 122ms
# 838:	learn: 0.2464273	total: 632ms	remaining: 121ms
# 839:	learn: 0.2463499	total: 633ms	remaining: 121ms
# 840:	learn: 0.2463025	total: 634ms	remaining: 120ms
# 841:	learn: 0.2462524	total: 635ms	remaining: 119ms
# 842:	learn: 0.2462343	total: 636ms	remaining: 118ms
# 843:	learn: 0.2461719	total: 637ms	remaining: 118ms
# 844:	learn: 0.2460901	total: 638ms	remaining: 117ms
# 845:	learn: 0.2460473	total: 639ms	remaining: 116ms
# 846:	learn: 0.2456498	total: 640ms	remaining: 116ms
# 847:	learn: 0.2400040	total: 641ms	remaining: 115ms
# 848:	learn: 0.2396389	total: 641ms	remaining: 114ms
# 849:	learn: 0.2388732	total: 642ms	remaining: 113ms
# 850:	learn: 0.2328842	total: 643ms	remaining: 113ms
# 851:	learn: 0.2328280	total: 643ms	remaining: 112ms
# 852:	learn: 0.2324916	total: 644ms	remaining: 111ms
# 853:	learn: 0.2315917	total: 645ms	remaining: 110ms
# 854:	learn: 0.2303948	total: 646ms	remaining: 109ms
# 855:	learn: 0.2300275	total: 646ms	remaining: 109ms
# 856:	learn: 0.2299703	total: 647ms	remaining: 108ms
# 857:	learn: 0.2299047	total: 648ms	remaining: 107ms
# 858:	learn: 0.2298818	total: 649ms	remaining: 107ms
# 859:	learn: 0.2295372	total: 650ms	remaining: 106ms
# 860:	learn: 0.2236101	total: 651ms	remaining: 105ms
# 861:	learn: 0.2178607	total: 652ms	remaining: 104ms
# 862:	learn: 0.2122839	total: 653ms	remaining: 104ms
# 863:	learn: 0.2122449	total: 653ms	remaining: 103ms
# 864:	learn: 0.2122146	total: 654ms	remaining: 102ms
# 865:	learn: 0.2067982	total: 655ms	remaining: 101ms
# 866:	learn: 0.2067724	total: 656ms	remaining: 101ms
# 867:	learn: 0.2061333	total: 656ms	remaining: 99.8ms
# 868:	learn: 0.2055143	total: 657ms	remaining: 99ms
# 869:	learn: 0.2049273	total: 658ms	remaining: 98.3ms
# 870:	learn: 0.2043580	total: 659ms	remaining: 97.5ms
# 871:	learn: 0.2043198	total: 660ms	remaining: 96.8ms
# 872:	learn: 0.2042822	total: 660ms	remaining: 96.1ms
# 873:	learn: 0.2042680	total: 662ms	remaining: 95.4ms
# 874:	learn: 0.2042309	total: 662ms	remaining: 94.6ms
# 875:	learn: 0.2039482	total: 663ms	remaining: 93.8ms
# 876:	learn: 0.2039036	total: 664ms	remaining: 93.1ms
# 877:	learn: 0.2038604	total: 664ms	remaining: 92.3ms
# 878:	learn: 0.2038185	total: 665ms	remaining: 91.6ms
# 879:	learn: 0.2034907	total: 667ms	remaining: 90.9ms
# 880:	learn: 0.2034523	total: 667ms	remaining: 90.2ms
# 881:	learn: 0.2034165	total: 668ms	remaining: 89.4ms
# 882:	learn: 0.2033819	total: 669ms	remaining: 88.7ms
# 883:	learn: 0.2033527	total: 670ms	remaining: 87.9ms
# 884:	learn: 0.2033241	total: 672ms	remaining: 87.3ms
# 885:	learn: 0.2032941	total: 673ms	remaining: 86.5ms
# 886:	learn: 0.2032617	total: 673ms	remaining: 85.8ms
# 887:	learn: 0.2032303	total: 674ms	remaining: 85ms
# 888:	learn: 0.2031907	total: 675ms	remaining: 84.2ms
# 889:	learn: 0.2028302	total: 675ms	remaining: 83.5ms
# 890:	learn: 0.1976619	total: 676ms	remaining: 82.7ms
# 891:	learn: 0.1976386	total: 677ms	remaining: 82ms
# 892:	learn: 0.1976208	total: 678ms	remaining: 81.2ms
# 893:	learn: 0.1966722	total: 679ms	remaining: 80.5ms
# 894:	learn: 0.1966383	total: 679ms	remaining: 79.7ms
# 895:	learn: 0.1966055	total: 680ms	remaining: 78.9ms
# 896:	learn: 0.1965738	total: 681ms	remaining: 78.2ms
# 897:	learn: 0.1965476	total: 682ms	remaining: 77.4ms
# 898:	learn: 0.1960299	total: 683ms	remaining: 76.7ms
# 899:	learn: 0.1910408	total: 684ms	remaining: 76ms
# 900:	learn: 0.1862013	total: 685ms	remaining: 75.2ms
# 901:	learn: 0.1857452	total: 685ms	remaining: 74.5ms
# 902:	learn: 0.1857063	total: 686ms	remaining: 73.7ms
# 903:	learn: 0.1856767	total: 687ms	remaining: 72.9ms
# 904:	learn: 0.1856438	total: 688ms	remaining: 72.2ms
# 905:	learn: 0.1850939	total: 688ms	remaining: 71.4ms
# 906:	learn: 0.1804275	total: 689ms	remaining: 70.7ms
# 907:	learn: 0.1803878	total: 690ms	remaining: 69.9ms
# 908:	learn: 0.1797783	total: 690ms	remaining: 69.1ms
# 909:	learn: 0.1791871	total: 691ms	remaining: 68.4ms
# 910:	learn: 0.1786137	total: 692ms	remaining: 67.6ms
# 911:	learn: 0.1784126	total: 693ms	remaining: 66.8ms
# 912:	learn: 0.1742810	total: 693ms	remaining: 66.1ms
# 913:	learn: 0.1702746	total: 694ms	remaining: 65.3ms
# 914:	learn: 0.1702353	total: 695ms	remaining: 64.6ms
# 915:	learn: 0.1701833	total: 696ms	remaining: 63.9ms
# 916:	learn: 0.1701553	total: 697ms	remaining: 63.1ms
# 917:	learn: 0.1701182	total: 698ms	remaining: 62.3ms
# 918:	learn: 0.1700972	total: 698ms	remaining: 61.6ms
# 919:	learn: 0.1696377	total: 699ms	remaining: 60.8ms
# 920:	learn: 0.1657663	total: 700ms	remaining: 60.1ms
# 921:	learn: 0.1657389	total: 701ms	remaining: 59.3ms
# 922:	learn: 0.1657114	total: 702ms	remaining: 58.5ms
# 923:	learn: 0.1656972	total: 702ms	remaining: 57.8ms
# 924:	learn: 0.1656530	total: 703ms	remaining: 57ms
# 925:	learn: 0.1656238	total: 704ms	remaining: 56.3ms
# 926:	learn: 0.1656076	total: 705ms	remaining: 55.5ms
# 927:	learn: 0.1614347	total: 705ms	remaining: 54.7ms
# 928:	learn: 0.1614090	total: 706ms	remaining: 54ms
# 929:	learn: 0.1613765	total: 707ms	remaining: 53.2ms
# 930:	learn: 0.1613407	total: 708ms	remaining: 52.5ms
# 931:	learn: 0.1572978	total: 708ms	remaining: 51.7ms
# 932:	learn: 0.1568912	total: 709ms	remaining: 50.9ms
# 933:	learn: 0.1568755	total: 710ms	remaining: 50.2ms
# 934:	learn: 0.1533552	total: 711ms	remaining: 49.4ms
# 935:	learn: 0.1533405	total: 712ms	remaining: 48.7ms
# 936:	learn: 0.1533127	total: 713ms	remaining: 47.9ms
# 937:	learn: 0.1532857	total: 714ms	remaining: 47.2ms
# 938:	learn: 0.1532581	total: 715ms	remaining: 46.4ms
# 939:	learn: 0.1531554	total: 716ms	remaining: 45.7ms
# 940:	learn: 0.1531251	total: 716ms	remaining: 44.9ms
# 941:	learn: 0.1530944	total: 717ms	remaining: 44.1ms
# 942:	learn: 0.1529224	total: 718ms	remaining: 43.4ms
# 943:	learn: 0.1528483	total: 718ms	remaining: 42.6ms
# 944:	learn: 0.1528174	total: 719ms	remaining: 41.8ms
# 945:	learn: 0.1527753	total: 720ms	remaining: 41.1ms
# 946:	learn: 0.1527701	total: 721ms	remaining: 40.3ms
# 947:	learn: 0.1527636	total: 722ms	remaining: 39.6ms
# 948:	learn: 0.1527575	total: 723ms	remaining: 38.8ms
# 949:	learn: 0.1527431	total: 723ms	remaining: 38.1ms
# 950:	learn: 0.1523674	total: 724ms	remaining: 37.3ms
# 951:	learn: 0.1523484	total: 725ms	remaining: 36.5ms
# 952:	learn: 0.1523303	total: 725ms	remaining: 35.8ms
# 953:	learn: 0.1523036	total: 726ms	remaining: 35ms
# 954:	learn: 0.1519387	total: 727ms	remaining: 34.2ms
# 955:	learn: 0.1515816	total: 728ms	remaining: 33.5ms
# 956:	learn: 0.1511878	total: 729ms	remaining: 32.7ms
# 957:	learn: 0.1511596	total: 729ms	remaining: 32ms
# 958:	learn: 0.1477211	total: 730ms	remaining: 31.2ms
# 959:	learn: 0.1473272	total: 731ms	remaining: 30.5ms
# 960:	learn: 0.1468888	total: 732ms	remaining: 29.7ms
# 961:	learn: 0.1468729	total: 733ms	remaining: 28.9ms
# 962:	learn: 0.1468419	total: 733ms	remaining: 28.2ms
# 963:	learn: 0.1464667	total: 734ms	remaining: 27.4ms
# 964:	learn: 0.1459661	total: 735ms	remaining: 26.6ms
# 965:	learn: 0.1459407	total: 735ms	remaining: 25.9ms
# 966:	learn: 0.1426045	total: 736ms	remaining: 25.1ms
# 967:	learn: 0.1423021	total: 737ms	remaining: 24.4ms
# 968:	learn: 0.1390693	total: 738ms	remaining: 23.6ms
# 969:	learn: 0.1383213	total: 738ms	remaining: 22.8ms
# 970:	learn: 0.1349445	total: 739ms	remaining: 22.1ms
# 971:	learn: 0.1314774	total: 740ms	remaining: 21.3ms
# 972:	learn: 0.1309708	total: 741ms	remaining: 20.5ms
# 973:	learn: 0.1309362	total: 741ms	remaining: 19.8ms
# 974:	learn: 0.1309049	total: 742ms	remaining: 19ms
# 975:	learn: 0.1308660	total: 743ms	remaining: 18.3ms
# 976:	learn: 0.1279430	total: 743ms	remaining: 17.5ms
# 977:	learn: 0.1279217	total: 744ms	remaining: 16.7ms
# 978:	learn: 0.1278856	total: 746ms	remaining: 16ms
# 979:	learn: 0.1278681	total: 746ms	remaining: 15.2ms
# 980:	learn: 0.1276009	total: 747ms	remaining: 14.5ms
# 981:	learn: 0.1275496	total: 748ms	remaining: 13.7ms
# 982:	learn: 0.1272864	total: 748ms	remaining: 12.9ms
# 983:	learn: 0.1272509	total: 749ms	remaining: 12.2ms
# 984:	learn: 0.1272188	total: 750ms	remaining: 11.4ms
# 985:	learn: 0.1271912	total: 751ms	remaining: 10.7ms
# 986:	learn: 0.1242269	total: 752ms	remaining: 9.9ms
# 987:	learn: 0.1213649	total: 753ms	remaining: 9.15ms
# 988:	learn: 0.1212369	total: 754ms	remaining: 8.38ms
# 989:	learn: 0.1211162	total: 755ms	remaining: 7.62ms
# 990:	learn: 0.1208752	total: 755ms	remaining: 6.86ms
# 991:	learn: 0.1208627	total: 756ms	remaining: 6.1ms
# 992:	learn: 0.1208431	total: 757ms	remaining: 5.33ms
# 993:	learn: 0.1208208	total: 758ms	remaining: 4.58ms
# 994:	learn: 0.1208031	total: 759ms	remaining: 3.81ms
# 995:	learn: 0.1207876	total: 760ms	remaining: 3.05ms
# 996:	learn: 0.1207666	total: 761ms	remaining: 2.29ms
# 997:	learn: 0.1207546	total: 762ms	remaining: 1.53ms
# 998:	learn: 0.1207462	total: 763ms	remaining: 763us
# 999:	learn: 0.1207371	total: 763ms	remaining: 0us

# %%
cb_up.get_all_params()
# Out:
# {'nan_mode': 'Min',
#  'eval_metric': 'MAE',
#  'iterations': 1000,
#  'sampling_frequency': 'PerTree',
#  'leaf_estimation_method': 'Exact',
#  'grow_policy': 'SymmetricTree',
#  'penalties_coefficient': 1,
#  'boosting_type': 'Plain',
#  'model_shrink_mode': 'Constant',
#  'feature_border_type': 'GreedyLogSum',
#  'bayesian_matrix_reg': 0.10000000149011612,
#  'l2_leaf_reg': 3,
#  'random_strength': 1,
#  'rsm': 1,
#  'boost_from_average': True,
#  'model_size_reg': 0.5,
#  'pool_metainfo_options': {'tags': {}},
#  'subsample': 1,
#  'use_best_model': False,
#  'random_seed': 2021,
#  'depth': 6,
#  'posterior_sampling': False,
#  'border_count': 254,
#  'classes_count': 0,
#  'auto_class_weights': 'None',
#  'sparse_features_conflict_fraction': 0,
#  'leaf_estimation_backtracking': 'AnyImprovement',
#  'best_model_min_trees': 1,
#  'model_shrink_rate': 0,
#  'min_data_in_leaf': 1,
#  'loss_function': 'MAE',
#  'learning_rate': 0.029999999329447743,
#  'score_function': 'Cosine',
#  'task_type': 'CPU',
#  'leaf_estimation_iterations': 1,
#  'bootstrap_type': 'MVS',
#  'max_leaves': 64}

# %%
ig, axes = plt.subplots(8,5, figsize= (16,32))

i = 0
for f in col:
    c = i % 5
    r = i // 5
    
    axes[r,c].hist(x = f, bins =30, data = train_up)
    plt.xlabel(f)
    i += 1
plt.show()

# %%
X_test
# Out:
#     총세대수  공가수  지하철역  버스정류장  단지내주차면수           연면적          위도         경도  \
# 0   1354    9   0.0      3     1216   3773.770000  126.887303  37.434649
# 1   1297   11   0.0      2     1112    361.789000  127.118208  37.400897
# 2   1974   15   0.0      6     1696     14.159000  127.114461  37.390596
# 3   1349   25   0.0      2     1098   5712.574000  126.723198  35.962854
# 4   1301   33   0.0      2     1101   6963.333000  129.164340  35.332524
# 5   1442   23   0.0      6     1225     28.000000  126.858872  35.171168
# 6   1138   25   0.0      5     1141   6054.620000  127.209118  37.725565
# 7   1008   15   1.0      4     1035   1222.296000  129.031160  35.338206
# 8    981    9   0.0      2      989   4020.626000  127.166664  37.282454
# 9   1267   26   0.0     12     1280   9058.122000  128.819509  35.167982
# 10  1175   14   0.0      4     1024      9.000000  127.741763  37.848425
# 11  1414   20   0.0      4     1307   4444.121102  126.937377  35.953784
# 12  1385   25   0.0     14     1139   4715.370000  129.145822  35.378381
# 13  1147   17   0.0      1     1222   5061.600000  126.779513  35.146391
# 14  1331   17   1.0      6     1204     20.250000  127.116691  37.645357
# 15  1191   33   0.0     15     1052     15.550000  127.097937  37.003065
# 16  1390   36   0.0      2     1216  24779.120000  128.449987  35.690526
# 17  1278   36   0.0      1     1014   4966.230000  127.545531  36.915738
# 18   963   16   0.0      6     1161   4144.247014  127.258542  37.004264
#
#     subway_dist  환승역 수  ...  행복주택  공공임대(분납)  공공분양  공공임대(50년)            임대료  \
# 0      0.015025      1  ...     0         0     0          0  245516.666667
# 1      0.009307      2  ...     0         0     0          0  292880.000000
# 2      0.005304      2  ...     0         0     0          0  293214.545455
# 3      0.538834      2  ...     0         0     0          0  138505.000000
# 4      0.083401      1  ...     0         0     0          0  185810.000000
# 5      0.022289      1  ...     0         0     0          0  126568.000000
# 6      0.080513      1  ...     0         0     0          0  183177.500000
# 7      0.004747      1  ...     0         0     0          0  228560.000000
# 8      0.019327      2  ...     0         0     0          0  229185.000000
# 9      0.080723      1  ...     0         0     0          0  172280.000000
# 10     0.023796      1  ...     0         0     0          0  124214.000000
# 11     0.369100      2  ...     0         0     0          0  120148.888889
# 12     0.107321      1  ...     0         0     0          0  140388.333333
# 13     0.014269      1  ...     0         0     0          0  131302.727273
# 14     0.010792      1  ...     0         0     0          0  290009.411765
# 15     0.017490      1  ...     0         0     0          0  253575.000000
# 16     0.115134      1  ...     0         0     0          0  199564.000000
# 17     0.349049      1  ...     0         0     0          0  169885.000000
# 18     0.158428      1  ...     0         0     0          0  536000.000000
#
#            임대보증금  대형전용면적  area_0  area_1  area_2
# 0   3.412500e+07       0       0       0       0
# 1   4.133450e+07       0       0       0       0
# 2   4.269218e+07       0       0       0       0
# 3   2.075800e+07       0       0       1       0
# 4   3.096867e+07       0       1       0       0
# 5   2.122280e+07       0       0       1       0
# 6   2.195700e+07       0       0       0       0
# 7   1.729875e+07       0       1       0       0
# 8   2.164733e+07       0       0       0       0
# 9   2.871360e+07       0       1       0       0
# 10  1.326540e+07       0       0       0       0
# 11  1.775611e+07       0       0       1       0
# 12  1.715567e+07       0       1       0       0
# 13  2.052455e+07       0       0       1       0
# 14  3.490641e+07       0       0       0       0
# 15  2.706900e+07       0       0       0       0
# 16  1.399920e+07       0       0       0       1
# 17  1.252600e+07       0       0       0       0
# 18  5.770000e+07       0       0       0       0
#
# [19 rows x 37 columns]

# %%
y_cat = pd.cut(y_train, 3, labels=range(3))
skf = StratifiedKFold(3)

preds = []
for tr_id, val_id in skf.split(X_train, y_cat) : 
    X_tr = X_train.iloc[tr_id]
    y_tr = y_train.iloc[tr_id]
    X_tr_val = X_train.iloc[val_id]
    y_tr_val = y_train.iloc[val_id]
    
    cb = CatBoostRegressor(random_state=2021).fit(X_tr, y_tr, verbose = 0)
    cb.predict(X_tr)
    pred = cb.predict(X_test)
    preds.append(pred)
pred_up = np.mean(preds, axis = 0)

# %%
pred_up
# Out:
# array([1271.26471551, 1250.70728414, 1616.40260568, 1078.33260732,
#         908.15561502, 1348.46320916, 1078.12760939, 1058.39067809,
#        1237.8545434 , 1191.46739434, 1043.97403471, 1137.28548873,
#        1086.82844029, 1149.03134943, 1242.56355098, 1025.21180988,
#         989.21605499,  935.33765103, 1316.86434649])

# %%
def get_pred():
    res_down = pd.DataFrame()
    res_down['code'] = test_down['단지코드'].values
    res_down['num'] = pred_down
    res_up = pd.DataFrame()
    res_up['code'] = test_up['단지코드'].values
    res_up['num'] = pred_up 
    res = pd.concat([res_down,res_up],axis=0).reset_index(drop=True)
    return res_down, res_up, res

# %% [markdown]
# ## 5. 기존 score와 비교 및 제출

# %%
def submit():
    res = get_pred()[2]
    res.loc[147,:] = ['C1327',0]
    res.loc[148,:] = ['C2335',0]
    res.loc[149,:] = ['C2675',0]
    return res

# %%
sub = submit()
sub.to_csv("result/0723_1.csv",index=False)

# %%
def score(mse):
    score = pd.read_csv("/Users/seungji/Downloads//MAE_"+str(mse)+".csv")
    score = pd.merge(score,get_pred()[2],on='code',how='inner')
    val = test_up['단지코드'].values
    score_up = score.loc[score['code'].isin(val),:]
    score_down = score.loc[-score['code'].isin(val),:] #y가 새롭게 예측
    mae = mean_absolute_error(score['num_x'],score['num_y'])
    mae_up = mean_absolute_error(score_up['num_x'],score_up['num_y'])
    mae_down = mean_absolute_error(score_down['num_x'],score_down['num_y'])
    print('전체 MAE : ',mae)
    print('큰 영역 MAE : ',mae_up)
    print('작은 영역 MAE : ',mae_down)
    return score

# %%
res2 = score(96)
# Out:
# 전체 MAE :  8.901914160372339
# 큰 영역 MAE :  68.87270429340678
# 작은 영역 MAE :  3.68594044175552e-14

# %%
res1 = score(98)
