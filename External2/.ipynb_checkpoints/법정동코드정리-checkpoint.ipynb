# %%
import pandas as pd
pd.options.display.float_format = '{:,.4f}'.format
pd.options.display.max_rows = 100
pd.options.display.max_columns = 40
import numpy as np
import os,random, math
from tqdm import tqdm
from copy import deepcopy
from collections import Counter

# Visualization
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
plt.rcParams['font.family'] = 'NanumGothic'
import platform
if platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
    rc('font', family='AppleGothic')

matplotlib.rcParams['axes.unicode_minus'] = False

# from dataprep.eda import plot, plot_correlation, plot_missing

import plotly 
import plotly.express as px
# from plotly import tools, subplots
# import plotly.offline as py
# py.init_notebook_mode(connected=True)
# from plotly.offline import init_notebook_mode, iplot
# import plotly.graph_objs as go
# import plotly.express as px

# Warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 법정동 정리

# %%
bjd = pd.read_csv("bupjeongdong.csv")

# %%
bjd
# Out:
#             법정동코드                  법정동명 폐지여부
# 0      1100000000                 서울특별시   존재
# 1      1111000000             서울특별시 종로구   존재
# 2      1111010100         서울특별시 종로구 청운동   존재
# 3      1111010200         서울특별시 종로구 신교동   존재
# 4      1111010300         서울특별시 종로구 궁정동   존재
# ...           ...                   ...  ...
# 46287  5013032022  제주특별자치도 서귀포시 표선면 하천리   존재
# 46288  5013032023  제주특별자치도 서귀포시 표선면 성읍리   존재
# 46289  5013032024  제주특별자치도 서귀포시 표선면 가시리   존재
# 46290  5013032025  제주특별자치도 서귀포시 표선면 세화리   존재
# 46291  5013032026  제주특별자치도 서귀포시 표선면 토산리   존재
#
# [46292 rows x 3 columns]

# %% [markdown]
# https://www.code.go.kr/stdcode/regCodeL.do

# %%
l = []
for c in bjd.법정동코드:
    l.append(len(str(c)))
pd.DataFrame(l).value_counts()
# Out:
# 10    46292
# dtype: int64

# %%
str(bjd.법정동코드[0])[:5]
# Out:
# '11000'

# %%
list(map(lambda x:str.split()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-388563f10857> in <module>
# ----> 1 list(map(lambda x:str.split()))
#
# TypeError: map() must have at least two arguments.

# %%
bjd["시군구"] = list(map(lambda x: str(x)[:5] , bjd.법정동코드))
bjd["법정동"] = list(map(lambda x: str(x)[5:] , bjd.법정동코드))

# %%
bjd
# Out:
#             법정동코드                  법정동명 폐지여부    시군구    법정동
# 0      1100000000                 서울특별시   존재  11000  00000
# 1      1111000000             서울특별시 종로구   존재  11110  00000
# 2      1111010100         서울특별시 종로구 청운동   존재  11110  10100
# 3      1111010200         서울특별시 종로구 신교동   존재  11110  10200
# 4      1111010300         서울특별시 종로구 궁정동   존재  11110  10300
# ...           ...                   ...  ...    ...    ...
# 46287  5013032022  제주특별자치도 서귀포시 표선면 하천리   존재  50130  32022
# 46288  5013032023  제주특별자치도 서귀포시 표선면 성읍리   존재  50130  32023
# 46289  5013032024  제주특별자치도 서귀포시 표선면 가시리   존재  50130  32024
# 46290  5013032025  제주특별자치도 서귀포시 표선면 세화리   존재  50130  32025
# 46291  5013032026  제주특별자치도 서귀포시 표선면 토산리   존재  50130  32026
#
# [46292 rows x 5 columns]

# %%
address = list(map(lambda x: x.split(" ") , bjd.법정동명))

# %%
pd.DataFrame(list(map(lambda x: x[0] , address))).value_counts()
# Out:
# 경상북도       9224
# 경기도        6522
# 경상남도       6093
# 충청남도       5267
# 전라남도       4821
# 전라북도       3350
# 충청북도       3147
# 강원도        2839
# 서울특별시      1112
# 부산직할시       454
# 대구광역시       368
# 제주도         357
# 인천광역시       344
# 대구직할시       334
# 부산광역시       297
# 광주직할시       272
# 울산광역시       248
# 광주광역시       246
# 인천직할시       223
# 대전직할시       220
# 제주특별자치도     216
# 대전광역시       184
# 세종특별자치시     154
# dtype: int64

# %%
bjd["시군구1"] = list(map(lambda x: x[0] , address))
bjd["시군구2"] = list(map(lambda x: x[1] if len(x)>1 else '' , address))
bjd["법정동1"] = list(map(lambda x: x[2] if len(x)>2 else '' , address))
bjd["법정동2"] = list(map(lambda x: x[3] if len(x)>3 else '' , address))

# %%
bjd
# Out:
#             법정동코드                  법정동명 폐지여부    시군구    법정동     시군구1  시군구2  \
# 0      1100000000                 서울특별시   존재  11000  00000    서울특별시
# 1      1111000000             서울특별시 종로구   존재  11110  00000    서울특별시   종로구
# 2      1111010100         서울특별시 종로구 청운동   존재  11110  10100    서울특별시   종로구
# 3      1111010200         서울특별시 종로구 신교동   존재  11110  10200    서울특별시   종로구
# 4      1111010300         서울특별시 종로구 궁정동   존재  11110  10300    서울특별시   종로구
# ...           ...                   ...  ...    ...    ...      ...   ...
# 46287  5013032022  제주특별자치도 서귀포시 표선면 하천리   존재  50130  32022  제주특별자치도  서귀포시
# 46288  5013032023  제주특별자치도 서귀포시 표선면 성읍리   존재  50130  32023  제주특별자치도  서귀포시
# 46289  5013032024  제주특별자치도 서귀포시 표선면 가시리   존재  50130  32024  제주특별자치도  서귀포시
# 46290  5013032025  제주특별자치도 서귀포시 표선면 세화리   존재  50130  32025  제주특별자치도  서귀포시
# 46291  5013032026  제주특별자치도 서귀포시 표선면 토산리   존재  50130  32026  제주특별자치도  서귀포시
#
#       법정동1 법정동2
# 0
# 1
# 2      청운동
# 3      신교동
# 4      궁정동
# ...    ...  ...
# 46287  표선면  하천리
# 46288  표선면  성읍리
# 46289  표선면  가시리
# 46290  표선면  세화리
# 46291  표선면  토산리
#
# [46292 rows x 9 columns]

# %% [markdown]
# ## 법정동 test set 과 merge

# %%
exdata = pd.read_csv("Daesamanlap/External/external_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-7d1dd5136329> in <module>
# ----> 1 exdata = pd.read_csv("Daesamanlap/External/external_data.csv")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Daesamanlap/External/external_data.csv'

# %%
test.head()

# %%
ad.head()

# %%
test.isnull().sum()

# %%
exdata[exdata.주택유형명 == "아파트"]

# %%
test.도로명주소[0]+"\n"

# %%
f = open("도로명주소.txt", 'w')
for a in list(test.도로명주소):
    data = a+"\n"
    f.write(data)
f.close()

# %% [markdown]
# https://cafe.naver.com/excelmaster/152667

# %%
pop1 = pd.read_excel("/Users/seungji/Desktop/Dacon/Daesamanlap/External2/202106주민등록인구및세대현황_월간.xlsx")
pop2 = pd.read_excel("/Users/seungji/Desktop/Dacon/Daesamanlap/External2/202106연령별인구현황_월간.xlsx")

# %%
tr = pd.read_csv("/Users/seungji/Desktop/Dacon/Daesamanlap/ProcessedData/train_processed.csv")
tr
# Out:
#        단지코드  총세대수 임대건물구분    지역  공급유형     전용면적  전용면적별세대수     공가수 자격유형  \
# 0     C2483   900    아파트  경상북도  국민임대  39.7200       134 38.0000    A
# 1     C2483   900    아파트  경상북도  국민임대  39.7200        15 38.0000    A
# 2     C2483   900    아파트  경상북도  국민임대  51.9300       385 38.0000    A
# 3     C2483   900    아파트  경상북도  국민임대  51.9300        15 38.0000    A
# 4     C2483   900    아파트  경상북도  국민임대  51.9300        41 38.0000    A
# ...     ...   ...    ...   ...   ...      ...       ...     ...  ...
# 2947  C2571   481     상가  경상남도  임대상가  31.8400         1  5.0000    D
# 2948  C2571   481     상가  경상남도  임대상가  31.8400         1  5.0000    D
# 2949  C2571   481     상가  경상남도  임대상가  31.8400         1  5.0000    D
# 2950  C2571   481     상가  경상남도  임대상가  31.8400         1  5.0000    D
# 2951  C2571   481     상가  경상남도  임대상가 126.6500         1  5.0000    D
#
#                임대보증금          임대료   지하철역  버스정류장    단지내주차면수      등록차량수  \
# 0    15,667,000.0000 103,680.0000 0.0000 3.0000 1,425.0000 1,015.0000
# 1    15,667,000.0000 103,680.0000 0.0000 3.0000 1,425.0000 1,015.0000
# 2    27,304,000.0000 184,330.0000 0.0000 3.0000 1,425.0000 1,015.0000
# 3    27,304,000.0000 184,330.0000 0.0000 3.0000 1,425.0000 1,015.0000
# 4    27,304,000.0000 184,330.0000 0.0000 3.0000 1,425.0000 1,015.0000
# ...              ...          ...    ...    ...        ...        ...
# 2947  5,580,000.0000  71,900.0000 0.0000 1.0000    65.0000    62.0000
# 2948  5,580,000.0000  71,900.0000 0.0000 1.0000    65.0000    62.0000
# 2949  5,580,000.0000  71,900.0000 0.0000 1.0000    65.0000    62.0000
# 2950  5,580,000.0000  71,900.0000 0.0000 1.0000    65.0000    62.0000
# 2951 22,195,571.6100 285,996.7023 0.0000 1.0000    65.0000    62.0000
#
#               단지명                 도로명주소
# 0     포항장량휴먼시아1단지  경상북도 포항시 북구 장량중앙로 17
# 1     포항장량휴먼시아1단지  경상북도 포항시 북구 장량중앙로 17
# 2     포항장량휴먼시아1단지  경상북도 포항시 북구 장량중앙로 17
# 3     포항장량휴먼시아1단지  경상북도 포항시 북구 장량중앙로 17
# 4     포항장량휴먼시아1단지  경상북도 포항시 북구 장량중앙로 17
# ...           ...                   ...
# 2947    통영도남주공아파트      경상남도 통영시 발개로 153
# 2948    통영도남주공아파트      경상남도 통영시 발개로 153
# 2949    통영도남주공아파트      경상남도 통영시 발개로 153
# 2950    통영도남주공아파트      경상남도 통영시 발개로 153
# 2951    통영도남주공아파트      경상남도 통영시 발개로 153
#
# [2952 rows x 17 columns]

# %%
pop1.head()
# Out:
#        행정기관코드             행정기관       총인구수        세대수  세대당 인구     남자 인구수  \
# 0  1100000000          서울특별시    9,565,990  4,405,638  2.1700  4,649,442
# 1  1111000000       서울특별시 종로구     146,029     73,525  1.9900     70,985
# 2  1111051500  서울특별시 종로구 청운효자동     12,024      5,242  2.2900      5,580
# 3  1111053000    서울특별시 종로구 사직동      9,371      4,674  2.0000      4,225
# 4  1111054000    서울특별시 종로구 삼청동      2,498      1,248  2.0000      1,191
#
#       여자 인구수  남여 비율
# 0  4,916,548 0.9500
# 1     75,044 0.9500
# 2      6,444 0.8700
# 3      5,146 0.8200
# 4      1,307 0.9100

# %%
pop2.head(2)
# Out:
#        행정기관코드        행정기관       총인구수   총연령구간인구수    총0~9세  총10~19세    총20~29세  \
# 0  1100000000     서울특별시    9,565,990  9,565,990  602,526  766,572  1,443,208
# 1  1111000000  서울특별시 종로구     146,029    146,029    7,275   10,684     23,147
#
#      총30~39세    총40~49세    총50~59세    총60~69세  총70~79세  총80~89세 총90~99세  \
# 0  1,452,328  1,501,071  1,506,232  1,269,804  696,049  284,923  40,808
# 1     19,595     21,433     24,939     20,192   11,791    5,985     936
#
#   총100세이상      남 인구수   남연령구간인구수    남0~9세  남10~19세  남20~29세  ...  남40~49세  \
# 0   2,469  4,649,442  4,649,442  309,269  392,686  696,930  ...  743,762
# 1      52     70,985     70,985    3,651    5,311   11,255  ...   10,450
#
#    남50~59세  남60~69세  남70~79세  남80~89세 남90~99세 남100세 이상      여 인구수   여연령구간인구수  \
# 0  741,675  599,745  317,147  111,573  10,322      619  4,916,548  4,916,548
# 1   12,579   10,055    5,224    2,413     288       16     75,044     75,044
#
#      여0~9세  여10~19세  여20~29세  여30~39세  여40~49세  여50~59세  여60~69세  여70~79세  \
# 0  293,257  373,886  746,278  726,614  757,309  764,557  670,059  378,902
# 1    3,624    5,373   11,892    9,852   10,983   12,360   10,137    6,567
#
#    여80~89세 여90~99세 여100세 이상
# 0  173,350  30,486    1,850
# 1    3,572     648       36
#
# [2 rows x 41 columns]

# %%
print(bjd.shape)
print(pop1.shape)
print(pop2.shape)
# Out:
# (46292, 9)
# (3846, 8)
# (3847, 41)

# %%
bjd1 = bjd.merge(pop1, left_on = ["법정동코드"], right_on =["행정기관코드"],how = "inner")
bjd1
# Out:
#            법정동코드              법정동명 폐지여부    시군구    법정동     시군구1  시군구2 법정동1  \
# 0     1100000000             서울특별시   존재  11000  00000    서울특별시
# 1     1111000000         서울특별시 종로구   존재  11110  00000    서울특별시   종로구
# 2     1114000000          서울특별시 중구   존재  11140  00000    서울특별시    중구
# 3     1117000000         서울특별시 용산구   존재  11170  00000    서울특별시   용산구
# 4     1120000000         서울특별시 성동구   존재  11200  00000    서울특별시   성동구
# ...          ...               ...  ...    ...    ...      ...   ...  ...
# 1678  5013025000  제주특별자치도 서귀포시 대정읍   존재  50130  25000  제주특별자치도  서귀포시  대정읍
# 1679  5013025300  제주특별자치도 서귀포시 남원읍   존재  50130  25300  제주특별자치도  서귀포시  남원읍
# 1680  5013025900  제주특별자치도 서귀포시 성산읍   존재  50130  25900  제주특별자치도  서귀포시  성산읍
# 1681  5013031000  제주특별자치도 서귀포시 안덕면   존재  50130  31000  제주특별자치도  서귀포시  안덕면
# 1682  5013032000  제주특별자치도 서귀포시 표선면   존재  50130  32000  제주특별자치도  서귀포시  표선면
#
#      법정동2      행정기관코드              행정기관       총인구수        세대수  세대당 인구  \
# 0          1100000000           서울특별시    9,565,990  4,405,638  2.1700
# 1          1111000000        서울특별시 종로구     146,029     73,525  1.9900
# 2          1114000000         서울특별시 중구     123,016     62,897  1.9600
# 3          1117000000        서울특별시 용산구     226,378    111,650  2.0300
# 4          1120000000        서울특별시 성동구     289,162    134,542  2.1500
# ...   ...         ...               ...        ...        ...     ...
# 1678       5013025000  제주특별자치도 서귀포시 대정읍     21,959     10,523  2.0900
# 1679       5013025300  제주특별자치도 서귀포시 남원읍     18,717      8,677  2.1600
# 1680       5013025900  제주특별자치도 서귀포시 성산읍     15,478      8,165  1.9000
# 1681       5013031000  제주특별자치도 서귀포시 안덕면     12,205      6,288  1.9400
# 1682       5013032000  제주특별자치도 서귀포시 표선면     12,347      6,168  2.0000
#
#          남자 인구수     여자 인구수  남여 비율
# 0     4,649,442  4,916,548 0.9500
# 1        70,985     75,044 0.9500
# 2        60,019     62,997 0.9500
# 3       108,948    117,430 0.9300
# 4       141,042    148,120 0.9500
# ...         ...        ...    ...
# 1678     10,687     11,272 0.9500
# 1679      9,668      9,049 1.0700
# 1680      8,105      7,373 1.1000
# 1681      6,306      5,899 1.0700
# 1682      6,314      6,033 1.0500
#
# [1683 rows x 17 columns]

# %%
bjd2 = bjd.merge(pop1, left_on = ["법정동명"], right_on =["행정기관"],how = "inner")
bjd2
# Out:
#            법정동코드              법정동명 폐지여부    시군구    법정동     시군구1  시군구2 법정동1  \
# 0     1111011500     서울특별시 종로구 사직동   존재  11110  11500    서울특별시   종로구  사직동
# 1     1111014000     서울특별시 종로구 삼청동   존재  11110  14000    서울특별시   종로구  삼청동
# 2     1111014600     서울특별시 종로구 가회동   존재  11110  14600    서울특별시   종로구  가회동
# 3     1111016500     서울특별시 종로구 이화동   존재  11110  16500    서울특별시   종로구  이화동
# 4     1111016900     서울특별시 종로구 혜화동   존재  11110  16900    서울특별시   종로구  혜화동
# ...          ...               ...  ...    ...    ...      ...   ...  ...
# 2229  5013025000  제주특별자치도 서귀포시 대정읍   존재  50130  25000  제주특별자치도  서귀포시  대정읍
# 2230  5013025300  제주특별자치도 서귀포시 남원읍   존재  50130  25300  제주특별자치도  서귀포시  남원읍
# 2231  5013025900  제주특별자치도 서귀포시 성산읍   존재  50130  25900  제주특별자치도  서귀포시  성산읍
# 2232  5013031000  제주특별자치도 서귀포시 안덕면   존재  50130  31000  제주특별자치도  서귀포시  안덕면
# 2233  5013032000  제주특별자치도 서귀포시 표선면   존재  50130  32000  제주특별자치도  서귀포시  표선면
#
#      법정동2      행정기관코드              행정기관    총인구수     세대수  세대당 인구  남자 인구수  \
# 0          1111053000     서울특별시 종로구 사직동   9,371   4,674  2.0000   4,225
# 1          1111054000     서울특별시 종로구 삼청동   2,498   1,248  2.0000   1,191
# 2          1111060000     서울특별시 종로구 가회동   4,210   2,030  2.0700   1,944
# 3          1111064000     서울특별시 종로구 이화동   7,347   4,289  1.7100   3,472
# 4          1111065000     서울특별시 종로구 혜화동  16,489   9,194  1.7900   7,949
# ...   ...         ...               ...     ...     ...     ...     ...
# 2229       5013025000  제주특별자치도 서귀포시 대정읍  21,959  10,523  2.0900  10,687
# 2230       5013025300  제주특별자치도 서귀포시 남원읍  18,717   8,677  2.1600   9,668
# 2231       5013025900  제주특별자치도 서귀포시 성산읍  15,478   8,165  1.9000   8,105
# 2232       5013031000  제주특별자치도 서귀포시 안덕면  12,205   6,288  1.9400   6,306
# 2233       5013032000  제주특별자치도 서귀포시 표선면  12,347   6,168  2.0000   6,314
#
#       여자 인구수  남여 비율
# 0      5,146 0.8200
# 1      1,307 0.9100
# 2      2,266 0.8600
# 3      3,875 0.9000
# 4      8,540 0.9300
# ...      ...    ...
# 2229  11,272 0.9500
# 2230   9,049 1.0700
# 2231   7,373 1.1000
# 2232   5,899 1.0700
# 2233   6,033 1.0500
#
# [2234 rows x 17 columns]

# %%
len(set(bjd1.법정동코드) | set(bjd2.법정동코드))
# Out:
# 2523

# %%
len(set(bjd2.법정동코드)- set(bjd1.법정동코드))
# Out:
# 840

# %%
bjd3 = pd.concat([bjd1,bjd2],axis=0).drop_duplicates()

# %%
bjd.법정동명[46100:46200]
# Out:
# 46100        제주특별자치도 제주시 외도일동
# 46101        제주특별자치도 제주시 외도이동
# 46102        제주특별자치도 제주시 이호일동
# 46103        제주특별자치도 제주시 이호이동
# 46104        제주특별자치도 제주시 도두일동
# 46105        제주특별자치도 제주시 도두이동
# 46106         제주특별자치도 제주시 도남동
# 46107        제주특별자치도 제주시 도련일동
# 46108        제주특별자치도 제주시 도련이동
# 46109         제주특별자치도 제주시 용강동
# 46110         제주특별자치도 제주시 회천동
# 46111         제주특별자치도 제주시 오등동
# 46112         제주특별자치도 제주시 월평동
# 46113         제주특별자치도 제주시 영평동
# 46114          제주특별자치도 제주시 연동
# 46115         제주특별자치도 제주시 도평동
# 46116         제주특별자치도 제주시 해안동
# 46117         제주특별자치도 제주시 내도동
# 46118         제주특별자치도 제주시 한림읍
# 46119     제주특별자치도 제주시 한림읍 귀덕리
# 46120     제주특별자치도 제주시 한림읍 수원리
# 46121     제주특별자치도 제주시 한림읍 대림리
# 46122     제주특별자치도 제주시 한림읍 한림리
# 46123     제주특별자치도 제주시 한림읍 금악리
# 46124     제주특별자치도 제주시 한림읍 동명리
# 46125     제주특별자치도 제주시 한림읍 명월리
# 46126     제주특별자치도 제주시 한림읍 옹포리
# 46127     제주특별자치도 제주시 한림읍 상대리
# 46128     제주특별자치도 제주시 한림읍 상명리
# 46129     제주특별자치도 제주시 한림읍 협재리
# 46130     제주특별자치도 제주시 한림읍 월령리
# 46131     제주특별자치도 제주시 한림읍 금능리
# 46132     제주특별자치도 제주시 한림읍 월림리
# 46133     제주특별자치도 제주시 한림읍 한수리
# 46134         제주특별자치도 제주시 애월읍
# 46135     제주특별자치도 제주시 애월읍 용흥리
# 46136     제주특별자치도 제주시 애월읍 중엄리
# 46137     제주특별자치도 제주시 애월읍 귀일리
# 46138     제주특별자치도 제주시 애월읍 어도리
# 46139     제주특별자치도 제주시 애월읍 동귀리
# 46140     제주특별자치도 제주시 애월읍 광령리
# 46141     제주특별자치도 제주시 애월읍 상귀리
# 46142     제주특별자치도 제주시 애월읍 구엄리
# 46143     제주특별자치도 제주시 애월읍 수산리
# 46144     제주특별자치도 제주시 애월읍 신엄리
# 46145     제주특별자치도 제주시 애월읍 장전리
# 46146     제주특별자치도 제주시 애월읍 소길리
# 46147     제주특별자치도 제주시 애월읍 고성리
# 46148     제주특별자치도 제주시 애월읍 하가리
# 46149     제주특별자치도 제주시 애월읍 상가리
# 46150     제주특별자치도 제주시 애월읍 고내리
# 46151     제주특별자치도 제주시 애월읍 애월리
# 46152     제주특별자치도 제주시 애월읍 납읍리
# 46153     제주특별자치도 제주시 애월읍 어음리
# 46154     제주특별자치도 제주시 애월읍 곽지리
# 46155     제주특별자치도 제주시 애월읍 금성리
# 46156     제주특별자치도 제주시 애월읍 봉성리
# 46157    제주특별자치도 제주시 애월읍 하귀1리
# 46158    제주특별자치도 제주시 애월읍 하귀2리
# 46159    제주특별자치도 제주시 애월읍 유수암리
# 46160    제주특별자치도 제주시 애월읍 광령1리
# 46161    제주특별자치도 제주시 애월읍 광령2리
# 46162    제주특별자치도 제주시 애월읍 광령3리
# 46163         제주특별자치도 제주시 구좌읍
# 46164     제주특별자치도 제주시 구좌읍 동복리
# 46165     제주특별자치도 제주시 구좌읍 덕천리
# 46166     제주특별자치도 제주시 구좌읍 송당리
# 46167     제주특별자치도 제주시 구좌읍 월정리
# 46168     제주특별자치도 제주시 구좌읍 행원리
# 46169     제주특별자치도 제주시 구좌읍 세화리
# 46170     제주특별자치도 제주시 구좌읍 상도리
# 46171     제주특별자치도 제주시 구좌읍 한동리
# 46172     제주특별자치도 제주시 구좌읍 하도리
# 46173     제주특별자치도 제주시 구좌읍 종달리
# 46174     제주특별자치도 제주시 구좌읍 평대리
# 46175     제주특별자치도 제주시 구좌읍 김녕리
# 46176         제주특별자치도 제주시 조천읍
# 46177     제주특별자치도 제주시 조천읍 신촌리
# 46178     제주특별자치도 제주시 조천읍 와흘리
# 46179     제주특별자치도 제주시 조천읍 조천리
# 46180     제주특별자치도 제주시 조천읍 함덕리
# 46181     제주특별자치도 제주시 조천읍 신흥리
# 46182     제주특별자치도 제주시 조천읍 대흘리
# 46183     제주특별자치도 제주시 조천읍 북촌리
# 46184     제주특별자치도 제주시 조천읍 와산리
# 46185     제주특별자치도 제주시 조천읍 교래리
# 46186     제주특별자치도 제주시 조천읍 선흘리
# 46187         제주특별자치도 제주시 한경면
# 46188     제주특별자치도 제주시 한경면 청수리
# 46189     제주특별자치도 제주시 한경면 용수리
# 46190     제주특별자치도 제주시 한경면 고산리
# 46191     제주특별자치도 제주시 한경면 판포리
# 46192     제주특별자치도 제주시 한경면 금등리
# 46193     제주특별자치도 제주시 한경면 조수리
# 46194     제주특별자치도 제주시 한경면 두모리
# 46195     제주특별자치도 제주시 한경면 신창리
# 46196     제주특별자치도 제주시 한경면 낙천리
# 46197     제주특별자치도 제주시 한경면 저지리
# 46198     제주특별자치도 제주시 한경면 산양리
# 46199     제주특별자치도 제주시 한경면 한원리
# Name: 법정동명, dtype: object

# %% [markdown]
# ## MERGE

# %%
bld_tr = pd.read_csv("/Users/seungji/Desktop/Dacon/Daesamanlap/External3/building_tr.csv")
bld_tst = pd.read_csv("/Users/seungji/Desktop/Dacon/Daesamanlap/External3/building_tst.csv")

# %%
bld_tr
# Out:
#            관리건축물대장PK              건물명       대지면적       건축면적         연면적  \
# 0    47113-100216867           장량휴먼시아     0.0000   632.9550  8,409.5540
# 1    48220-100186682           미수휴먼시아     0.0000   661.9600  1,213.8700
# 2    30200-100200744        도안휴먼시아4단지     0.0000   707.1500  4,636.4100
# 3    41360-100216608             휴먼시아     0.0000   385.9900  6,017.7600
# 4    45140-100190554        장신휴먼시아1단지     0.0000   556.1800  6,611.9000
# ..               ...              ...        ...        ...         ...
# 348  50130-100340536       서귀포서홍 행복주택     0.0000     0.0000     67.9800
# 349  42110-100311797  춘천우두엘에이치천년나무3단지     0.0000     0.0000     59.4100
# 350  26290-100212522           용호행복주택     0.0000     0.0000    152.2900
# 351  43150-100289809        제천 공공실버주택     0.0000     0.0000     88.8600
# 352  42760-100179404       평창하진부주공아파트 2,718.0000 1,687.0910 24,661.2380
#
#        용적률산정연면적      용적률  세대수  가구수                  도로명주소  \
# 0    8,394.6490   0.0000  149    0   경상북도 포항시 북구 장량중앙로 17
# 1      240.8300   0.0000    0    0    경상남도 통영시 미우지해안로 107
# 2    4,636.4100   0.0000  102    0       대전광역시 유성구 상대로 40
# 3    5,951.0800   0.0000   76    0        경기도 남양주시 늘을3로 8
# 4    6,611.9000   0.0000   84    0  전라북도 익산시 오산면 선화로4길 66
# ..          ...      ...  ...  ...                    ...
# 348      0.0000   0.0000    0    0   제주특별자치도 서귀포시 장수로 115
# 349     59.4100   0.0000    0    0        강원도 춘천시 우두1길 40
# 350      0.0000   0.0000    0    0       부산광역시 남구 동명로 183
# 351      0.0000   0.0000    0    0    충청북도 제천시 용두천로40길 28
# 352 17,751.4270 653.1100  239    0   강원도 평창군 진부면 경강로 3587
#
#                        지번주소
# 0     경상북도 포항시 북구 양덕동 336-1
# 1          경상남도 통영시 미수동 695
# 2         대전광역시 유성구 상대동 465
# 3          경기도 남양주시 호평동 712
# 4     전라북도 익산시 오산면 장신리 1130
# ..                      ...
# 348  제주특별자치도 서귀포시 서홍동 355-1
# 349        강원도 춘천시 우두동 1088
# 350      부산광역시 남구 용호동 376-9
# 351       충청북도 제천시 고암동 1273
# 352    강원도 평창군 진부면 하진부리 115
#
# [353 rows x 11 columns]

# %%
train = pd.read_csv("/Users/seungji/Desktop/Dacon/Daesamanlap/ProcessedData/train_processed.csv")

# %%
train.도로명주소.nunique()
# Out:
# 421

# %%
juso = list(map(lambda x: ''.join(x.split()[:-1]) , bld_tr.지번주소))
juso
# Out:
# ['경상북도포항시북구양덕동',
#  '경상남도통영시미수동',
#  '대전광역시유성구상대동',
#  '경기도남양주시호평동',
#  '전라북도익산시오산면장신리',
#  '전라북도익산시오산면장신리',
#  '경기도성남시분당구백현동',
#  '대전광역시유성구지족동',
#  '강원도횡성군횡성읍읍하리',
#  '광주광역시남구백운동',
#  '광주광역시남구백운동',
#  '강원도강릉시교동',
#  '강원도강릉시포남동',
#  '강원도강릉시입암동',
#  '경상남도거제시장평동',
#  '충청남도당진시석문면통정리',
#  '충청남도공주시옥룡동',
#  '부산광역시기장군기장읍교리',
#  '경상남도김해시구산동',
#  '경상남도김해시삼문동',
#  '대전광역시서구관저동',
#  '대전광역시서구관저동',
#  '대전광역시서구월평동',
#  '대전광역시중구문화동',
#  '대전광역시유성구반석동',
#  '대전광역시대덕구법동',
#  '대전광역시중구중촌동',
#  '경상남도창원시마산회원구내서읍삼계리',
#  '경상남도창원시마산회원구내서읍상곡리',
#  '경상남도밀양시가곡동',
#  '경상남도밀양시삼문동',
#  '충청남도보령시명천동',
#  '부산광역시북구금곡동',
#  '부산광역시북구금곡동',
#  '부산광역시북구금곡동',
#  '부산광역시북구금곡동',
#  '부산광역시북구덕천동',
#  '부산광역시북구만덕동',
#  '부산광역시사상구모라동',
#  '부산광역시해운대구반송동',
#  '부산광역시북구금곡동',
#  '충청남도부여군부여읍쌍북리',
#  '경상남도사천시벌리동',
#  '충청남도서산시석림동',
#  '강원도속초시교동',
#  '울산광역시북구화봉동',
#  '강원도원주시문막읍건등리',
#  '부산광역시기장군정관읍용수리',
#  '제주특별자치도제주시아라일동',
#  '제주특별자치도제주시노형동',
#  '제주특별자치도제주시화북일동',
#  '경상남도진주시가좌동',
#  '경상남도진주시평거동',
#  '경상남도창원시진해구자은동',
#  '경상남도창녕군창녕읍말흘리',
#  '충청남도천안시서북구백석동',
#  '충청남도천안시서북구성정동',
#  '충청남도천안시서북구쌍용동',
#  '충청남도청양군청양읍읍내리',
#  '강원도춘천시후평동',
#  '강원도태백시철암동',
#  '경상남도통영시도남동',
#  '충청남도홍성군홍성읍남장리',
#  '제주특별자치도제주시화북일동',
#  '충청북도제천시강제동',
#  '전라남도여수시소라면죽림리',
#  '전라남도여수시소라면죽림리',
#  '경상북도고령군다산면곽촌리',
#  '전라북도순창군풍산면대가리',
#  '전라북도남원시금동',
#  '강원도원주시무실동',
#  '경상남도사천시용현면송지리',
#  '충청북도진천군진천읍벽암리',
#  '부산광역시강서구지사동',
#  '광주광역시북구신용동',
#  '광주광역시북구신용동',
#  '경상북도구미시옥계동',
#  '전라남도무안군무안읍성내리',
#  '경기도용인시수지구상현동',
#  '강원도강릉시회산동',
#  '경상북도경산시사동',
#  '경상북도경산시평산동',
#  '경상북도경산시진량읍부기리',
#  '경상북도고령군다산면상곡리',
#  '전라북도고창군고창읍읍내리',
#  '부산광역시기장군철마면고촌리',
#  '경기도광명시소하동',
#  '전라남도광양시마동',
#  '광주광역시남구노대동',
#  '광주광역시남구노대동',
#  '광주광역시남구노대동',
#  '광주광역시광산구신가동',
#  '광주광역시광산구흑석동',
#  '광주광역시북구신용동',
#  '광주광역시북구연제동',
#  '광주광역시북구용두동',
#  '광주광역시북구용봉동',
#  '전라북도군산시삼학동',
#  '충청남도금산군금산읍상리',
#  '경상북도김천시덕곡동',
#  '경상남도김해시율하동',
#  '경상남도김해시부곡동',
#  '경상남도김해시부곡동',
#  '경상남도김해시진영읍여래리',
#  '경기도남양주시진접읍장현리',
#  '경기도남양주시진접읍금곡리',
#  '경기도남양주시진접읍금곡리',
#  '경기도남양주시퇴계원읍퇴계원리',
#  '경기도남양주시퇴계원읍퇴계원리',
#  '경기도남양주시호평동',
#  '대전광역시유성구반석동',
#  '대구광역시달성군가창면용계리',
#  '대구광역시달성군다사읍서재리',
#  '대구광역시달서구장기동',
#  '대전광역시유성구봉산동',
#  '전라남도목포시옥암동',
#  '전라남도목포시용해동',
#  '충청남도보령시죽정동',
#  '부산광역시기장군기장읍내리',
#  '전라북도부안군부안읍서외리',
#  '경상남도사천시용강동',
#  '경상남도사천시사남면월성리',
#  '서울특별시관악구신림동',
#  '충청남도서천군서천읍사곡리',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시분당구삼평동',
#  '부산광역시해운대구송정동',
#  '전라북도순창군순창읍교성리',
#  '전라남도순천시서면선평리',
#  '전라남도순천시연향동',
#  '경기도안산시단원구신길동',
#  '경기도안산시단원구신길동',
#  '경기도안산시단원구신길동',
#  '경기도안산시단원구신길동',
#  '경기도안산시상록구팔곡일동',
#  '경상남도양산시남부동',
#  '경기도양주시광적면석우리',
#  '경기도양주시고읍동',
#  '경기도양주시만송동',
#  '경기도양주시만송동',
#  '경기도양주시고암동',
#  '경기도양주시백석읍방성리',
#  '전라남도여수시화장동',
#  '경상북도예천군예천읍대심리',
#  '경기도용인시기흥구청덕동',
#  '경기도용인시기흥구청덕동',
#  '경기도용인시기흥구중동',
#  '경기도용인시기흥구보라동',
#  '경기도용인시기흥구공세동',
#  '경기도용인시기흥구신갈동',
#  '경기도용인시수지구죽전동',
#  '경기도용인시수지구죽전동',
#  '경기도용인시기흥구영덕동',
#  '경기도용인시기흥구영덕동',
#  '경기도용인시기흥구영덕동',
#  '울산광역시울주군범서읍구영리',
#  '울산광역시북구매곡동',
#  '경상북도울진군울진읍읍내리',
#  '강원도원주시개운동',
#  '강원도원주시개운동',
#  '강원도원주시무실동',
#  '강원도원주시단계동',
#  '경상남도김해시율하동',
#  '충청북도음성군금왕읍무극리',
#  '경기도의왕시삼동',
#  '경기도의왕시청계동',
#  '경기도의왕시청계동',
#  '경기도이천시갈산동',
#  '경기도이천시갈산동',
#  '전라북도익산시부송동',
#  '전라북도임실군임실읍이도리',
#  '전라남도장성군장성읍영천리',
#  '전라북도장수군장수읍장수리',
#  '충청남도서천군장항읍원수리',
#  '제주특별자치도제주시노형동',
#  '강원도정선군고한읍고한리',
#  '강원도정선군정선읍봉양리',
#  '전라북도정읍시농소동',
#  '전라북도정읍시신태인읍신태인리',
#  '제주특별자치도제주시도련일동',
#  '제주특별자치도제주시한림읍대림리',
#  '충청북도제천시영천동',
#  '충청북도제천시장락동',
#  '대구광역시달성군다사읍매곡리',
#  '충청북도증평군증평읍송산리',
#  '경상남도진주시가좌동',
#  '경상남도창원시진해구자은동',
#  '경상남도창원시의창구도계동',
#  '충청북도청주시청원구내수읍마산리',
#  '충청북도청주시흥덕구가경동',
#  '강원도춘천시퇴계동',
#  '강원도춘천시퇴계동',
#  '충청북도충주시연수동',
#  '충청북도충주시연수동',
#  '경기도평택시안중읍현화리',
#  '경기도평택시이충동',
#  '경상남도함안군가야읍도항리',
#  '경상남도함양군함양읍교산리',
#  '충청북도음성군감곡면오향리',
#  '충청북도청주시서원구성화동',
#  '광주광역시광산구장덕동',
#  '전라남도장성군장성읍영천리',
#  '경기도광명시소하동',
#  '대전광역시유성구봉명동',
#  '경상북도경주시건천읍건천리',
#  '광주광역시광산구장덕동',
#  '대전광역시유성구원신흥동',
#  '전라남도영암군삼호읍용앙리',
#  '경상남도창원시의창구봉림동',
#  '경상남도창원시의창구봉림동',
#  '충청북도증평군증평읍송산리',
#  '경상남도양산시소주동',
#  '경기도의왕시포일동',
#  '경기도남양주시별내동',
#  '충청북도청주시청원구주중동',
#  '서울특별시서초구우면동',
#  '경상북도영천시망정동',
#  '경상남도양산시물금읍가촌리',
#  '충청남도서천군종천면종천리',
#  '전라남도장흥군장흥읍건산리',
#  '경상남도함안군칠원읍구성리',
#  '강원도강릉시포남동',
#  '경기도평택시비전동',
#  '부산광역시부산진구범천동',
#  '경상북도포항시북구양덕동',
#  '경기도화성시남양읍남양리',
#  '서울특별시강남구자곡동',
#  '충청남도논산시내동',
#  '경기도남양주시호평동',
#  '부산광역시사상구괘법동',
#  '경기도남양주시별내동',
#  '서울특별시강남구자곡동',
#  '경상남도밀양시내이동',
#  '서울특별시서초구우면동',
#  '충청북도청주시청원구주중동',
#  '경상북도영주시가흥동',
#  '경기도군포시당동',
#  '부산광역시기장군정관읍달산리',
#  '전라남도해남군해남읍해리',
#  '대전광역시유성구지족동',
#  '전라북도완주군이서면갈산리',
#  '충청북도음성군금왕읍금석리',
#  '충청북도진천군덕산읍두촌리',
#  '서울특별시강남구자곡동',
#  '경상남도거제시하청면하청리',
#  '경상북도김천시율곡동',
#  '전라남도나주시빛가람동',
#  '전라남도나주시빛가람동',
#  '전라남도보성군벌교읍회정리',
#  '충청남도보령시성주면성주리',
#  '광주광역시남구행암동',
#  '부산광역시사상구감전동',
#  '경상남도진주시충무공동',
#  '대구광역시달성군옥포읍강림리',
#  '충청북도청주시청원구율량동',
#  '경기도남양주시별내동',
#  '경기도남양주시별내동',
#  '전라북도완주군이서면갈산리',
#  '제주특별자치도제주시도련이동',
#  '강원도속초시조양동',
#  '경기도양주시옥정동',
#  '경상북도포항시북구양덕동',
#  '전라남도나주시빛가람동',
#  '대전광역시서구관저동',
#  '경기도남양주시별내동',
#  '경기도남양주시별내동',
#  '경상남도양산시물금읍가촌리',
#  '광주광역시남구행암동',
#  '대구광역시달성군옥포읍강림리',
#  '대전광역시서구관저동',
#  '충청북도충주시안림동',
#  '강원도원주시반곡동',
#  '경기도구리시갈매동',
#  '경상남도양산시물금읍물금리',
#  '경상남도양산시물금읍물금리',
#  '제주특별자치도서귀포시남원읍남원리',
#  '충청북도제천시영천동',
#  '경기도평택시비전동',
#  '강원도강릉시회산동',
#  '경기도구리시갈매동',
#  '충청북도증평군증평읍송산리',
#  '대전광역시유성구원신흥동',
#  '충청남도부여군규암면내리',
#  '광주광역시광산구선암동',
#  '대구광역시달성군현풍읍중리',
#  '세종특별자치시새롬동',
#  '충청북도진천군덕산읍두촌리',
#  '대구광역시달성군유가읍봉리',
#  '경기도평택시비전동',
#  '세종특별자치시종촌동',
#  '부산광역시부산진구전포동',
#  '경상북도상주시함창읍구향리',
#  '충청북도충주시안림동',
#  '제주특별자치도서귀포시강정동',
#  '경기도안성시아양동',
#  '경상북도김천시율곡동',
#  '경기도성남시수정구창곡동',
#  '경기도남양주시별내동',
#  '경상남도김해시진영읍여래리',
#  '경상남도진주시충무공동',
#  '부산광역시기장군정관읍모전리',
#  '충청북도충주시대소원면본리',
#  '경기도양주시옥정동',
#  '경기도양주시옥정동',
#  '강원도강릉시홍제동',
#  '경상남도창원시진해구자은동',
#  '경기도성남시중원구성남동',
#  '광주광역시남구행암동',
#  '경상남도진주시충무공동',
#  '세종특별자치시대평동',
#  '경기도성남시수정구창곡동',
#  '경상남도창원시진해구자은동',
#  '경기도군포시도마교동',
#  '대구광역시달서구대곡동',
#  '경기도양주시옥정동',
#  '경기도양주시옥정동',
#  '부산광역시강서구명지동',
#  '전라남도목포시연산동',
#  '서울특별시구로구오류동',
#  '대구광역시달성군현풍읍중리',
#  '전라남도순천시서면선평리',
#  '울산광역시남구야음동',
#  '전라북도전주시덕진구반월동',
#  '제주특별자치도제주시봉개동',
#  '전라남도여수시수정동',
#  '세종특별자치시다정동',
#  '대구광역시달성군옥포읍교항리',
#  '강원도양양군강현면강선리',
#  '울산광역시북구송정동',
#  '경기도양주시옥정동',
#  '경상북도김천시삼락동',
#  '경상남도진주시문산읍삼곡리',
#  '제주특별자치도서귀포시서호동',
#  '경기도남양주시별내동',
#  '대전광역시유성구봉산동',
#  '경상남도김해시장유동',
#  '경기도성남시수정구고등동',
#  '광주광역시광산구쌍암동',
#  '광주광역시광산구쌍암동',
#  '광주광역시남구임암동',
#  '경기도양주시광사동',
#  '경기도평택시고덕면여염리',
#  '울산광역시북구화봉동',
#  '전라남도고흥군고흥읍등암리',
#  '경기도의왕시고천동',
#  '제주특별자치도서귀포시서홍동',
#  '강원도춘천시우두동',
#  '부산광역시남구용호동',
#  '충청북도제천시고암동',
#  '강원도평창군진부면하진부리']

# %%
juso = list(map(lambda x: x.split()[:-1] , bld_tr.지번주소))
juso
# Out:
# [['경상북도', '포항시', '북구', '양덕동'],
#  ['경상남도', '통영시', '미수동'],
#  ['대전광역시', '유성구', '상대동'],
#  ['경기도', '남양주시', '호평동'],
#  ['전라북도', '익산시', '오산면', '장신리'],
#  ['전라북도', '익산시', '오산면', '장신리'],
#  ['경기도', '성남시', '분당구', '백현동'],
#  ['대전광역시', '유성구', '지족동'],
#  ['강원도', '횡성군', '횡성읍', '읍하리'],
#  ['광주광역시', '남구', '백운동'],
#  ['광주광역시', '남구', '백운동'],
#  ['강원도', '강릉시', '교동'],
#  ['강원도', '강릉시', '포남동'],
#  ['강원도', '강릉시', '입암동'],
#  ['경상남도', '거제시', '장평동'],
#  ['충청남도', '당진시', '석문면', '통정리'],
#  ['충청남도', '공주시', '옥룡동'],
#  ['부산광역시', '기장군', '기장읍', '교리'],
#  ['경상남도', '김해시', '구산동'],
#  ['경상남도', '김해시', '삼문동'],
#  ['대전광역시', '서구', '관저동'],
#  ['대전광역시', '서구', '관저동'],
#  ['대전광역시', '서구', '월평동'],
#  ['대전광역시', '중구', '문화동'],
#  ['대전광역시', '유성구', '반석동'],
#  ['대전광역시', '대덕구', '법동'],
#  ['대전광역시', '중구', '중촌동'],
#  ['경상남도', '창원시', '마산회원구', '내서읍', '삼계리'],
#  ['경상남도', '창원시', '마산회원구', '내서읍', '상곡리'],
#  ['경상남도', '밀양시', '가곡동'],
#  ['경상남도', '밀양시', '삼문동'],
#  ['충청남도', '보령시', '명천동'],
#  ['부산광역시', '북구', '금곡동'],
#  ['부산광역시', '북구', '금곡동'],
#  ['부산광역시', '북구', '금곡동'],
#  ['부산광역시', '북구', '금곡동'],
#  ['부산광역시', '북구', '덕천동'],
#  ['부산광역시', '북구', '만덕동'],
#  ['부산광역시', '사상구', '모라동'],
#  ['부산광역시', '해운대구', '반송동'],
#  ['부산광역시', '북구', '금곡동'],
#  ['충청남도', '부여군', '부여읍', '쌍북리'],
#  ['경상남도', '사천시', '벌리동'],
#  ['충청남도', '서산시', '석림동'],
#  ['강원도', '속초시', '교동'],
#  ['울산광역시', '북구', '화봉동'],
#  ['강원도', '원주시', '문막읍', '건등리'],
#  ['부산광역시', '기장군', '정관읍', '용수리'],
#  ['제주특별자치도', '제주시', '아라일동'],
#  ['제주특별자치도', '제주시', '노형동'],
#  ['제주특별자치도', '제주시', '화북일동'],
#  ['경상남도', '진주시', '가좌동'],
#  ['경상남도', '진주시', '평거동'],
#  ['경상남도', '창원시', '진해구', '자은동'],
#  ['경상남도', '창녕군', '창녕읍', '말흘리'],
#  ['충청남도', '천안시', '서북구', '백석동'],
#  ['충청남도', '천안시', '서북구', '성정동'],
#  ['충청남도', '천안시', '서북구', '쌍용동'],
#  ['충청남도', '청양군', '청양읍', '읍내리'],
#  ['강원도', '춘천시', '후평동'],
#  ['강원도', '태백시', '철암동'],
#  ['경상남도', '통영시', '도남동'],
#  ['충청남도', '홍성군', '홍성읍', '남장리'],
#  ['제주특별자치도', '제주시', '화북일동'],
#  ['충청북도', '제천시', '강제동'],
#  ['전라남도', '여수시', '소라면', '죽림리'],
#  ['전라남도', '여수시', '소라면', '죽림리'],
#  ['경상북도', '고령군', '다산면', '곽촌리'],
#  ['전라북도', '순창군', '풍산면', '대가리'],
#  ['전라북도', '남원시', '금동'],
#  ['강원도', '원주시', '무실동'],
#  ['경상남도', '사천시', '용현면', '송지리'],
#  ['충청북도', '진천군', '진천읍', '벽암리'],
#  ['부산광역시', '강서구', '지사동'],
#  ['광주광역시', '북구', '신용동'],
#  ['광주광역시', '북구', '신용동'],
#  ['경상북도', '구미시', '옥계동'],
#  ['전라남도', '무안군', '무안읍', '성내리'],
#  ['경기도', '용인시', '수지구', '상현동'],
#  ['강원도', '강릉시', '회산동'],
#  ['경상북도', '경산시', '사동'],
#  ['경상북도', '경산시', '평산동'],
#  ['경상북도', '경산시', '진량읍', '부기리'],
#  ['경상북도', '고령군', '다산면', '상곡리'],
#  ['전라북도', '고창군', '고창읍', '읍내리'],
#  ['부산광역시', '기장군', '철마면', '고촌리'],
#  ['경기도', '광명시', '소하동'],
#  ['전라남도', '광양시', '마동'],
#  ['광주광역시', '남구', '노대동'],
#  ['광주광역시', '남구', '노대동'],
#  ['광주광역시', '남구', '노대동'],
#  ['광주광역시', '광산구', '신가동'],
#  ['광주광역시', '광산구', '흑석동'],
#  ['광주광역시', '북구', '신용동'],
#  ['광주광역시', '북구', '연제동'],
#  ['광주광역시', '북구', '용두동'],
#  ['광주광역시', '북구', '용봉동'],
#  ['전라북도', '군산시', '삼학동'],
#  ['충청남도', '금산군', '금산읍', '상리'],
#  ['경상북도', '김천시', '덕곡동'],
#  ['경상남도', '김해시', '율하동'],
#  ['경상남도', '김해시', '부곡동'],
#  ['경상남도', '김해시', '부곡동'],
#  ['경상남도', '김해시', '진영읍', '여래리'],
#  ['경기도', '남양주시', '진접읍', '장현리'],
#  ['경기도', '남양주시', '진접읍', '금곡리'],
#  ['경기도', '남양주시', '진접읍', '금곡리'],
#  ['경기도', '남양주시', '퇴계원읍', '퇴계원리'],
#  ['경기도', '남양주시', '퇴계원읍', '퇴계원리'],
#  ['경기도', '남양주시', '호평동'],
#  ['대전광역시', '유성구', '반석동'],
#  ['대구광역시', '달성군', '가창면', '용계리'],
#  ['대구광역시', '달성군', '다사읍', '서재리'],
#  ['대구광역시', '달서구', '장기동'],
#  ['대전광역시', '유성구', '봉산동'],
#  ['전라남도', '목포시', '옥암동'],
#  ['전라남도', '목포시', '용해동'],
#  ['충청남도', '보령시', '죽정동'],
#  ['부산광역시', '기장군', '기장읍', '내리'],
#  ['전라북도', '부안군', '부안읍', '서외리'],
#  ['경상남도', '사천시', '용강동'],
#  ['경상남도', '사천시', '사남면', '월성리'],
#  ['서울특별시', '관악구', '신림동'],
#  ['충청남도', '서천군', '서천읍', '사곡리'],
#  ['경기도', '성남시', '중원구', '도촌동'],
#  ['경기도', '성남시', '중원구', '도촌동'],
#  ['경기도', '성남시', '중원구', '도촌동'],
#  ['경기도', '성남시', '중원구', '도촌동'],
#  ['경기도', '성남시', '분당구', '삼평동'],
#  ['부산광역시', '해운대구', '송정동'],
#  ['전라북도', '순창군', '순창읍', '교성리'],
#  ['전라남도', '순천시', '서면', '선평리'],
#  ['전라남도', '순천시', '연향동'],
#  ['경기도', '안산시', '단원구', '신길동'],
#  ['경기도', '안산시', '단원구', '신길동'],
#  ['경기도', '안산시', '단원구', '신길동'],
#  ['경기도', '안산시', '단원구', '신길동'],
#  ['경기도', '안산시', '상록구', '팔곡일동'],
#  ['경상남도', '양산시', '남부동'],
#  ['경기도', '양주시', '광적면', '석우리'],
#  ['경기도', '양주시', '고읍동'],
#  ['경기도', '양주시', '만송동'],
#  ['경기도', '양주시', '만송동'],
#  ['경기도', '양주시', '고암동'],
#  ['경기도', '양주시', '백석읍', '방성리'],
#  ['전라남도', '여수시', '화장동'],
#  ['경상북도', '예천군', '예천읍', '대심리'],
#  ['경기도', '용인시', '기흥구', '청덕동'],
#  ['경기도', '용인시', '기흥구', '청덕동'],
#  ['경기도', '용인시', '기흥구', '중동'],
#  ['경기도', '용인시', '기흥구', '보라동'],
#  ['경기도', '용인시', '기흥구', '공세동'],
#  ['경기도', '용인시', '기흥구', '신갈동'],
#  ['경기도', '용인시', '수지구', '죽전동'],
#  ['경기도', '용인시', '수지구', '죽전동'],
#  ['경기도', '용인시', '기흥구', '영덕동'],
#  ['경기도', '용인시', '기흥구', '영덕동'],
#  ['경기도', '용인시', '기흥구', '영덕동'],
#  ['울산광역시', '울주군', '범서읍', '구영리'],
#  ['울산광역시', '북구', '매곡동'],
#  ['경상북도', '울진군', '울진읍', '읍내리'],
#  ['강원도', '원주시', '개운동'],
#  ['강원도', '원주시', '개운동'],
#  ['강원도', '원주시', '무실동'],
#  ['강원도', '원주시', '단계동'],
#  ['경상남도', '김해시', '율하동'],
#  ['충청북도', '음성군', '금왕읍', '무극리'],
#  ['경기도', '의왕시', '삼동'],
#  ['경기도', '의왕시', '청계동'],
#  ['경기도', '의왕시', '청계동'],
#  ['경기도', '이천시', '갈산동'],
#  ['경기도', '이천시', '갈산동'],
#  ['전라북도', '익산시', '부송동'],
#  ['전라북도', '임실군', '임실읍', '이도리'],
#  ['전라남도', '장성군', '장성읍', '영천리'],
#  ['전라북도', '장수군', '장수읍', '장수리'],
#  ['충청남도', '서천군', '장항읍', '원수리'],
#  ['제주특별자치도', '제주시', '노형동'],
#  ['강원도', '정선군', '고한읍', '고한리'],
#  ['강원도', '정선군', '정선읍', '봉양리'],
#  ['전라북도', '정읍시', '농소동'],
#  ['전라북도', '정읍시', '신태인읍', '신태인리'],
#  ['제주특별자치도', '제주시', '도련일동'],
#  ['제주특별자치도', '제주시', '한림읍', '대림리'],
#  ['충청북도', '제천시', '영천동'],
#  ['충청북도', '제천시', '장락동'],
#  ['대구광역시', '달성군', '다사읍', '매곡리'],
#  ['충청북도', '증평군', '증평읍', '송산리'],
#  ['경상남도', '진주시', '가좌동'],
#  ['경상남도', '창원시', '진해구', '자은동'],
#  ['경상남도', '창원시', '의창구', '도계동'],
#  ['충청북도', '청주시', '청원구', '내수읍', '마산리'],
#  ['충청북도', '청주시', '흥덕구', '가경동'],
#  ['강원도', '춘천시', '퇴계동'],
#  ['강원도', '춘천시', '퇴계동'],
#  ['충청북도', '충주시', '연수동'],
#  ['충청북도', '충주시', '연수동'],
#  ['경기도', '평택시', '안중읍', '현화리'],
#  ['경기도', '평택시', '이충동'],
#  ['경상남도', '함안군', '가야읍', '도항리'],
#  ['경상남도', '함양군', '함양읍', '교산리'],
#  ['충청북도', '음성군', '감곡면', '오향리'],
#  ['충청북도', '청주시', '서원구', '성화동'],
#  ['광주광역시', '광산구', '장덕동'],
#  ['전라남도', '장성군', '장성읍', '영천리'],
#  ['경기도', '광명시', '소하동'],
#  ['대전광역시', '유성구', '봉명동'],
#  ['경상북도', '경주시', '건천읍', '건천리'],
#  ['광주광역시', '광산구', '장덕동'],
#  ['대전광역시', '유성구', '원신흥동'],
#  ['전라남도', '영암군', '삼호읍', '용앙리'],
#  ['경상남도', '창원시', '의창구', '봉림동'],
#  ['경상남도', '창원시', '의창구', '봉림동'],
#  ['충청북도', '증평군', '증평읍', '송산리'],
#  ['경상남도', '양산시', '소주동'],
#  ['경기도', '의왕시', '포일동'],
#  ['경기도', '남양주시', '별내동'],
#  ['충청북도', '청주시', '청원구', '주중동'],
#  ['서울특별시', '서초구', '우면동'],
#  ['경상북도', '영천시', '망정동'],
#  ['경상남도', '양산시', '물금읍', '가촌리'],
#  ['충청남도', '서천군', '종천면', '종천리'],
#  ['전라남도', '장흥군', '장흥읍', '건산리'],
#  ['경상남도', '함안군', '칠원읍', '구성리'],
#  ['강원도', '강릉시', '포남동'],
#  ['경기도', '평택시', '비전동'],
#  ['부산광역시', '부산진구', '범천동'],
#  ['경상북도', '포항시', '북구', '양덕동'],
#  ['경기도', '화성시', '남양읍', '남양리'],
#  ['서울특별시', '강남구', '자곡동'],
#  ['충청남도', '논산시', '내동'],
#  ['경기도', '남양주시', '호평동'],
#  ['부산광역시', '사상구', '괘법동'],
#  ['경기도', '남양주시', '별내동'],
#  ['서울특별시', '강남구', '자곡동'],
#  ['경상남도', '밀양시', '내이동'],
#  ['서울특별시', '서초구', '우면동'],
#  ['충청북도', '청주시', '청원구', '주중동'],
#  ['경상북도', '영주시', '가흥동'],
#  ['경기도', '군포시', '당동'],
#  ['부산광역시', '기장군', '정관읍', '달산리'],
#  ['전라남도', '해남군', '해남읍', '해리'],
#  ['대전광역시', '유성구', '지족동'],
#  ['전라북도', '완주군', '이서면', '갈산리'],
#  ['충청북도', '음성군', '금왕읍', '금석리'],
#  ['충청북도', '진천군', '덕산읍', '두촌리'],
#  ['서울특별시', '강남구', '자곡동'],
#  ['경상남도', '거제시', '하청면', '하청리'],
#  ['경상북도', '김천시', '율곡동'],
#  ['전라남도', '나주시', '빛가람동'],
#  ['전라남도', '나주시', '빛가람동'],
#  ['전라남도', '보성군', '벌교읍', '회정리'],
#  ['충청남도', '보령시', '성주면', '성주리'],
#  ['광주광역시', '남구', '행암동'],
#  ['부산광역시', '사상구', '감전동'],
#  ['경상남도', '진주시', '충무공동'],
#  ['대구광역시', '달성군', '옥포읍', '강림리'],
#  ['충청북도', '청주시', '청원구', '율량동'],
#  ['경기도', '남양주시', '별내동'],
#  ['경기도', '남양주시', '별내동'],
#  ['전라북도', '완주군', '이서면', '갈산리'],
#  ['제주특별자치도', '제주시', '도련이동'],
#  ['강원도', '속초시', '조양동'],
#  ['경기도', '양주시', '옥정동'],
#  ['경상북도', '포항시', '북구', '양덕동'],
#  ['전라남도', '나주시', '빛가람동'],
#  ['대전광역시', '서구', '관저동'],
#  ['경기도', '남양주시', '별내동'],
#  ['경기도', '남양주시', '별내동'],
#  ['경상남도', '양산시', '물금읍', '가촌리'],
#  ['광주광역시', '남구', '행암동'],
#  ['대구광역시', '달성군', '옥포읍', '강림리'],
#  ['대전광역시', '서구', '관저동'],
#  ['충청북도', '충주시', '안림동'],
#  ['강원도', '원주시', '반곡동'],
#  ['경기도', '구리시', '갈매동'],
#  ['경상남도', '양산시', '물금읍', '물금리'],
#  ['경상남도', '양산시', '물금읍', '물금리'],
#  ['제주특별자치도', '서귀포시', '남원읍', '남원리'],
#  ['충청북도', '제천시', '영천동'],
#  ['경기도', '평택시', '비전동'],
#  ['강원도', '강릉시', '회산동'],
#  ['경기도', '구리시', '갈매동'],
#  ['충청북도', '증평군', '증평읍', '송산리'],
#  ['대전광역시', '유성구', '원신흥동'],
#  ['충청남도', '부여군', '규암면', '내리'],
#  ['광주광역시', '광산구', '선암동'],
#  ['대구광역시', '달성군', '현풍읍', '중리'],
#  ['세종특별자치시', '새롬동'],
#  ['충청북도', '진천군', '덕산읍', '두촌리'],
#  ['대구광역시', '달성군', '유가읍', '봉리'],
#  ['경기도', '평택시', '비전동'],
#  ['세종특별자치시', '종촌동'],
#  ['부산광역시', '부산진구', '전포동'],
#  ['경상북도', '상주시', '함창읍', '구향리'],
#  ['충청북도', '충주시', '안림동'],
#  ['제주특별자치도', '서귀포시', '강정동'],
#  ['경기도', '안성시', '아양동'],
#  ['경상북도', '김천시', '율곡동'],
#  ['경기도', '성남시', '수정구', '창곡동'],
#  ['경기도', '남양주시', '별내동'],
#  ['경상남도', '김해시', '진영읍', '여래리'],
#  ['경상남도', '진주시', '충무공동'],
#  ['부산광역시', '기장군', '정관읍', '모전리'],
#  ['충청북도', '충주시', '대소원면', '본리'],
#  ['경기도', '양주시', '옥정동'],
#  ['경기도', '양주시', '옥정동'],
#  ['강원도', '강릉시', '홍제동'],
#  ['경상남도', '창원시', '진해구', '자은동'],
#  ['경기도', '성남시', '중원구', '성남동'],
#  ['광주광역시', '남구', '행암동'],
#  ['경상남도', '진주시', '충무공동'],
#  ['세종특별자치시', '대평동'],
#  ['경기도', '성남시', '수정구', '창곡동'],
#  ['경상남도', '창원시', '진해구', '자은동'],
#  ['경기도', '군포시', '도마교동'],
#  ['대구광역시', '달서구', '대곡동'],
#  ['경기도', '양주시', '옥정동'],
#  ['경기도', '양주시', '옥정동'],
#  ['부산광역시', '강서구', '명지동'],
#  ['전라남도', '목포시', '연산동'],
#  ['서울특별시', '구로구', '오류동'],
#  ['대구광역시', '달성군', '현풍읍', '중리'],
#  ['전라남도', '순천시', '서면', '선평리'],
#  ['울산광역시', '남구', '야음동'],
#  ['전라북도', '전주시', '덕진구', '반월동'],
#  ['제주특별자치도', '제주시', '봉개동'],
#  ['전라남도', '여수시', '수정동'],
#  ['세종특별자치시', '다정동'],
#  ['대구광역시', '달성군', '옥포읍', '교항리'],
#  ['강원도', '양양군', '강현면', '강선리'],
#  ['울산광역시', '북구', '송정동'],
#  ['경기도', '양주시', '옥정동'],
#  ['경상북도', '김천시', '삼락동'],
#  ['경상남도', '진주시', '문산읍', '삼곡리'],
#  ['제주특별자치도', '서귀포시', '서호동'],
#  ['경기도', '남양주시', '별내동'],
#  ['대전광역시', '유성구', '봉산동'],
#  ['경상남도', '김해시', '장유동'],
#  ['경기도', '성남시', '수정구', '고등동'],
#  ['광주광역시', '광산구', '쌍암동'],
#  ['광주광역시', '광산구', '쌍암동'],
#  ['광주광역시', '남구', '임암동'],
#  ['경기도', '양주시', '광사동'],
#  ['경기도', '평택시', '고덕면', '여염리'],
#  ['울산광역시', '북구', '화봉동'],
#  ['전라남도', '고흥군', '고흥읍', '등암리'],
#  ['경기도', '의왕시', '고천동'],
#  ['제주특별자치도', '서귀포시', '서홍동'],
#  ['강원도', '춘천시', '우두동'],
#  ['부산광역시', '남구', '용호동'],
#  ['충청북도', '제천시', '고암동'],
#  ['강원도', '평창군', '진부면', '하진부리']]

# %%
for idx, j in enumerate (juso):
    if j[-1].strip()[-1] == "리":
        juso[idx] = j[:-1]

# %%
juso = list(map(lambda x: "".join(x) , juso))
juso
# Out:
# ['경상북도포항시북구양덕동',
#  '경상남도통영시미수동',
#  '대전광역시유성구상대동',
#  '경기도남양주시호평동',
#  '전라북도익산시오산면',
#  '전라북도익산시오산면',
#  '경기도성남시분당구백현동',
#  '대전광역시유성구지족동',
#  '강원도횡성군횡성읍',
#  '광주광역시남구백운동',
#  '광주광역시남구백운동',
#  '강원도강릉시교동',
#  '강원도강릉시포남동',
#  '강원도강릉시입암동',
#  '경상남도거제시장평동',
#  '충청남도당진시석문면',
#  '충청남도공주시옥룡동',
#  '부산광역시기장군기장읍',
#  '경상남도김해시구산동',
#  '경상남도김해시삼문동',
#  '대전광역시서구관저동',
#  '대전광역시서구관저동',
#  '대전광역시서구월평동',
#  '대전광역시중구문화동',
#  '대전광역시유성구반석동',
#  '대전광역시대덕구법동',
#  '대전광역시중구중촌동',
#  '경상남도창원시마산회원구내서읍',
#  '경상남도창원시마산회원구내서읍',
#  '경상남도밀양시가곡동',
#  '경상남도밀양시삼문동',
#  '충청남도보령시명천동',
#  '부산광역시북구금곡동',
#  '부산광역시북구금곡동',
#  '부산광역시북구금곡동',
#  '부산광역시북구금곡동',
#  '부산광역시북구덕천동',
#  '부산광역시북구만덕동',
#  '부산광역시사상구모라동',
#  '부산광역시해운대구반송동',
#  '부산광역시북구금곡동',
#  '충청남도부여군부여읍',
#  '경상남도사천시벌리동',
#  '충청남도서산시석림동',
#  '강원도속초시교동',
#  '울산광역시북구화봉동',
#  '강원도원주시문막읍',
#  '부산광역시기장군정관읍',
#  '제주특별자치도제주시아라일동',
#  '제주특별자치도제주시노형동',
#  '제주특별자치도제주시화북일동',
#  '경상남도진주시가좌동',
#  '경상남도진주시평거동',
#  '경상남도창원시진해구자은동',
#  '경상남도창녕군창녕읍',
#  '충청남도천안시서북구백석동',
#  '충청남도천안시서북구성정동',
#  '충청남도천안시서북구쌍용동',
#  '충청남도청양군청양읍',
#  '강원도춘천시후평동',
#  '강원도태백시철암동',
#  '경상남도통영시도남동',
#  '충청남도홍성군홍성읍',
#  '제주특별자치도제주시화북일동',
#  '충청북도제천시강제동',
#  '전라남도여수시소라면',
#  '전라남도여수시소라면',
#  '경상북도고령군다산면',
#  '전라북도순창군풍산면',
#  '전라북도남원시금동',
#  '강원도원주시무실동',
#  '경상남도사천시용현면',
#  '충청북도진천군진천읍',
#  '부산광역시강서구지사동',
#  '광주광역시북구신용동',
#  '광주광역시북구신용동',
#  '경상북도구미시옥계동',
#  '전라남도무안군무안읍',
#  '경기도용인시수지구상현동',
#  '강원도강릉시회산동',
#  '경상북도경산시사동',
#  '경상북도경산시평산동',
#  '경상북도경산시진량읍',
#  '경상북도고령군다산면',
#  '전라북도고창군고창읍',
#  '부산광역시기장군철마면',
#  '경기도광명시소하동',
#  '전라남도광양시마동',
#  '광주광역시남구노대동',
#  '광주광역시남구노대동',
#  '광주광역시남구노대동',
#  '광주광역시광산구신가동',
#  '광주광역시광산구흑석동',
#  '광주광역시북구신용동',
#  '광주광역시북구연제동',
#  '광주광역시북구용두동',
#  '광주광역시북구용봉동',
#  '전라북도군산시삼학동',
#  '충청남도금산군금산읍',
#  '경상북도김천시덕곡동',
#  '경상남도김해시율하동',
#  '경상남도김해시부곡동',
#  '경상남도김해시부곡동',
#  '경상남도김해시진영읍',
#  '경기도남양주시진접읍',
#  '경기도남양주시진접읍',
#  '경기도남양주시진접읍',
#  '경기도남양주시퇴계원읍',
#  '경기도남양주시퇴계원읍',
#  '경기도남양주시호평동',
#  '대전광역시유성구반석동',
#  '대구광역시달성군가창면',
#  '대구광역시달성군다사읍',
#  '대구광역시달서구장기동',
#  '대전광역시유성구봉산동',
#  '전라남도목포시옥암동',
#  '전라남도목포시용해동',
#  '충청남도보령시죽정동',
#  '부산광역시기장군기장읍',
#  '전라북도부안군부안읍',
#  '경상남도사천시용강동',
#  '경상남도사천시사남면',
#  '서울특별시관악구신림동',
#  '충청남도서천군서천읍',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시분당구삼평동',
#  '부산광역시해운대구송정동',
#  '전라북도순창군순창읍',
#  '전라남도순천시서면',
#  '전라남도순천시연향동',
#  '경기도안산시단원구신길동',
#  '경기도안산시단원구신길동',
#  '경기도안산시단원구신길동',
#  '경기도안산시단원구신길동',
#  '경기도안산시상록구팔곡일동',
#  '경상남도양산시남부동',
#  '경기도양주시광적면',
#  '경기도양주시고읍동',
#  '경기도양주시만송동',
#  '경기도양주시만송동',
#  '경기도양주시고암동',
#  '경기도양주시백석읍',
#  '전라남도여수시화장동',
#  '경상북도예천군예천읍',
#  '경기도용인시기흥구청덕동',
#  '경기도용인시기흥구청덕동',
#  '경기도용인시기흥구중동',
#  '경기도용인시기흥구보라동',
#  '경기도용인시기흥구공세동',
#  '경기도용인시기흥구신갈동',
#  '경기도용인시수지구죽전동',
#  '경기도용인시수지구죽전동',
#  '경기도용인시기흥구영덕동',
#  '경기도용인시기흥구영덕동',
#  '경기도용인시기흥구영덕동',
#  '울산광역시울주군범서읍',
#  '울산광역시북구매곡동',
#  '경상북도울진군울진읍',
#  '강원도원주시개운동',
#  '강원도원주시개운동',
#  '강원도원주시무실동',
#  '강원도원주시단계동',
#  '경상남도김해시율하동',
#  '충청북도음성군금왕읍',
#  '경기도의왕시삼동',
#  '경기도의왕시청계동',
#  '경기도의왕시청계동',
#  '경기도이천시갈산동',
#  '경기도이천시갈산동',
#  '전라북도익산시부송동',
#  '전라북도임실군임실읍',
#  '전라남도장성군장성읍',
#  '전라북도장수군장수읍',
#  '충청남도서천군장항읍',
#  '제주특별자치도제주시노형동',
#  '강원도정선군고한읍',
#  '강원도정선군정선읍',
#  '전라북도정읍시농소동',
#  '전라북도정읍시신태인읍',
#  '제주특별자치도제주시도련일동',
#  '제주특별자치도제주시한림읍',
#  '충청북도제천시영천동',
#  '충청북도제천시장락동',
#  '대구광역시달성군다사읍',
#  '충청북도증평군증평읍',
#  '경상남도진주시가좌동',
#  '경상남도창원시진해구자은동',
#  '경상남도창원시의창구도계동',
#  '충청북도청주시청원구내수읍',
#  '충청북도청주시흥덕구가경동',
#  '강원도춘천시퇴계동',
#  '강원도춘천시퇴계동',
#  '충청북도충주시연수동',
#  '충청북도충주시연수동',
#  '경기도평택시안중읍',
#  '경기도평택시이충동',
#  '경상남도함안군가야읍',
#  '경상남도함양군함양읍',
#  '충청북도음성군감곡면',
#  '충청북도청주시서원구성화동',
#  '광주광역시광산구장덕동',
#  '전라남도장성군장성읍',
#  '경기도광명시소하동',
#  '대전광역시유성구봉명동',
#  '경상북도경주시건천읍',
#  '광주광역시광산구장덕동',
#  '대전광역시유성구원신흥동',
#  '전라남도영암군삼호읍',
#  '경상남도창원시의창구봉림동',
#  '경상남도창원시의창구봉림동',
#  '충청북도증평군증평읍',
#  '경상남도양산시소주동',
#  '경기도의왕시포일동',
#  '경기도남양주시별내동',
#  '충청북도청주시청원구주중동',
#  '서울특별시서초구우면동',
#  '경상북도영천시망정동',
#  '경상남도양산시물금읍',
#  '충청남도서천군종천면',
#  '전라남도장흥군장흥읍',
#  '경상남도함안군칠원읍',
#  '강원도강릉시포남동',
#  '경기도평택시비전동',
#  '부산광역시부산진구범천동',
#  '경상북도포항시북구양덕동',
#  '경기도화성시남양읍',
#  '서울특별시강남구자곡동',
#  '충청남도논산시내동',
#  '경기도남양주시호평동',
#  '부산광역시사상구괘법동',
#  '경기도남양주시별내동',
#  '서울특별시강남구자곡동',
#  '경상남도밀양시내이동',
#  '서울특별시서초구우면동',
#  '충청북도청주시청원구주중동',
#  '경상북도영주시가흥동',
#  '경기도군포시당동',
#  '부산광역시기장군정관읍',
#  '전라남도해남군해남읍',
#  '대전광역시유성구지족동',
#  '전라북도완주군이서면',
#  '충청북도음성군금왕읍',
#  '충청북도진천군덕산읍',
#  '서울특별시강남구자곡동',
#  '경상남도거제시하청면',
#  '경상북도김천시율곡동',
#  '전라남도나주시빛가람동',
#  '전라남도나주시빛가람동',
#  '전라남도보성군벌교읍',
#  '충청남도보령시성주면',
#  '광주광역시남구행암동',
#  '부산광역시사상구감전동',
#  '경상남도진주시충무공동',
#  '대구광역시달성군옥포읍',
#  '충청북도청주시청원구율량동',
#  '경기도남양주시별내동',
#  '경기도남양주시별내동',
#  '전라북도완주군이서면',
#  '제주특별자치도제주시도련이동',
#  '강원도속초시조양동',
#  '경기도양주시옥정동',
#  '경상북도포항시북구양덕동',
#  '전라남도나주시빛가람동',
#  '대전광역시서구관저동',
#  '경기도남양주시별내동',
#  '경기도남양주시별내동',
#  '경상남도양산시물금읍',
#  '광주광역시남구행암동',
#  '대구광역시달성군옥포읍',
#  '대전광역시서구관저동',
#  '충청북도충주시안림동',
#  '강원도원주시반곡동',
#  '경기도구리시갈매동',
#  '경상남도양산시물금읍',
#  '경상남도양산시물금읍',
#  '제주특별자치도서귀포시남원읍',
#  '충청북도제천시영천동',
#  '경기도평택시비전동',
#  '강원도강릉시회산동',
#  '경기도구리시갈매동',
#  '충청북도증평군증평읍',
#  '대전광역시유성구원신흥동',
#  '충청남도부여군규암면',
#  '광주광역시광산구선암동',
#  '대구광역시달성군현풍읍',
#  '세종특별자치시새롬동',
#  '충청북도진천군덕산읍',
#  '대구광역시달성군유가읍',
#  '경기도평택시비전동',
#  '세종특별자치시종촌동',
#  '부산광역시부산진구전포동',
#  '경상북도상주시함창읍',
#  '충청북도충주시안림동',
#  '제주특별자치도서귀포시강정동',
#  '경기도안성시아양동',
#  '경상북도김천시율곡동',
#  '경기도성남시수정구창곡동',
#  '경기도남양주시별내동',
#  '경상남도김해시진영읍',
#  '경상남도진주시충무공동',
#  '부산광역시기장군정관읍',
#  '충청북도충주시대소원면',
#  '경기도양주시옥정동',
#  '경기도양주시옥정동',
#  '강원도강릉시홍제동',
#  '경상남도창원시진해구자은동',
#  '경기도성남시중원구성남동',
#  '광주광역시남구행암동',
#  '경상남도진주시충무공동',
#  '세종특별자치시대평동',
#  '경기도성남시수정구창곡동',
#  '경상남도창원시진해구자은동',
#  '경기도군포시도마교동',
#  '대구광역시달서구대곡동',
#  '경기도양주시옥정동',
#  '경기도양주시옥정동',
#  '부산광역시강서구명지동',
#  '전라남도목포시연산동',
#  '서울특별시구로구오류동',
#  '대구광역시달성군현풍읍',
#  '전라남도순천시서면',
#  '울산광역시남구야음동',
#  '전라북도전주시덕진구반월동',
#  '제주특별자치도제주시봉개동',
#  '전라남도여수시수정동',
#  '세종특별자치시다정동',
#  '대구광역시달성군옥포읍',
#  '강원도양양군강현면',
#  '울산광역시북구송정동',
#  '경기도양주시옥정동',
#  '경상북도김천시삼락동',
#  '경상남도진주시문산읍',
#  '제주특별자치도서귀포시서호동',
#  '경기도남양주시별내동',
#  '대전광역시유성구봉산동',
#  '경상남도김해시장유동',
#  '경기도성남시수정구고등동',
#  '광주광역시광산구쌍암동',
#  '광주광역시광산구쌍암동',
#  '광주광역시남구임암동',
#  '경기도양주시광사동',
#  '경기도평택시고덕면',
#  '울산광역시북구화봉동',
#  '전라남도고흥군고흥읍',
#  '경기도의왕시고천동',
#  '제주특별자치도서귀포시서홍동',
#  '강원도춘천시우두동',
#  '부산광역시남구용호동',
#  '충청북도제천시고암동',
#  '강원도평창군진부면']

# %%
juso[112][:-1]
# Out:
# ['대구광역시', '달성군', '다사읍']

# %%
"아리 ".strip()
# Out:
# '아리'

# %%
bjd3
# Out:
#            법정동코드              법정동명 폐지여부    시군구    법정동     시군구1  시군구2 법정동1  \
# 0     1100000000             서울특별시   존재  11000  00000    서울특별시
# 1     1111000000         서울특별시 종로구   존재  11110  00000    서울특별시   종로구
# 2     1114000000          서울특별시 중구   존재  11140  00000    서울특별시    중구
# 3     1117000000         서울특별시 용산구   존재  11170  00000    서울특별시   용산구
# 4     1120000000         서울특별시 성동구   존재  11200  00000    서울특별시   성동구
# ...          ...               ...  ...    ...    ...      ...   ...  ...
# 2217  5011012200   제주특별자치도 제주시 노형동   존재  50110  12200  제주특별자치도   제주시  노형동
# 2218  5011013700    제주특별자치도 제주시 연동   존재  50110  13700  제주특별자치도   제주시   연동
# 2226  5013010500  제주특별자치도 서귀포시 동홍동   존재  50130  10500  제주특별자치도  서귀포시  동홍동
# 2227  5013010600  제주특별자치도 서귀포시 서홍동   존재  50130  10600  제주특별자치도  서귀포시  서홍동
# 2228  5013011200  제주특별자치도 서귀포시 중문동   존재  50130  11200  제주특별자치도  서귀포시  중문동
#
#      법정동2      행정기관코드              행정기관       총인구수        세대수  세대당 인구  \
# 0          1100000000           서울특별시    9,565,990  4,405,638  2.1700
# 1          1111000000        서울특별시 종로구     146,029     73,525  1.9900
# 2          1114000000         서울특별시 중구     123,016     62,897  1.9600
# 3          1117000000        서울특별시 용산구     226,378    111,650  2.0300
# 4          1120000000        서울특별시 성동구     289,162    134,542  2.1500
# ...   ...         ...               ...        ...        ...     ...
# 2217       5011066000   제주특별자치도 제주시 노형동     55,385     23,087  2.4000
# 2218       5011065000    제주특별자치도 제주시 연동     41,910     21,203  1.9800
# 2226       5013057000  제주특별자치도 서귀포시 동홍동     23,205      9,512  2.4400
# 2227       5013058000  제주특별자치도 서귀포시 서홍동     10,925      4,483  2.4400
# 2228       5013061000  제주특별자치도 서귀포시 중문동     11,563      5,544  2.0900
#
#          남자 인구수     여자 인구수  남여 비율
# 0     4,649,442  4,916,548 0.9500
# 1        70,985     75,044 0.9500
# 2        60,019     62,997 0.9500
# 3       108,948    117,430 0.9300
# 4       141,042    148,120 0.9500
# ...         ...        ...    ...
# 2217     27,144     28,241 0.9600
# 2218     20,525     21,385 0.9600
# 2226     11,316     11,889 0.9500
# 2227      5,401      5,524 0.9800
# 2228      5,938      5,625 1.0600
#
# [2523 rows x 17 columns]

# %%
bjd_key = list(map(lambda x: ''.join(x.split()) , bjd3.법정동명))

# %%
len(set(bjd_key) & set(juso))
# Out:
# 58

# %%
pop1_key = list(map(lambda x: ''.join(x.split()) , pop1.행정기관))

# %%
set(pop1_key) & set(juso)
# Out:
# {'강원도강릉시홍제동',
#  '강원도속초시교동',
#  '강원도속초시조양동',
#  '강원도양양군강현면',
#  '강원도원주시개운동',
#  '강원도원주시단계동',
#  '강원도원주시무실동',
#  '강원도원주시문막읍',
#  '강원도정선군고한읍',
#  '강원도정선군정선읍',
#  '강원도춘천시퇴계동',
#  '강원도태백시철암동',
#  '강원도평창군진부면',
#  '강원도횡성군횡성읍',
#  '경기도구리시갈매동',
#  '경기도남양주시별내동',
#  '경기도남양주시진접읍',
#  '경기도남양주시퇴계원읍',
#  '경기도남양주시호평동',
#  '경기도성남시분당구백현동',
#  '경기도성남시분당구삼평동',
#  '경기도성남시수정구고등동',
#  '경기도성남시중원구도촌동',
#  '경기도성남시중원구성남동',
#  '경기도안산시단원구신길동',
#  '경기도양주시광적면',
#  '경기도양주시백석읍',
#  '경기도용인시기흥구보라동',
#  '경기도용인시기흥구신갈동',
#  '경기도의왕시고천동',
#  '경기도의왕시청계동',
#  '경기도평택시고덕면',
#  '경기도평택시안중읍',
#  '경기도화성시남양읍',
#  '경상남도거제시장평동',
#  '경상남도거제시하청면',
#  '경상남도김해시진영읍',
#  '경상남도밀양시가곡동',
#  '경상남도밀양시내이동',
#  '경상남도밀양시삼문동',
#  '경상남도사천시사남면',
#  '경상남도사천시용현면',
#  '경상남도양산시물금읍',
#  '경상남도양산시소주동',
#  '경상남도진주시문산읍',
#  '경상남도진주시충무공동',
#  '경상남도진주시평거동',
#  '경상남도창녕군창녕읍',
#  '경상남도창원시마산회원구내서읍',
#  '경상남도창원시의창구봉림동',
#  '경상남도창원시진해구자은동',
#  '경상남도통영시미수동',
#  '경상남도함안군가야읍',
#  '경상남도함안군칠원읍',
#  '경상남도함양군함양읍',
#  '경상북도경산시진량읍',
#  '경상북도경주시건천읍',
#  '경상북도고령군다산면',
#  '경상북도김천시율곡동',
#  '경상북도상주시함창읍',
#  '경상북도예천군예천읍',
#  '경상북도울진군울진읍',
#  '광주광역시광산구신가동',
#  '광주광역시북구신용동',
#  '광주광역시북구용봉동',
#  '대구광역시달서구장기동',
#  '대구광역시달성군가창면',
#  '대구광역시달성군다사읍',
#  '대구광역시달성군옥포읍',
#  '대구광역시달성군유가읍',
#  '대구광역시달성군현풍읍',
#  '대전광역시유성구원신흥동',
#  '대전광역시중구중촌동',
#  '부산광역시기장군기장읍',
#  '부산광역시기장군정관읍',
#  '부산광역시기장군철마면',
#  '부산광역시북구금곡동',
#  '부산광역시사상구감전동',
#  '부산광역시사상구괘법동',
#  '부산광역시해운대구송정동',
#  '서울특별시관악구신림동',
#  '세종특별자치시다정동',
#  '세종특별자치시대평동',
#  '세종특별자치시새롬동',
#  '세종특별자치시종촌동',
#  '울산광역시북구송정동',
#  '울산광역시울주군범서읍',
#  '전라남도고흥군고흥읍',
#  '전라남도나주시빛가람동',
#  '전라남도목포시연산동',
#  '전라남도목포시옥암동',
#  '전라남도목포시용해동',
#  '전라남도무안군무안읍',
#  '전라남도보성군벌교읍',
#  '전라남도순천시서면',
#  '전라남도여수시소라면',
#  '전라남도영암군삼호읍',
#  '전라남도장성군장성읍',
#  '전라남도장흥군장흥읍',
#  '전라남도해남군해남읍',
#  '전라북도고창군고창읍',
#  '전라북도군산시삼학동',
#  '전라북도남원시금동',
#  '전라북도부안군부안읍',
#  '전라북도순창군순창읍',
#  '전라북도순창군풍산면',
#  '전라북도완주군이서면',
#  '전라북도익산시오산면',
#  '전라북도임실군임실읍',
#  '전라북도장수군장수읍',
#  '전라북도정읍시농소동',
#  '전라북도정읍시신태인읍',
#  '제주특별자치도서귀포시남원읍',
#  '제주특별자치도서귀포시서홍동',
#  '제주특별자치도제주시노형동',
#  '제주특별자치도제주시봉개동',
#  '제주특별자치도제주시한림읍',
#  '충청남도공주시옥룡동',
#  '충청남도금산군금산읍',
#  '충청남도당진시석문면',
#  '충청남도보령시성주면',
#  '충청남도부여군규암면',
#  '충청남도부여군부여읍',
#  '충청남도서천군서천읍',
#  '충청남도서천군장항읍',
#  '충청남도서천군종천면',
#  '충청남도천안시서북구백석동',
#  '충청남도청양군청양읍',
#  '충청남도홍성군홍성읍',
#  '충청북도음성군감곡면',
#  '충청북도음성군금왕읍',
#  '충청북도증평군증평읍',
#  '충청북도진천군덕산읍',
#  '충청북도진천군진천읍',
#  '충청북도청주시청원구내수읍',
#  '충청북도청주시흥덕구가경동',
#  '충청북도충주시대소원면',
#  '충청북도충주시연수동'}

# %%
set(juso) - set(pop1_key)
# Out:
# {'강원도강릉시교동',
#  '강원도강릉시입암동',
#  '강원도강릉시포남동',
#  '강원도강릉시회산동',
#  '강원도원주시반곡동',
#  '강원도춘천시우두동',
#  '강원도춘천시후평동',
#  '경기도광명시소하동',
#  '경기도군포시당동',
#  '경기도군포시도마교동',
#  '경기도성남시수정구창곡동',
#  '경기도안산시상록구팔곡일동',
#  '경기도안성시아양동',
#  '경기도양주시고암동',
#  '경기도양주시고읍동',
#  '경기도양주시광사동',
#  '경기도양주시만송동',
#  '경기도양주시옥정동',
#  '경기도용인시기흥구공세동',
#  '경기도용인시기흥구영덕동',
#  '경기도용인시기흥구중동',
#  '경기도용인시기흥구청덕동',
#  '경기도용인시수지구상현동',
#  '경기도용인시수지구죽전동',
#  '경기도의왕시삼동',
#  '경기도의왕시포일동',
#  '경기도이천시갈산동',
#  '경기도평택시비전동',
#  '경기도평택시이충동',
#  '경상남도김해시구산동',
#  '경상남도김해시부곡동',
#  '경상남도김해시삼문동',
#  '경상남도김해시율하동',
#  '경상남도김해시장유동',
#  '경상남도사천시벌리동',
#  '경상남도사천시용강동',
#  '경상남도양산시남부동',
#  '경상남도진주시가좌동',
#  '경상남도창원시의창구도계동',
#  '경상남도통영시도남동',
#  '경상북도경산시사동',
#  '경상북도경산시평산동',
#  '경상북도구미시옥계동',
#  '경상북도김천시덕곡동',
#  '경상북도김천시삼락동',
#  '경상북도영주시가흥동',
#  '경상북도영천시망정동',
#  '경상북도포항시북구양덕동',
#  '광주광역시광산구선암동',
#  '광주광역시광산구쌍암동',
#  '광주광역시광산구장덕동',
#  '광주광역시광산구흑석동',
#  '광주광역시남구노대동',
#  '광주광역시남구백운동',
#  '광주광역시남구임암동',
#  '광주광역시남구행암동',
#  '광주광역시북구연제동',
#  '광주광역시북구용두동',
#  '대구광역시달서구대곡동',
#  '대전광역시대덕구법동',
#  '대전광역시서구관저동',
#  '대전광역시서구월평동',
#  '대전광역시유성구반석동',
#  '대전광역시유성구봉명동',
#  '대전광역시유성구봉산동',
#  '대전광역시유성구상대동',
#  '대전광역시유성구지족동',
#  '대전광역시중구문화동',
#  '부산광역시강서구명지동',
#  '부산광역시강서구지사동',
#  '부산광역시남구용호동',
#  '부산광역시부산진구범천동',
#  '부산광역시부산진구전포동',
#  '부산광역시북구덕천동',
#  '부산광역시북구만덕동',
#  '부산광역시사상구모라동',
#  '부산광역시해운대구반송동',
#  '서울특별시강남구자곡동',
#  '서울특별시구로구오류동',
#  '서울특별시서초구우면동',
#  '울산광역시남구야음동',
#  '울산광역시북구매곡동',
#  '울산광역시북구화봉동',
#  '전라남도광양시마동',
#  '전라남도순천시연향동',
#  '전라남도여수시수정동',
#  '전라남도여수시화장동',
#  '전라북도익산시부송동',
#  '전라북도전주시덕진구반월동',
#  '제주특별자치도서귀포시강정동',
#  '제주특별자치도서귀포시서호동',
#  '제주특별자치도제주시도련이동',
#  '제주특별자치도제주시도련일동',
#  '제주특별자치도제주시아라일동',
#  '제주특별자치도제주시화북일동',
#  '충청남도논산시내동',
#  '충청남도보령시명천동',
#  '충청남도보령시죽정동',
#  '충청남도서산시석림동',
#  '충청남도천안시서북구성정동',
#  '충청남도천안시서북구쌍용동',
#  '충청북도제천시강제동',
#  '충청북도제천시고암동',
#  '충청북도제천시영천동',
#  '충청북도제천시장락동',
#  '충청북도청주시서원구성화동',
#  '충청북도청주시청원구율량동',
#  '충청북도청주시청원구주중동',
#  '충청북도충주시안림동'}
