# %%
import pandas as pd
pd.options.display.float_format = '{:,.4f}'.format
pd.options.display.max_rows = 100
pd.options.display.max_columns = 40
import numpy as np
import os, shutil
from tqdm import tqdm

# Warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Web Scraping
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.keys import Keys
from time import sleep
from bs4 import BeautifulSoup
from tqdm import tqdm
options = webdriver.ChromeOptions()

options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-gpu")

options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")
options.add_argument("user-agent=Chrome/77.0.3865.90")

from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib, requests, json
from bs4 import BeautifulSoup
import urllib.request
import pandas as pd
import numpy as np
import os, re

# %% [markdown]
# # cf.) functions

# %%
def transform_address(address, filepath, output):
    # output 저장할 파일 생성
    with open(output, "w") as f:
        f.write("old;new\n")
    
    # 크롤링
    url = "https://www.juso.go.kr/openIndexPage.do"
    driver = webdriver.Chrome(executable_path = 'C:/Program Files/chromedriver/chromedriver.exe',options = options)

    for i in tqdm(address):
        driver.get(url)
        selected_tag_a=driver.find_element_by_css_selector('input#inputSearchAddr')
        selected_tag_a.click()
        selected_tag_a.send_keys(i) 
        selected_tag_a.find_element_by_xpath('//*[@id="AKCFrm"]/fieldset/div/button').send_keys((Keys.ENTER))
        source=driver.page_source
        soup=BeautifulSoup(source,'lxml') 
        # output txt파일에 저장
        try:
            address = soup.findAll("div",{"class":"subejct_2"})[0].text.replace('\t','').split("\n")
            new = (address[0]+address[1]).replace('  ',' ').replace('지번','')
            with open(os.path.join(filepath, output), "a") as f:
                f.write(f"{i};{new}\n")
        except IndexError: # 검색 결과가 없는 경우
            print(f"도로명주소: {i}\n지번주소: {new}")
            with open(os.path.join(filepath, output), "a") as f:
                f.write(f"{i};{0}\n")
        except TimeoutException as ex:
            print(ex.Message)
            webDriver.navigate().refresh()
    # txt파일 불러오기
    trans_address = pd.read_csv(os.path.join(filepath, output), sep=";",encoding ="cp949")
    trans_address.columns = ['도로명주소','지번주소']
    return trans_address
            
def get_data(xmlobj, tag):
    try:
        result = xmlobj.findAll(tag)[0].text
    except:
        result = re.findall("\d+", str(xmlobj.findAll(tag)[0]))[0]
    return result

def get_archarea(trans_address, new_address, k_var, v_var):
    old_address = trans_address.loc[trans_address.도로명주소==new_address,"지번주소"].values[0].strip()
    bjdongNm = re.findall('.*?동|.*?리|.*?가', old_address)[0]
    code = bupjeongdong.loc[bupjeongdong.법정동명==bjdongNm,'법정동코드'].unique()[0]
    sigunguCd = str(code)[:5]
    bjdongCd = str(code)[5:]
    try:
        bun_ls = old_address.split("-")
        bun = re.findall("\d+", bun_ls[0])[0].zfill(4)
        ji = re.findall("\d+", bun_ls[1])[0].zfill(4)
    except:
        bun = re.findall("\d+", old_address)[0].zfill(4)
        ji = "0000"
        
    # OpenAPI
    API_KEY = 'aaJUNB0G9RL42RIOAUXocxGfIZRGIP9cxVQ+7+IvE8xiQBA6rhn6AAMqQ81eOudK/8Hb6jfX48cDA2BtbsGt4g=='
    API_URL = 'http://apis.data.go.kr/1613000/BldRgstService_v2/getBrTitleInfo'
    queryParams = '?' + urlencode({quote_plus('serviceKey') : API_KEY, 
                                   quote_plus('sigunguCd') : sigunguCd, 
                                   quote_plus('bjdongCd') : bjdongCd, 
                                   quote_plus('platGbCd') : '0', 
                                   quote_plus('bun') : bun, 
                                   quote_plus('ji') : ji, 
    #                                quote_plus('startDate') : '', 
    #                                quote_plus('endDate') : '', 
                                   quote_plus('numOfRows') : '10',
                                   quote_plus('pageNo') : '1' })
    response = requests.get(API_URL+queryParams).text.encode('utf-8')
    xmlobj = BeautifulSoup(response, 'html.parser')
    
    # key
    res_dic = {k: v for k,v in zip(k_var, v_var)}
    # tag
    tag_list = list(map(lambda x: x.lower(),v_var))
    data = [get_data(xmlobj, tag) for tag in tag_list]
   
    # Dataframe
    for idx, i in  enumerate(res_dic.keys()):
        res_dic[i] = [data[idx]]
    df = pd.DataFrame(res_dic)
    df['도로명주소'] = new_address
    df['지번주소'] = old_address

    return df

def get_building(trans_address, address, k_var, v_var):
    building = pd.DataFrame(columns=k_var)
    for i in tqdm(address):
        try:
            res = get_archarea(trans_address,i,k_var,v_var)
        except:
            res = pd.DataFrame(columns=k_var)
        building = pd.concat([building,res])
    building.reset_index(inplace=True)
    del building['index']
    return building

# %% [markdown]
# # 데이콘 데이터셋 - train.csv, test.csv
# - new_address_tr - train 도로명주소
# - new_address_tst - test 도로명주소

# %%
filepath = 'C:/Users/yumin/OneDrive - 숙명여자대학교/문서/카카오톡 받은 파일'
train = pd.read_csv(os.path.join(filepath,'train_processed.csv'))
print(train.단지코드.nunique())
print(train.도로명주소.nunique())
# Out:
# 421
# 421

# %%
filepath = "../External"
test = pd.read_excel(os.path.join(filepath, 'test_imputed.xlsx'), engine="openpyxl")
print(test.단지코드.nunique())
print(test.도로명주소.nunique())
# Out:
# 150
# 150

# %%
new_address_tr = list(train.도로명주소.unique())
new_address_tst = list(test.도로명주소.unique())
print(len(list(train.도로명주소.unique())+list(test.도로명주소.unique())))
# Out:
# 571

# %% [markdown]
# # 공공임대주택 단지정보 - housing.csv

# %%
filepath = "../External"
housing = pd.read_csv(os.path.join(filepath,'external_data.csv'))

# %%
print(housing.columns)
housing.columns = ['기관명', '광역시도코드', '지역', '시군구코드', '시군구명', '단지명', '도로명주소', '총세대수',
       '공급유형', '형명', '전용면적', '공용면적', '임대건물구분', '주차수', '기본임대보증금', '기본월임대료',
       '기본전환보증금']
print(housing.columns)
# Out:
# Index(['기관명', '광역시도코드', '광역시도명', '시군구코드', '시군구명', '단지명', '도로명주소', '세대수',
#        '공급유형명', '형명', '공급전용면적', '공급공용면적', '주택유형명', '주차수', '기본임대보증금', '기본월임대료',
#        '기본전환보증금'],
#       dtype='object')
# Index(['기관명', '광역시도코드', '지역', '시군구코드', '시군구명', '단지명', '도로명주소', '총세대수', '공급유형',
#        '형명', '전용면적', '공용면적', '임대건물구분', '주차수', '기본임대보증금', '기본월임대료', '기본전환보증금'],
#       dtype='object')

# %% [markdown]
# # 도로명주소 -> 지번주소 변환(필요한 주소만)

# %%
print(len(new_address_tr))
print(len(new_address_tst))
# Out:
# 422

# %%
filepath = "./"
output = 'trans_address_tr.txt'
trans_address_tr = transform_address(new_address_tr, filepath, output)
trans_address_tr
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 421/421 [08:29<00:00,  1.21s/it]
#                      도로명주소                               지번주소
# 0     경상북도 포항시 북구 장량중앙로 17       경상북도 포항시 북구 양덕동 336-1 장량휴먼시아
# 1      경상남도 통영시 미우지해안로 107            경상남도 통영시 미수동 695 미수휴먼시아
# 2         대전광역시 유성구 상대로 40        대전광역시 유성구 상대동 465 도안휴먼시아4단지
# 3          경기도 남양주시 늘을3로 8        경기도 남양주시 호평동 712 주공Humansia
# 4    전라북도 익산시 오산면 선화로4길 66    전라북도 익산시 오산면 장신리 1130 장신휴먼시아1단지
# ..                     ...                                ...
# 416   제주특별자치도 서귀포시 장수로 115  제주특별자치도 서귀포시 서홍동 355-1 서귀포서홍 행복주택
# 417        강원도 춘천시 우두1길 40   강원도 춘천시 우두동 1088 춘천우두엘에이치천년나무3단지
# 418       부산광역시 남구 동명로 183                 부산광역시 남구 용호동 376-9
# 419    충청북도 제천시 용두천로40길 28                  충청북도 제천시 고암동 1273
# 420   강원도 평창군 진부면 경강로 3587    강원도 평창군 진부면 하진부리 115 평창하진부주공아파트
#
# [421 rows x 2 columns]

# %%
filepath = "./"
output = 'trans_address_tst.txt'
trans_address_tst = transform_address(new_address_tst, filepath, output)
trans_address_tst
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 150/150 [03:02<00:00,  1.21s/it]
#                          도로명주소                                      지번주소
# 0               경기도 광명시 서원로 25                경기도 광명시 소하동 1391 광명역세권휴먼시아
# 1              경기도 광명시 성채안로 26                경기도 광명시 소하동 1373 광명역세권휴먼시아
# 2       부산광역시 동래구 충렬대로447번길 38             부산광역시 동래구 안락동 1256 부산안락4 휴먼시아
# 3        전라북도 익산시 오산면 선화로4길 14           전라북도 익산시 오산면 장신리 1126 장신휴먼시아3단지
# 4         경기도 성남시 분당구 동판교로 212            경기도 성남시 분당구 삼평동 728 봇들마을6단지아파트
# ..                         ...                                       ...
# 145  제주특별자치도 서귀포시 성산읍 고성동서로 33  제주특별자치도 서귀포시 성산읍 고성리 1141-1 서귀포성산엘에이치아파트
# 146         충청북도 충주시 호암수청2로 56                 충청북도 충주시 호암동 1066 충주호암1단지
# 147       강원도 화천군 화천읍 산천어길 196               강원도 화천군 화천읍 신읍리 1818 공공실버주택
# 148   경상남도 창원시 마산합포구 가포본동5길 37  경상남도 창원시 마산합포구 가포동 58-2 창원가포 엘에이치아파트 1단지
# 149            전라북도 정읍시 첨단3로 7                       전라북도 정읍시 신정동 1494-1
#
# [150 rows x 2 columns]

# %% [markdown]
# # 법정동 - bupjeongdong.csv

# %%
filepath = "./"
bupjeongdong = pd.read_csv(os.path.join(filepath, "bupjeongdong.csv"))
# bupjeongdong.loc[bupjeongdong.법정동명=="서울특별시 종로구 명륜4가",]

# %% [markdown]
# # 건축물대장정보 - building.csv

# %%
# k_var = ["관리건축물대장PK","건물명","대지면적","건축면적","연면적","용적률산정연면적","용적률","세대수","가구수"]
# v_var = ["mgmBldrgstPk","bldNm","platArea","archArea","totArea","vlRatEstmTotArea","vlRat","hhldCnt","fmlyCnt"]

# building_tr = get_building(trans_address_tr, new_address_tr[:10],k_var,v_var)
# building
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:14<00:00,  1.45s/it]
#          관리건축물대장PK           건물명 대지면적     건축면적       연면적  용적률산정연면적 용적률  세대수  \
# 0  47113-100216867        장량휴먼시아    0  632.955  8409.554  8394.649   0  149
# 1  48220-100186682        미수휴먼시아    0   661.96   1213.87    240.83   0    0
# 2  30200-100200744     도안휴먼시아4단지    0   707.15   4636.41   4636.41   0  102
# 3  41360-100216608          휴먼시아    0   385.99   6017.76   5951.08   0   76
# 4  45140-100190554     장신휴먼시아1단지    0   556.18    6611.9    6611.9   0   84
# 5  45140-100187229     장신휴먼시아2단지    0   549.97    6749.2    6749.2   0   86
# 6  41135-100219035          백현마을    0  314.363   3320.18         0   0    0
# 7  30200-100216666         노은4단지    0   509.89   4595.19   4595.19   0   69
# 8  42730-100185047  횡성읍하 엘에이치아파트    0  265.458  2768.614  2768.614   0   39
# 9  29155-100194096     광주백운3휴먼시아    0   340.66    913.34    913.34   0    0
#
#   가구수                    도로명주소                              지번주소
# 0   0     경상북도 포항시 북구 장량중앙로 17      경상북도 포항시 북구 양덕동 336-1 장량휴먼시아
# 1   0      경상남도 통영시 미우지해안로 107           경상남도 통영시 미수동 695 미수휴먼시아
# 2   0         대전광역시 유성구 상대로 40       대전광역시 유성구 상대동 465 도안휴먼시아4단지
# 3   0          경기도 남양주시 늘을3로 8       경기도 남양주시 호평동 712 주공Humansia
# 4   0    전라북도 익산시 오산면 선화로4길 66   전라북도 익산시 오산면 장신리 1130 장신휴먼시아1단지
# 5   0  전라북도 익산시 오산면 선화로4길 24-9   전라북도 익산시 오산면 장신리 1127 장신휴먼시아2단지
# 6   0      경기도 성남시 분당구 동판교로 92       경기도 성남시 분당구 백현동 546 백현마을3단지
# 7   0    대전광역시 유성구 지족로148번길 40          대전광역시 유성구 지족동 1051 노은4단지
# 8   0     강원도 횡성군 횡성읍 앞들서2로 34  강원도 횡성군 횡성읍 읍하리 172 횡성읍하 엘에이치아파트
# 9   0         광주광역시 남구 백운로 100        광주광역시 남구 백운동 686 광주백운3휴먼시아

# %%
k_var = ["관리건축물대장PK","건물명","대지면적","건축면적","연면적","용적률산정연면적","용적률","세대수","가구수"]
v_var = ["mgmBldrgstPk","bldNm","platArea","archArea","totArea","vlRatEstmTotArea","vlRat","hhldCnt","fmlyCnt"]

building_tr = get_building(trans_address_tr, new_address_tr,k_var,v_var)
building_tst = get_building(trans_address_tst, new_address_tst,k_var,v_var)

# %%
filepath = "../Final"
os.mkdir(filepath)
building_tr.to_csv(os.path.join(filepath,building_tr))
building_tst.to_csv(os.path.join(filepath,building_tst))
