# %% [markdown]
# # 외부데이터 EDA

# %%
#Package
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import font_manager, rc
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#한글폰트 설정
rc('font', family = 'AppleGothic')

# %%
data = pd.read_csv('external_data.csv',header='infer')
data
# Out:
#                기관명  광역시도코드    광역시도명  시군구코드  시군구명        단지명  \
# 0             LH서울      11    서울특별시    110   종로구  서울특별시 종로구
# 1             LH서울      11    서울특별시    110   종로구  서울특별시 종로구
# 2             LH서울      11    서울특별시    110   종로구  서울특별시 종로구
# 3             LH서울      11    서울특별시    110   종로구  서울특별시 종로구
# 4             LH서울      11    서울특별시    110   종로구  서울특별시 종로구
# ...            ...     ...      ...    ...   ...        ...
# 97485  제주특별자치도개발공사      50  제주특별자치도    130  서귀포시    SK원빌라가동
# 97486  제주특별자치도개발공사      50  제주특별자치도    130  서귀포시     반석주택나동
# 97487  제주특별자치도개발공사      50  제주특별자치도    130  서귀포시    SK원연립가동
# 97488  제주특별자치도개발공사      50  제주특별자치도    130  서귀포시    SK원연립가동
# 97489  제주특별자치도개발공사      50  제주특별자치도    130  서귀포시      신효아파트
#
#                                  도로명주소  세대수 공급유형명  형명  공급전용면적   공급공용면적  주택유형명  \
# 0                서울특별시 종로구 종로31가길 25-5   66  매입임대  19   19.68  12.1124   오피스텔
# 1                서울특별시 종로구 종로31가길 25-5   66  매입임대  19   19.69  12.1074   오피스텔
# 2                서울특별시 종로구 종로31가길 25-5   66  매입임대  21   21.41  13.2757   오피스텔
# 3                서울특별시 종로구 종로31가길 25-5   66  매입임대  21   21.42  13.2706   오피스텔
# 4                서울특별시 종로구 종로31가길 25-5   66  매입임대  21   21.94  13.5241   오피스텔
# ...                                ...  ...   ...  ..     ...      ...    ...
# 97485      제주특별자치도 서귀포시 성산읍 고성중앙로 62-1    8  매입임대  2형   61.63   6.7000  다세대주택
# 97486  제주특별자치도 서귀포시 대정읍 최남단해안로125번길 53    8  매입임대  2형   58.40  11.3000   연립주택
# 97487        제주특별자치도 서귀포시 성산읍 산성효자로 30    8  매입임대  2형   74.40   6.3000  다세대주택
# 97488        제주특별자치도 서귀포시 성산읍 산성효자로 30    8  매입임대  2형   81.60   6.9000  다세대주택
# 97489             제주특별자치도 서귀포시 효돈로 145   12  매입임대  2형  101.90  17.0000    아파트
#
#        주차수  기본임대보증금  기본월임대료  기본전환보증금
# 0        0   600000  338000        0
# 1        0   600000  312000        0
# 2        0   600000  342000        0
# 3        0   600000  368000        0
# 4        0   600000  363000        0
# ...    ...      ...     ...      ...
# 97485    0  4314100   18000        0
# 97486    0  4147000   26250        0
# 97487    0  5291000   21670        0
# 97488    0  5791500   23340        0
# 97489    0  7221500   99650        0
#
# [97490 rows x 17 columns]

# %%
data['주택유형명'].value_counts()
# Out:
# 다가구주택    42925
# 다세대주택    32762
# 아파트      13884
# 오피스텔      1570
# 연립주택       946
# 단독주택       819
# Name: 주택유형명, dtype: int64

# %%
data['공급유형명'].value_counts()
# Out:
# 매입임대     87319
# 국민임대      3959
# 장기전세      2109
# 10년임대     1538
# 행복주택       962
# 50년임대      785
# 영구임대       747
# 5년임대        71
# Name: 공급유형명, dtype: int64

# %%
plt.rcParams["figure.figsize"] = (14,8)

sns.countplot(data['주차수'].value_counts())
# Out:
# /Users/yelinkim/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='주차수', ylabel='count'>

# %%
data['주차수'].value_counts()
# Out:
# 0       90247
# 16         56
# 1364       46
# 658        44
# 1311       43
#         ...
# 867         1
# 36          1
# 563         1
# 720         1
# 1116        1
# Name: 주차수, Length: 899, dtype: int64
